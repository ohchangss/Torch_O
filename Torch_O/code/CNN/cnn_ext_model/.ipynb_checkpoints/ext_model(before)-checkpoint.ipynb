# %%
BASE_DIR = '../'*3
RUN_DIR = BASE_DIR + 'code/CNN/cnn_regmodel/cnn_reg_model.ipynb'

# %%
# %run {RUN_DIR}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\program\nalcoding\Torch_O\code\MLP\MLP_MODEL\mlp_model.ipynb in <module>
# ----> 1 import torch.nn as nn
#       2 import torch
#       3 import torch.optim as optim
#       4 import torch.nn.functional as F
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\__init__.py in <module>
#     227
#     228
# --> 229 __all__ += [name for name in dir(_C)
#     230             if name[0] != '_' and
#     231             not name.endswith('Base')]
#
# NameError: name '_C' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\program\nalcoding\Torch_O\code\CNN\cnn_basic\cnn_basic_model.ipynb in <module>
#       1 BASE_DIR = '../'*3
#       2 MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
# ----> 3 get_ipython().run_line_magic('run', '{MLPMODEL}')
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\Documents\program\nalcoding\Torch_O\code\CNN\cnn_basic\cnn_basic_model.ipynb in <module>
# ----> 1 import torch.nn as nn
#       2 import torch
#       3 import torch.optim as optim
#       4 import torch.nn.functional as F
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\__init__.py in <module>
#     227
#     228
# --> 229 __all__ += [name for name in dir(_C)
#     230             if name[0] != '_' and
#     231             not name.endswith('Base')]
#
# NameError: name '_C' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\program\nalcoding\Torch_O\code\CNN\cnn_regmodel\cnn_reg_model.ipynb in <module>
#       1 BASE_DIR = '../'*3
#       2 RUN_DIR = BASE_DIR+"code/CNN/cnn_basic/cnn_basic_model.ipynb"
# ----> 3 get_ipython().run_line_magic('run', '{RUN_DIR}')
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\Documents\program\nalcoding\Torch_O\code\CNN\cnn_regmodel\cnn_reg_model.ipynb in <module>
#       1 BASE_DIR = '../'*3
#       2 MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
# ----> 3 get_ipython().run_line_magic('run', '{MLPMODEL}')
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\Documents\program\nalcoding\Torch_O\code\CNN\cnn_regmodel\cnn_reg_model.ipynb in <module>
# ----> 1 import torch.nn as nn
#       2 import torch
#       3 import torch.optim as optim
#       4 import torch.nn.functional as F
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\__init__.py in <module>
#     227
#     228
# --> 229 __all__ += [name for name in dir(_C)
#     230             if name[0] != '_' and
#     231             not name.endswith('Base')]
#
# NameError: name '_C' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15344/179147624.py in <module>
# ----> 1 get_ipython().run_line_magic('run', '{RUN_DIR}')
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_15344/350211275.py in <module>
#       1 BASE_DIR = '../'*3
#       2 RUN_DIR = BASE_DIR+"code/CNN/cnn_basic/cnn_basic_model.ipynb"
# ----> 3 get_ipython().run_line_magic('run', '{RUN_DIR}')
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_15344/2412433014.py in <module>
#       1 BASE_DIR = '../'*3
#       2 MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
# ----> 3 get_ipython().run_line_magic('run', '{MLPMODEL}')
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_15344/662720437.py in <module>
# ----> 1 import torch.nn as nn
#       2 import torch
#       3 import torch.optim as optim
#       4 import torch.nn.functional as F
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\__init__.py in <module>
#     227
#     228
# --> 229 __all__ += [name for name in dir(_C)
#     230             if name[0] != '_' and
#     231             not name.endswith('Base')]
#
# NameError: name '_C' is not defined

# %%
class CnnExtModel(CnnRegModel):
    macros ={}
    
    def __init__(self, name, dataset, hconfigs, show_maps=False,\
                l2_decay = 0, l1_decay = 0, dump_structure = False):
        self.dump_structure = dump_structure
        self.layer_index = 0
        self.layer_depth=0
        self.param_count = 0
        self.pw = 0
        self.ph = 0
        #
        self.modules = {}
        self.net = []
        self.name = name
        self.macro =[]
        self.idx = 1
        self.pm_hiddens_serial=[]
        #
        super(CnnExtModel, self).__init__(name, dataset, hconfigs, show_maps,l2_decay, l1_decay)
        if self.dump_structure :
            print('Total parameter count : {}'.format(self.param_count))

# %%
def cnn_ext_alloc_layer_param(self, input_shape, hconfig):
    layer_type = get_layer_type(hconfig)
    
    if layer_type in ['serial', 'parallel', 'loop','add','custom']:
        if self.dump_structure:
            dump_str = layer_type
            if layer_type =='custom':
                name = get_conf_param(hconfig, 'name')
                dump_str += ' '+name
            print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
        self.layer_depth += 1;
    pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
    if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
        self.layer_depth -= 1;
    elif self.dump_structure:
        self.layer_index +=1
        pm_str ='';
        if layer_type == 'full':
            ph, pw = pm[0].weight.shape
            pm_count = torch.prod(torch.tensor(pm[0].weight.shape)) + torch.tensor(pm[0].bias.shape[0])
            self.param_count += pm_count
            pm_str = 'pm :{}x{}+{}={}'.format(ph,pw,torch.tensor(pm[0].bias.shape[0]),pm_count)
        elif layer_type == 'conv':
            ychn,xchn,kh,kw = pm[0].weight.shape
            pm_count= torch.prod(torch.tensor(pm[0].weight.shape))+torch.tensor(pm[0].bias.shape[0])
            self.param_count += pm_count            
            pm_str = 'pm : {}x{}x{}x{}+{} = {}'.format(ychn, xchn, kh, kw, torch.tensor(pm[0].bias.shape[0]), pm_count)
        print('{:>{width}}{}: {}, {}=>{}{}'.format('', self.layer_index, layer_type, input_shape, output_shape, pm_str,width=self.layer_depth*2))
    
    return pm, output_shape

CnnExtModel.alloc_layer_param = cnn_ext_alloc_layer_param

# %%
def cnn_ext_alloc_parallel_layer(self, input_shape, hconfig):
    pm_hiddens_parallel = []

    num_parallel=0
    output_shape =None
    
    if not isinstance(hconfig[1], dict): hconfig.insert(1,{})
    for bconfig in hconfig[2:]:
        bpms, bshape = self.alloc_layer_param(input_shape, bconfig)
        for bpm in bpms:
        
            if bpm!=None:
                pm_hiddens_parallel.append(bpm)
                num_parallel += 1

            if output_shape:
                assert output_shape[1:] == bshape[1:]
                output_shape[0] += bshape[0]

            else:
                output_shape = bshape
            
    return [pm_hiddens_parallel], output_shape


CnnExtModel.alloc_parallel_layer = cnn_ext_alloc_parallel_layer

# %%
def cnn_ext_alloc_serial_layer(self, input_shape, hconfig):
    self.pm_hiddens_serial =[]
    prev_shape = input_shape
    
    if not isinstance(hconfig[1], dict) : hconfig.insert(1,{})
    for sconfig in hconfig[2:]:
        
        pm_hiddens, prev_shape = self.alloc_layer_param(prev_shape,sconfig)
        if pm_hiddens[0].__class__.__name__ in ['Normal', 'P_Block','rsd_net']:
        
            self.pm_hiddens_serial=[]
            pass
        else:
            for pm_hidden in pm_hiddens:
                if pm_hidden != None:
                    self.pm_hiddens_serial.append(pm_hidden)
#                     print(pm_hidden)
#         print(self.pm_hiddens_serial)            
    return [self.pm_hiddens_serial], prev_shape
    

CnnExtModel.alloc_serial_layer = cnn_ext_alloc_serial_layer

# %%
def cnn_ext_alloc_add_layer(self, input_shape, hconfig):
    if not isinstance(hconfig[1], dict): hconfig.insert(1, {})
    
    bpm, output_shape = self.alloc_layer_param(input_shape, hconfig[2])
    pm_hiddens = bpm 
    
    for bconfig in hconfig[3:]:
        bpm, bshape =self.alloc_layer_param(input_shape, bconfig)
        pm_hiddens.append(bpm)
        check_add_shape(output_shape, bshape)
        
    if get_conf_param(hconfig, 'x', True):
        check_add_shape(output_shape, input_shape)
        
    pm = pm_hiddens
    
    for act in get_conf_param(hconfig, 'actions', ''):
        if act == 'B':
            bn_config = ['batch_normal', {'rescale':True}]
            pm_b,_=self.alloc_batch_normal_param(output_shape, bn_config)
            pm.append(pm_b)
            
            
    return pm, output_shape

CnnExtModel.alloc_add_layer = cnn_ext_alloc_add_layer

# %%
def check_add_shape(yshape, bshape):
    assert yshape[:0] == bshape[:0]
    assert yshape[0] % bshape[0] == 0
    
def tile_add_result(by, ychn, bchn):
    if ychn == bchn : return by
    times = ychn // bchn
    return np.tile(by, times)

def merge_add_grad(G_y, ychn, bchn):
    if ychn == bchn: return G_y
    
    times = ychn // bchn
    split_shape = G_y.shape[:-1] + tuple([times, bchn])
    return np.sum(G_y.reshape(split_shape), axis = -2)

# %%
def cnn_ext_alloc_loop_layer(self, input_shape, hconfig):
    pm_hiddens = []
    prev_shape = input_shape
    if not isinstance(hconfig[1], dict): hconfig.insert(1,{})
    for n in range(get_conf_param(hconfig, 'repeat',1)):
        pm_hidden, prev_shape = self.alloc_layer_param(prev_shape, hconfig[2])
#         print(pm_hidden)
        pm_hiddens.extend(pm_hidden)
#         print(pm_hiddens)
        
    if len(self.pm_hiddens_serial) == 0:
        return pm_hiddens,prev_shape
    else:
        pm_hiddens=[self.pm_hiddens_serial]+[pm_hiddens]

        name = get_conf_param(hconfig, 'name','loop')

        col = name+'_{0}'.format(self.idx)

        self.modules[col]= pm_hiddens
        N=Normal(pm_hiddens)
        self.net.append(N)
        self.idx += 1
        self.pm_hiddens_serial = []
        
#     print(x)
    return self.net, prev_shape


CnnExtModel.alloc_loop_layer = cnn_ext_alloc_loop_layer

# %%
class rsd_net(nn.Module):
    
    def __init__(self, modules, add=False):
        super(rsd_net, self).__init__()
        self.modules = modules
        self.add=add
            
        idx=[i for i, ele in enumerate(modules) if isinstance(ele, nn.Conv2d) ]
        
        fst_input_shape = modules[idx[0]].in_channels
        lat_output_shape = modules[idx[-1]].out_channels
        
        
        self.relu = nn.ReLU()
        
        self.for_type=''
        if isinstance(modules[-1], nn.AvgPool2d):
            
            self.bh=nn.Sequential(*modules[:-1])
            self.avg = nn.Sequential(nn.AvgPool2d(2,2), nn.Conv2d(in_channels=fst_input_shape,
                                                   out_channels=lat_output_shape,kernel_size=1,padding='same'))
            self.for_type = 'bh'
            
        else:
            self.for_type = 'bf'
            
            self.bf=nn.Sequential(*modules[:-1])
            
            self.short=nn.Sequential()
            if fst_input_shape != lat_output_shape:
                self.short=nn.Sequential(nn.Conv2d(in_channels=fst_input_shape,
                                                   out_channels=lat_output_shape,kernel_size=1,padding='same'))
            
            
                
        
    def forward(self,x):

        if self.for_type == 'bh':
            
            out= self.bh(x) + self.avg(x)
            out = self.relu(out)
            return out
        
        elif self.for_type == 'bf':
            if len(self.short) == 0:
                
                out = self.bf(x)
                out = out+x
                out = self.relu(out)
                
                return out
            else:
                
                out = self.bf(x) + self.short(x)
                out = self.relu(out)
                
                return out

# %%
def cnn_ext_get_layer_inception(self,pm_hidden,macro,name):
    
    # last depth layer return to MLP_init & make layer
    
    if len(pm_hidden)==0 :
        pass
    
    else:
        assert isinstance(macro[1], dict)

        col = name+'_{0}'.format(self.idx)

        if name.split('_')[-1].strip() in ['preproc','postproc']:
            self.modules[col]= pm_hidden
            N=Normal(pm_hidden)
            self.net.append(N)
        else:
            self.modules[col]= pm_hidden
            mo_dict=self.get_module_dict(pm_hidden, col)
            B=P_Block(pm_hidden, col, mo_dict)
            self.net.append(B)
        self.idx += 1
        self.pm_hiddens_serial = []
        

def cnn_ext_get_layer_resnet(self, pm_hidden, macro, name):
    col = name+'_{0}'.format(self.idx)
    if len(pm_hidden)==0 :pass
    
    elif isinstance(pm_hidden[0], nn.AvgPool2d):
        
        self.modules[col]= pm_hidden
        N=Normal(pm_hidden)
        self.net.append(N)
        
    elif self.name[0] == 'v' or self.name[0] == 'p':
        self.modules[col]= pm_hidden
        N=Normal(pm_hidden)
        self.net.append(N)
        self.idx += 1
        self.pm_hiddens_serial = []
        
    else :
        add=get_conf_param(macro, 'x', False)
        assert isinstance(macro[1], dict)
        self.modules[col]= pm_hidden
        rsd=rsd_net(pm_hidden,add)
        self.idx += 1
        self.pm_hiddens_serial = []
        self.net.append(rsd)
        
        
        

def cnn_ext_chck_layer_resnet(self,name):
    
    if len(self.pm_hiddens_serial) != 0:
        col = name+'_{0}'.format(self.idx)
        self.modules[col]= self.pm_hiddens_serial
        N=Normal(self.pm_hiddens_serial)
        self.net.append(N)

CnnExtModel.get_layer_inception = cnn_ext_get_layer_inception
CnnExtModel.get_layer_resnet = cnn_ext_get_layer_resnet
CnnExtModel.chck_layer_resnet = cnn_ext_chck_layer_resnet

# %%
def cnn_ext_alloc_custom_layer(self, input_shape, hconfig):
    name = get_conf_param(hconfig, 'name')
    args = get_conf_param(hconfig, 'args',{})
    macro = CnnExtModel.get_macro(name, args)
    # resnet
    if self.name[0] in ['r','v','p','b']:
        self.chck_layer_resnet(name)
        
        pm_hidden, output_shape = self.alloc_layer_param(input_shape, macro)
        
        pm_hidden=sum(pm_hidden,[])
        
        self.get_layer_resnet(pm_hidden, macro, name)
            
    elif self.name[0] == 'i':
        
        pm_hidden, output_shape = self.alloc_layer_param(input_shape, macro)
        pm_hidden=sum(pm_hidden,[])
        
        self.get_layer_inception(pm_hidden,macro,name)
        
    return self.net, output_shape
   
    

def cnn_ext_forward_custom_layer(self, x, hconfig, pm):
    return self.forward_layer(x, pm['macro'], pm['pm'])



CnnExtModel.alloc_custom_layer = cnn_ext_alloc_custom_layer
CnnExtModel.forward_custom_layer = cnn_ext_forward_custom_layer

# %%
def cnn_ext_get_module_dict(self,pm, col):
    dic={}
    idx = 1
    for layer in pm:
        if not isinstance(layer,list):
            dic[col+'_'+str(idx)]=layer
            idx += 1
        else:
            for layer_depth in layer:
                print(dic)
                if not isinstance(layer_depth, list):
                    dic[col+'_'+str(idx)]=layer_depth
                    idx +=1
                else:
                    k,m = layer_depth
                    dic[col+'_'+str(idx)]=k
                    idx +=1
                    dic[col+'_'+str(idx)]=m
                    idx +=1
    return dic
    
CnnExtModel.get_module_dict = cnn_ext_get_module_dict

# %%
class Normal(nn.Module):
    
    def __init__(self, modules):
        super(Normal, self).__init__()
        if isinstance(modules[0],list):
            modules = sum(modules,[])
        self.layer=nn.Sequential(*modules)
        
    def forward(self,x):
        out = self.layer(x)
        return out

# %%
class P_Block(nn.Module):
    def __init__(self, modules, col, module_dict):
        
        super(P_Block, self).__init__()
        
        self.col = col
        self.modules = modules
        
        setattr(self, self.col, nn.Sequential())
        method = getattr(self, self.col)
        method.add_module('dict', nn.ModuleDict(module_dict))
        
    def forward(self,x):
        cat_modules=[]
        idx = 1
        for dep1_layer in self.modules:
            
            if not isinstance(dep1_layer, list):
                out,idx = self.get_output(idx, x, dep1_layer)
                cat_modules.append(out)
                
            else:
                out_val = None
                
                for dep2_layer in dep1_layer:
                    
                    if not isinstance(dep2_layer, list): # perellel
                        
                        if out_val ==None:
                            out,idx = self.get_output(idx, x, dep2_layer)
                        else:
                            out,idx = self.get_output(idx, out_val, dep2_layer)
                            
                        out_val=out
                        
                    else:
                        
                        out,idx = self.get_output(idx,out_val,dep2_layer)
                        out_val=out

                cat_modules.append(out_val)
        
        return torch.cat(cat_modules,1)                
            
    def get_output(self,idx,x, nn):
        
        out_method = getattr(self, self.col)
        
        if isinstance(nn, list):
            val1 = out_method.dict[self.col+'_'+ str(idx)](x)
            idx += 1
            val2 = out_method.dict[self.col+'_' + str(idx)](x)
            idx += 1
            return torch.cat([val1,val2],dim=1),idx
        
        else:
            out = out_method.dict[self.col+'_' + str(idx)](x)
            idx += 1
            return out,idx

# %%
def cnn_ext_set_macro(name, config):
    CnnExtModel.macros[name] = config
    
def cnn_ext_get_macro(name, args):
    restored = copy.deepcopy(CnnExtModel.macros[name])
    replace_arg(restored, args)
    return restored

def replace_arg(exp, args):
    if isinstance(exp, (list, tuple)):
        for n, term in enumerate(exp):
            if isinstance(term, str) and term[0] == '#':
                if term[1] == '#' :exp[n]= term[1:]
                elif term in args: exp[n]= args[term]
                    
            else:
                replace_arg(term, args)
                
    elif isinstance(exp, dict):
        for key in exp:
            if isinstance(exp[key], str) and exp[key][0] == '#':
                if exp[key][1]=='#' :exp[key] = exp[key][1:]
                elif exp[key] in args : exp[key] = args[exp[key]]
                    
            else:
                replace_arg(exp[key], args)
                
CnnExtModel.set_macro = cnn_ext_set_macro
CnnExtModel.get_macro = cnn_ext_get_macro

# %%
def cnn_ext_alloc_conv_layer(self, input_shape, hconfig):
    pm, output_shape = super(CnnExtModel, self).alloc_conv_layer(input_shape, hconfig)
    xchn_1,xh1,xw1 = input_shape
    sh, sw = get_conf_param_2d(hconfig, 'stride',[1,1])
    kh, kw = get_conf_param_2d(hconfig, 'ksize',[sh,sw])
    
    padding = get_conf_param(hconfig, 'padding')
    act_func = get_conf_param(hconfig, 'actions','LA')
    
    for act in act_func:
        
        if act == 'L':
            input_shape = output_shape
        elif act == 'B':
            bn_config=['batch_noram', {'rescale':False}]
            bpm,input_shape = self.alloc_batch_normal_layer(input_shape, bn_config)
            pm.append(bpm[0])
        elif act == 'A':
#             pass
            pm.append(nn.ReLU())
    xchn, xh, xw = input_shape
    
    ychn= get_conf_param(hconfig, 'chn')
    
    output_shape = eval_stride_shape(hconfig, True, ychn, xh, xw)
    _,yh1,yw1 = output_shape

    self.pw = int((yw1*sw)-xw+kw-1)//2 
    self.ph = int((yh1*sh)-xh+kh-1)//2
    
    if padding==None and (sh,sw)==(1,1):
        padding='same'
    if padding == None:padding=(self.ph,self.pw)
    if padding == 'VALID':padding='valid'
    if padding == 'SAME':padding='same'
        
    pm[0]=nn.Conv2d(kernel_size=(kh, kw),in_channels=xchn_1, out_channels=ychn, padding=padding,stride=(sh,sw))
    
    return pm, output_shape


CnnExtModel.alloc_conv_layer = cnn_ext_alloc_conv_layer

# %%
def cnn_ext_forward_conv_layer(self, x, hconfig, pm):
    y = x
    x_flat, k_flat, relu_y, aux_bn = None, None, None, None
    
    for act in pm['actions']:
        if act == 'L':
            mb_size, xh, xw, xchn = y.shape
            kh, kw, _, ychn = pm['k'].shape
            x_flat = get_ext_regions_for_conv(y, kh, kw)
            k_flat = pm['k'].reshape([kh*kw*xchn, ychn])
            conv_flat = np.matmul(x_flat, k_flat)
            y=conv_flat.reshape([mb_size, xh, xw, ychn])+pm['b']
            
        elif act == 'A':
            y= self.activate(y, hconfig)
            relu_y = y
            
        elif act =='B':
            y, aux_bn = self.forward_batch_normal_layer(y, None, pm['bn'])
            
    y, aux_stride = stride_filter(hconfig, True, y)
    
    if self.need_maps: self. maps.append(y)
        
    return y, [x_flat, k_flat, x, relu_y, aux_bn, aux_stride]


CnnExtModel.forward_conv_layer = cnn_ext_forward_conv_layer

# %%
def cnn_ext_alloc_max_layer(self, input_shape, hconfig):
    ychn, xh, xw = input_shape 
    output_shape = eval_stride_shape(hconfig, False, ychn, xh, xw )
    kh, kw, sh, sw, padding = get_shape_params(hconfig, False)
    if padding =='VALID':padding='valid'
    if padding =='SAME':padding='same'
    _,yh1,yw1 = output_shape
    self.pw = int((yw1*sw)-xw+kw-1)//2 
    self.ph = int((yh1*sh)-xh+kh-1)//2
    
    pm=nn.MaxPool2d((kh,kw),stride=(sh,sw),padding=(self.pw,self.ph))
    
    return [pm], output_shape


CnnExtModel.alloc_max_layer = cnn_ext_alloc_max_layer

# %%
def cnn_ext_forward_max_layer(self, x, hconfig, pm):
    
    mb_size, xh, xw, chn = x.shape
    
    sh, sw = get_conf_param_2d(hconfig, 'strid', [1,1])
    kh, kw = get_conf_param_2d(hconfig, 'ksize', [sh, sw])
    padding = get_conf_param(hconfig, 'padding', 'SAME')
    
    if [sh, sw] == [kh, kw] and xh % sh == 0 and xw % sw == 0 and \
    padding == 'SAME':
        return super(CnnExtModel, self).forward_max_layer(x, hconfig, pm)
    
    x_flat = get_ext_regions(x, kh, kw, -np.inf)
    x_flat = x_flat.transpose([2, 5, 0, 1, 3, 4])
    x_flat = x_flat.reshape(mb_size * chn * xh * xw, kh*kw)
    
    max_idx = np.argmax(x_flat, axis = 1)
    y = x_flat[np.arange(x_flat.shape[0]), max_idx]
    y = y.reshape([mb_size, chn, xh, xw])
    y = y.transpose([0,2,3,1])
    
    
    y, aux_stride = stride_filter(hconfig, False, y)
    
    if self.need_maps : self.maps.append(y)
    
    return y, [x.shape, kh, kw, sh, sw, padding, max_idx, aux_stride]



CnnExtModel.forward_max_layer = cnn_ext_forward_max_layer

# %%
def eval_stride_shape(hconfig, conv_type, ychn, xh, xw):
    kh, kw, sh, sw, padding = get_shape_params(hconfig, conv_type)
    if padding == 'VALID':
        xh = xh - kh + 1
        xw = xw - kw + 1
        
    yh = xh // sh
    yw = xw // sw
    
    return [ychn, yh, yw]

# %%
def stride_filter(hconfig, conv_type, y):
    
    _, xh, xw, _ = x_shape=y.shape
    nh, nw = xh, xw
    kh, kw, sh, sw, padding = get_shape_params(hconfig, conv_type)
    
    
    if padding == 'VALID':
        bh, bw = (kh -1)//2, (kw-1)//2
        nh, nw = xh - kh +1, xw - kw +1
        y=y[:,bh:bh+nh, bw:bw+nw:, :]
        
        
    if sh != 1 or sw != 1:
        bh, bw = (sh-1)//2, (sw -1)//2
        mh,mw = nh // sh, nw//sw
        y = y[:,bh:bh+mh*sh:sh, bw:bw+mw*sw:sw, :]
        
        
    return y, [x_shape, nh, nw]

# %%
def get_shape_params(hconfig, conv_type):
    if conv_type:
        kh, kw = get_conf_param_2d(hconfig, 'ksize')
        sh, sw = get_conf_param_2d(hconfig, 'stride',[1,1])
        
    else:
        sh,sw = get_conf_param_2d(hconfig, 'stride', [1,1])
        kh,kw = get_conf_param_2d(hconfig, 'ksize',[sh, sw])
        
    padding=get_conf_param(hconfig, 'padding', 'SAME')
#     print(padding)
    return kh, kw, sh, sw, padding
