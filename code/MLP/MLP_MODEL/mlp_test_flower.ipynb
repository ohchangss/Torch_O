# %%
BASE_DIR = '../'*3
MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
PREPRO = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'
# %run {MLPMODEL}
# %run {PREPRO}
# Out:
# Using device: cuda
# GeForce GTX 1660 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.1 GB
# Using PyTorch version: 1.7.1

# %%
EPOCH = 1
BATCH_SIZE=20
NUM_WORKERS=0
LEARNING_RATE = 0.0001

# %%
fd = FlowersDataset()
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# 레이어는 아래와 같습니다.
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=5, bias=True)
#   )
# )
#     Epoch 1: cost=54.720, accuracy=0.175/0.200 (0/0 secs)
#     Epoch 1: cost=28.984, accuracy=0.160/0.200 (0/0 secs)
#     Epoch 1: cost=19.858, accuracy=0.167/0.190 (0/0 secs)
#     Epoch 1: cost=15.296, accuracy=0.181/0.160 (0/0 secs)
#     Epoch 1: cost=12.559, accuracy=0.181/0.200 (0/0 secs)
#     Epoch 1: cost=10.732, accuracy=0.183/0.160 (0/0 secs)
#     Epoch 1: cost=9.430, accuracy=0.183/0.190 (0/0 secs)
#     Epoch 1: cost=8.452, accuracy=0.181/0.220 (0/0 secs)
#     Epoch 1: cost=7.692, accuracy=0.177/0.150 (0/0 secs)
#     Epoch 1: cost=7.085, accuracy=0.176/0.210 (0/0 secs)
#     Epoch 1: cost=6.587, accuracy=0.177/0.160 (0/0 secs)
#     Epoch 1: cost=6.171, accuracy=0.181/0.150 (0/0 secs)
#     Epoch 1: cost=5.820, accuracy=0.180/0.210 (0/0 secs)
#     Epoch 1: cost=5.520, accuracy=0.181/0.180 (0/0 secs)
#     Epoch 1: cost=5.259, accuracy=0.180/0.180 (0/0 secs)
#     Epoch 1: cost=5.031, accuracy=0.184/0.230 (0/0 secs)
#     Epoch 1: cost=4.830, accuracy=0.184/0.130 (0/0 secs)
# Model flowers_model_1 train ended in 0 secs:
# Model flowers_model_1 test report: accuracy = 0.155, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [20,20,22,17,21] => 추정 rose : 정답 rose => O
# 추정확률분포 [20,20,22,17,21] => 추정 rose : 정답 daisy => X
# 추정확률분포 [20,20,22,17,21] => 추정 rose : 정답 daisy => X

# %%
# fd = FlowersDataset()
# fm = Mlp_Torch('flowers_model_1', fd, [10])
# fm.exec_all(epoch_count=10, report=2)
