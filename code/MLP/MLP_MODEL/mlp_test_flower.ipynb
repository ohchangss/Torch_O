# %%
BASE_DIR = '../'*3
MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
PREPRO = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'
# %run {MLPMODEL}
# %run {PREPRO}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
EPOCH = 10
BATCH_SIZE=20
NUM_WORKERS=0
LEARNING_RATE = 0.0005

# %%
fd = FlowersDataset()
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8808/1122541276.py in <module>
# ----> 1 fd = FlowersDataset()
#       2 fm = Mlp_Torch('flowers_model_1', fd, [12])
#       3 fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
#       4            , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
#
# ~\AppData\Local\Temp/ipykernel_8808/598706954.py in flowers_init(self, resolution, input_shape)
#      15                 continue
#      16             imagepath = os.path.join(subpath, fname)
# ---> 17             pixels = load_image_pixels(imagepath, resolution, input_shape)
#      18             images.append(pixels)
#      19             idxs.append(dx)
#
# ~\AppData\Local\Temp/ipykernel_8808/1502682102.py in load_image_pixels(imagepath, resolution, input_shape)
#       1 def load_image_pixels(imagepath, resolution, input_shape):
# ----> 2     img = Image.open(imagepath)
#       3     resized = img.resize(resolution)
#       4     return np.array(resized).reshape(input_shape)
#       5
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2966
#    2967     if filename:
# -> 2968         fp = builtins.open(filename, "rb")
#    2969         exclusive_fp = True
#    2970
#
# KeyboardInterrupt:

# %%
fm = Mlp_Torch('flowers_model_1', fd, [30,10])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# 레이어는 아래와 같습니다.
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=5, bias=True)
#   )
# )
#     Epoch 1: cost=166.743, accuracy=0.240/0.280 (1/1 secs)
#     Epoch 1: cost=126.195, accuracy=0.275/0.260 (0/1 secs)
#     Epoch 1: cost=102.767, accuracy=0.275/0.220 (1/2 secs)
#     Epoch 1: cost=83.248, accuracy=0.301/0.370 (0/2 secs)
#     Epoch 1: cost=70.047, accuracy=0.311/0.300 (0/2 secs)
#     Epoch 1: cost=61.316, accuracy=0.314/0.290 (1/3 secs)
#     Epoch 1: cost=54.752, accuracy=0.316/0.320 (0/3 secs)
#     Epoch 1: cost=49.458, accuracy=0.324/0.330 (0/3 secs)
#     Epoch 1: cost=45.858, accuracy=0.328/0.310 (0/3 secs)
#     Epoch 1: cost=42.650, accuracy=0.327/0.270 (1/4 secs)
#     Epoch 1: cost=40.201, accuracy=0.327/0.300 (0/4 secs)
#     Epoch 1: cost=37.895, accuracy=0.332/0.360 (0/4 secs)
#     Epoch 1: cost=36.251, accuracy=0.330/0.230 (1/5 secs)
#     Epoch 1: cost=35.107, accuracy=0.330/0.270 (0/5 secs)
#     Epoch 1: cost=34.367, accuracy=0.330/0.240 (0/5 secs)
#     Epoch 1: cost=34.104, accuracy=0.326/0.310 (0/5 secs)
#     Epoch 1: cost=33.320, accuracy=0.326/0.300 (1/6 secs)
#     Epoch 2: cost=23.786, accuracy=0.270/0.340 (0/6 secs)
#     Epoch 2: cost=20.020, accuracy=0.322/0.270 (0/6 secs)
#     Epoch 2: cost=18.141, accuracy=0.348/0.440 (1/7 secs)
#     Epoch 2: cost=16.288, accuracy=0.364/0.350 (0/7 secs)
#     Epoch 2: cost=14.988, accuracy=0.371/0.370 (0/7 secs)
#     Epoch 2: cost=13.762, accuracy=0.392/0.400 (1/8 secs)
#     Epoch 2: cost=13.447, accuracy=0.391/0.330 (0/8 secs)
#     Epoch 2: cost=14.428, accuracy=0.394/0.270 (0/8 secs)
#     Epoch 2: cost=14.594, accuracy=0.392/0.390 (0/8 secs)
#     Epoch 2: cost=14.689, accuracy=0.393/0.260 (1/9 secs)
#     Epoch 2: cost=14.625, accuracy=0.393/0.310 (0/9 secs)
#     Epoch 2: cost=14.627, accuracy=0.390/0.350 (0/9 secs)
#     Epoch 2: cost=14.104, accuracy=0.396/0.430 (1/10 secs)
#     Epoch 2: cost=14.246, accuracy=0.390/0.380 (0/10 secs)
#     Epoch 2: cost=14.098, accuracy=0.389/0.360 (0/10 secs)
#     Epoch 2: cost=13.989, accuracy=0.390/0.340 (0/10 secs)
#     Epoch 2: cost=14.361, accuracy=0.388/0.270 (1/11 secs)
#     Epoch 3: cost=20.549, accuracy=0.320/0.380 (0/11 secs)
#     Epoch 3: cost=17.544, accuracy=0.337/0.410 (0/11 secs)
#     Epoch 3: cost=14.635, accuracy=0.368/0.310 (1/12 secs)
#     Epoch 3: cost=13.338, accuracy=0.381/0.430 (0/12 secs)
#     Epoch 3: cost=11.865, accuracy=0.403/0.380 (0/12 secs)
#     Epoch 3: cost=11.341, accuracy=0.408/0.350 (1/13 secs)
#     Epoch 3: cost=10.877, accuracy=0.413/0.400 (0/13 secs)
#     Epoch 3: cost=11.005, accuracy=0.410/0.340 (0/13 secs)
#     Epoch 3: cost=10.967, accuracy=0.413/0.300 (1/14 secs)
#     Epoch 3: cost=11.678, accuracy=0.405/0.360 (0/14 secs)
#     Epoch 3: cost=11.867, accuracy=0.405/0.320 (0/14 secs)
#     Epoch 3: cost=11.493, accuracy=0.407/0.370 (0/14 secs)
#     Epoch 3: cost=11.402, accuracy=0.406/0.290 (1/15 secs)
#     Epoch 3: cost=11.262, accuracy=0.409/0.370 (0/15 secs)
#     Epoch 3: cost=11.395, accuracy=0.407/0.320 (0/15 secs)
#     Epoch 3: cost=11.180, accuracy=0.408/0.410 (1/16 secs)
#     Epoch 3: cost=10.927, accuracy=0.410/0.340 (0/16 secs)
#     Epoch 4: cost=7.935, accuracy=0.440/0.430 (0/16 secs)
#     Epoch 4: cost=8.029, accuracy=0.465/0.320 (1/17 secs)
#     Epoch 4: cost=8.739, accuracy=0.473/0.420 (0/17 secs)
#     Epoch 4: cost=8.143, accuracy=0.476/0.320 (0/17 secs)
#     Epoch 4: cost=8.972, accuracy=0.467/0.160 (0/17 secs)
#     Epoch 4: cost=10.976, accuracy=0.442/0.220 (1/18 secs)
#     Epoch 4: cost=11.609, accuracy=0.423/0.310 (0/18 secs)
#     Epoch 4: cost=11.286, accuracy=0.421/0.380 (0/18 secs)
#     Epoch 4: cost=10.989, accuracy=0.426/0.380 (1/19 secs)
#     Epoch 4: cost=10.766, accuracy=0.419/0.310 (0/19 secs)
#     Epoch 4: cost=10.476, accuracy=0.415/0.340 (0/19 secs)
#     Epoch 4: cost=10.212, accuracy=0.413/0.260 (1/20 secs)
#     Epoch 4: cost=10.214, accuracy=0.407/0.270 (0/20 secs)
#     Epoch 4: cost=10.326, accuracy=0.405/0.390 (0/20 secs)
#     Epoch 4: cost=10.250, accuracy=0.402/0.370 (1/21 secs)
#     Epoch 4: cost=9.992, accuracy=0.406/0.320 (0/21 secs)
#     Epoch 4: cost=9.771, accuracy=0.408/0.310 (0/21 secs)
#     Epoch 5: cost=4.037, accuracy=0.430/0.410 (1/22 secs)
#     Epoch 5: cost=4.474, accuracy=0.445/0.270 (0/22 secs)
#     Epoch 5: cost=4.647, accuracy=0.442/0.340 (0/22 secs)
#     Epoch 5: cost=4.437, accuracy=0.449/0.430 (1/23 secs)
#     Epoch 5: cost=4.308, accuracy=0.450/0.320 (0/23 secs)
#     Epoch 5: cost=4.116, accuracy=0.455/0.300 (1/24 secs)
#     Epoch 5: cost=4.735, accuracy=0.438/0.270 (1/25 secs)
#     Epoch 5: cost=5.419, accuracy=0.421/0.240 (1/26 secs)
#     Epoch 5: cost=5.265, accuracy=0.401/0.230 (0/26 secs)
#     Epoch 5: cost=4.904, accuracy=0.384/0.250 (1/27 secs)
#     Epoch 5: cost=4.604, accuracy=0.372/0.300 (1/28 secs)
#     Epoch 5: cost=4.356, accuracy=0.361/0.230 (1/29 secs)
#     Epoch 5: cost=4.145, accuracy=0.352/0.230 (1/30 secs)
#     Epoch 5: cost=3.964, accuracy=0.342/0.240 (1/31 secs)
#     Epoch 5: cost=3.806, accuracy=0.336/0.250 (1/32 secs)
#     Epoch 5: cost=3.668, accuracy=0.327/0.210 (0/32 secs)
#     Epoch 5: cost=3.546, accuracy=0.326/0.240 (1/33 secs)
#     Epoch 6: cost=1.599, accuracy=0.215/0.260 (1/34 secs)
#     Epoch 6: cost=1.603, accuracy=0.208/0.260 (1/35 secs)
#     Epoch 6: cost=1.596, accuracy=0.240/0.290 (1/36 secs)
#     Epoch 6: cost=1.595, accuracy=0.251/0.280 (1/37 secs)
#     Epoch 6: cost=1.595, accuracy=0.241/0.320 (1/38 secs)
#     Epoch 6: cost=1.596, accuracy=0.243/0.310 (1/39 secs)
#     Epoch 6: cost=1.594, accuracy=0.239/0.250 (0/39 secs)
#     Epoch 6: cost=1.593, accuracy=0.246/0.260 (1/40 secs)
#     Epoch 6: cost=1.592, accuracy=0.242/0.280 (1/41 secs)
#     Epoch 6: cost=1.592, accuracy=0.246/0.270 (1/42 secs)
#     Epoch 6: cost=1.593, accuracy=0.247/0.230 (1/43 secs)
#     Epoch 6: cost=1.592, accuracy=0.244/0.280 (0/43 secs)
#     Epoch 6: cost=1.589, accuracy=0.250/0.310 (1/44 secs)
#     Epoch 6: cost=1.586, accuracy=0.252/0.280 (1/45 secs)
#     Epoch 6: cost=1.579, accuracy=0.261/0.300 (1/46 secs)
#     Epoch 6: cost=1.579, accuracy=0.258/0.360 (1/47 secs)
#     Epoch 6: cost=1.580, accuracy=0.260/0.310 (0/47 secs)
#     Epoch 7: cost=1.564, accuracy=0.225/0.330 (1/48 secs)
#     Epoch 7: cost=1.559, accuracy=0.240/0.320 (1/49 secs)
#     Epoch 7: cost=1.552, accuracy=0.262/0.340 (1/50 secs)
#     Epoch 7: cost=1.533, accuracy=0.269/0.300 (1/51 secs)
#     Epoch 7: cost=1.527, accuracy=0.275/0.280 (1/52 secs)
#     Epoch 7: cost=1.530, accuracy=0.283/0.330 (0/52 secs)
#     Epoch 7: cost=1.533, accuracy=0.281/0.350 (1/53 secs)
#     Epoch 7: cost=1.523, accuracy=0.291/0.350 (1/54 secs)
#     Epoch 7: cost=1.517, accuracy=0.297/0.340 (1/55 secs)
#     Epoch 7: cost=1.516, accuracy=0.305/0.310 (0/55 secs)
#     Epoch 7: cost=1.513, accuracy=0.308/0.400 (1/56 secs)
#     Epoch 7: cost=1.512, accuracy=0.305/0.330 (1/57 secs)
#     Epoch 7: cost=1.519, accuracy=0.309/0.310 (1/58 secs)
#     Epoch 7: cost=1.518, accuracy=0.311/0.290 (1/59 secs)
#     Epoch 7: cost=1.514, accuracy=0.311/0.390 (0/59 secs)
#     Epoch 7: cost=1.513, accuracy=0.314/0.370 (1/60 secs)
#     Epoch 7: cost=1.514, accuracy=0.310/0.300 (1/61 secs)
#     Epoch 8: cost=1.533, accuracy=0.270/0.290 (1/62 secs)
#     Epoch 8: cost=1.517, accuracy=0.285/0.300 (1/63 secs)
#     Epoch 8: cost=1.526, accuracy=0.322/0.310 (1/64 secs)
#     Epoch 8: cost=1.529, accuracy=0.329/0.210 (0/64 secs)
#     Epoch 8: cost=1.536, accuracy=0.319/0.250 (2/66 secs)
#     Epoch 8: cost=1.547, accuracy=0.307/0.250 (2/68 secs)
#     Epoch 8: cost=1.553, accuracy=0.301/0.260 (2/70 secs)
#     Epoch 8: cost=1.556, accuracy=0.299/0.270 (1/71 secs)
#     Epoch 8: cost=1.561, accuracy=0.288/0.320 (0/71 secs)
#     Epoch 8: cost=1.564, accuracy=0.289/0.270 (1/72 secs)
#     Epoch 8: cost=1.566, accuracy=0.286/0.330 (1/73 secs)
#     Epoch 8: cost=1.568, accuracy=0.284/0.290 (1/74 secs)
#     Epoch 8: cost=1.570, accuracy=0.278/0.200 (1/75 secs)
#     Epoch 8: cost=1.572, accuracy=0.274/0.230 (0/75 secs)
#     Epoch 8: cost=1.573, accuracy=0.272/0.310 (1/76 secs)
#     Epoch 8: cost=1.573, accuracy=0.270/0.250 (1/77 secs)
#     Epoch 8: cost=1.572, accuracy=0.269/0.330 (1/78 secs)
#     Epoch 9: cost=1.562, accuracy=0.225/0.310 (1/79 secs)
#     Epoch 9: cost=1.513, accuracy=0.305/0.320 (1/80 secs)
#     Epoch 9: cost=1.501, accuracy=0.320/0.330 (1/81 secs)
#     Epoch 9: cost=1.501, accuracy=0.321/0.380 (0/81 secs)
#     Epoch 9: cost=1.506, accuracy=0.313/0.280 (1/82 secs)
#     Epoch 9: cost=1.497, accuracy=0.325/0.340 (1/83 secs)
#     Epoch 9: cost=1.506, accuracy=0.326/0.320 (1/84 secs)
#     Epoch 9: cost=1.502, accuracy=0.326/0.260 (1/85 secs)
#     Epoch 9: cost=1.514, accuracy=0.323/0.270 (1/86 secs)
#     Epoch 9: cost=1.519, accuracy=0.318/0.340 (0/86 secs)
#     Epoch 9: cost=1.521, accuracy=0.314/0.300 (1/87 secs)
#     Epoch 9: cost=1.519, accuracy=0.313/0.280 (1/88 secs)
#     Epoch 9: cost=1.513, accuracy=0.315/0.390 (1/89 secs)
#     Epoch 9: cost=1.516, accuracy=0.316/0.310 (0/89 secs)
#     Epoch 9: cost=1.520, accuracy=0.311/0.330 (1/90 secs)
#     Epoch 9: cost=1.523, accuracy=0.308/0.290 (1/91 secs)
#     Epoch 9: cost=1.526, accuracy=0.306/0.360 (1/92 secs)
#     Epoch 10: cost=1.566, accuracy=0.270/0.300 (1/93 secs)
#     Epoch 10: cost=1.566, accuracy=0.265/0.250 (1/94 secs)
#     Epoch 10: cost=1.567, accuracy=0.265/0.330 (0/94 secs)
#     Epoch 10: cost=1.561, accuracy=0.281/0.300 (1/95 secs)
#     Epoch 10: cost=1.550, accuracy=0.294/0.270 (1/96 secs)
#     Epoch 10: cost=1.553, accuracy=0.301/0.280 (1/97 secs)
#     Epoch 10: cost=1.541, accuracy=0.299/0.310 (1/98 secs)
#     Epoch 10: cost=1.529, accuracy=0.308/0.330 (0/98 secs)
#     Epoch 10: cost=1.526, accuracy=0.307/0.280 (1/99 secs)
#     Epoch 10: cost=1.519, accuracy=0.310/0.340 (1/100 secs)
#     Epoch 10: cost=1.513, accuracy=0.313/0.320 (1/101 secs)
#     Epoch 10: cost=1.509, accuracy=0.312/0.290 (1/102 secs)
#     Epoch 10: cost=1.504, accuracy=0.316/0.310 (0/102 secs)
#     Epoch 10: cost=1.505, accuracy=0.312/0.330 (1/103 secs)
#     Epoch 10: cost=1.508, accuracy=0.310/0.290 (1/104 secs)
#     Epoch 10: cost=1.508, accuracy=0.311/0.290 (1/105 secs)
#     Epoch 10: cost=1.507, accuracy=0.312/0.330 (0/105 secs)
# Model flowers_model_1 train ended in 106 secs:
# Model flowers_model_1 test report: accuracy = 0.327, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [20,25,16,19,20] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [20,25,16,19,20] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [20,25,16,19,20] => 추정 dandelion : 정답 rose => X

# %%
# fd = FlowersDataset()?
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0005
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8808/1026971213.py in <module>
#       2 fm = Mlp_Torch('flowers_model_1', fd, [12])
#       3 fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
# ----> 4            , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
#
# ~\AppData\Local\Temp/ipykernel_8808/4054610662.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, num_workers)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3, num_workers=0):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report, num_workers)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# ~\AppData\Local\Temp/ipykernel_8808/2384071044.py in train_torch(self, epoch_count, batch_size, learning_rate, report, num_workers)
#      46             acc = self.eval_accuracy(X_train, y_train, output)
#      47
# ---> 48             loss.backward()
#      49             optimizer.step()
#      50
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:
