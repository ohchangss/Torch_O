# %%
BASE_DIR = '../'*3
MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
PREPRO = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'
# %run {MLPMODEL}
# %run {PREPRO}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
EPOCH = 10
BATCH_SIZE=20
NUM_WORKERS=0
LEARNING_RATE = 0.0001

# %%
fd = FlowersDataset()
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# 레이어는 아래와 같습니다.
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=5, bias=True)
#   )
# )
#     Epoch 1: cost=4.826, accuracy=0.190/0.280 (1/1 secs)
#     Epoch 1: cost=3.214, accuracy=0.225/0.230 (0/1 secs)
#     Epoch 1: cost=2.681, accuracy=0.227/0.210 (1/2 secs)
#     Epoch 1: cost=2.417, accuracy=0.224/0.230 (0/2 secs)
#     Epoch 1: cost=2.286, accuracy=0.222/0.210 (1/3 secs)
#     Epoch 1: cost=2.175, accuracy=0.215/0.220 (0/3 secs)
#     Epoch 1: cost=2.093, accuracy=0.226/0.250 (1/4 secs)
#     Epoch 1: cost=2.031, accuracy=0.233/0.310 (0/4 secs)
#     Epoch 1: cost=1.985, accuracy=0.230/0.230 (1/5 secs)
#     Epoch 1: cost=1.948, accuracy=0.232/0.240 (0/5 secs)
#     Epoch 1: cost=1.917, accuracy=0.233/0.230 (1/6 secs)
#     Epoch 1: cost=1.893, accuracy=0.233/0.220 (0/6 secs)
#     Epoch 1: cost=1.872, accuracy=0.233/0.250 (0/6 secs)
#     Epoch 1: cost=1.852, accuracy=0.236/0.290 (1/7 secs)
#     Epoch 1: cost=1.835, accuracy=0.239/0.220 (0/7 secs)
#     Epoch 1: cost=1.820, accuracy=0.242/0.210 (1/8 secs)
#     Epoch 1: cost=1.807, accuracy=0.243/0.260 (0/8 secs)
#     Epoch 2: cost=1.603, accuracy=0.265/0.170 (1/9 secs)
#     Epoch 2: cost=1.608, accuracy=0.248/0.160 (0/9 secs)
#     Epoch 2: cost=1.611, accuracy=0.240/0.190 (1/10 secs)
#     Epoch 2: cost=1.614, accuracy=0.234/0.250 (0/10 secs)
#     Epoch 2: cost=1.607, accuracy=0.247/0.220 (1/11 secs)
#     Epoch 2: cost=1.606, accuracy=0.250/0.240 (0/11 secs)
#     Epoch 2: cost=1.607, accuracy=0.249/0.190 (0/11 secs)
#     Epoch 2: cost=1.607, accuracy=0.248/0.250 (1/12 secs)
#     Epoch 2: cost=1.608, accuracy=0.247/0.190 (0/12 secs)
#     Epoch 2: cost=1.607, accuracy=0.250/0.180 (1/13 secs)
#     Epoch 2: cost=1.608, accuracy=0.248/0.230 (0/13 secs)
#     Epoch 2: cost=1.610, accuracy=0.245/0.280 (0/13 secs)
#     Epoch 2: cost=1.610, accuracy=0.245/0.220 (1/14 secs)
#     Epoch 2: cost=1.611, accuracy=0.241/0.180 (0/14 secs)
#     Epoch 2: cost=1.612, accuracy=0.240/0.240 (1/15 secs)
#     Epoch 2: cost=1.611, accuracy=0.242/0.260 (0/15 secs)
#     Epoch 2: cost=1.610, accuracy=0.245/0.250 (1/16 secs)
#     Epoch 3: cost=1.608, accuracy=0.260/0.270 (0/16 secs)
#     Epoch 3: cost=1.618, accuracy=0.227/0.280 (1/17 secs)
#     Epoch 3: cost=1.614, accuracy=0.242/0.290 (0/17 secs)
#     Epoch 3: cost=1.612, accuracy=0.245/0.220 (0/17 secs)
#     Epoch 3: cost=1.608, accuracy=0.250/0.220 (1/18 secs)
#     Epoch 3: cost=1.610, accuracy=0.242/0.280 (0/18 secs)
#     Epoch 3: cost=1.608, accuracy=0.246/0.250 (1/19 secs)
#     Epoch 3: cost=1.610, accuracy=0.242/0.250 (0/19 secs)
#     Epoch 3: cost=1.610, accuracy=0.244/0.210 (0/19 secs)
#     Epoch 3: cost=1.610, accuracy=0.245/0.210 (1/20 secs)
#     Epoch 3: cost=1.611, accuracy=0.242/0.210 (0/20 secs)
#     Epoch 3: cost=1.612, accuracy=0.241/0.240 (1/21 secs)
#     Epoch 3: cost=1.611, accuracy=0.242/0.260 (0/21 secs)
#     Epoch 3: cost=1.610, accuracy=0.244/0.250 (1/22 secs)
#     Epoch 3: cost=1.610, accuracy=0.243/0.270 (0/22 secs)
#     Epoch 3: cost=1.609, accuracy=0.244/0.240 (0/22 secs)
#     Epoch 3: cost=1.608, accuracy=0.246/0.260 (1/23 secs)
#     Epoch 4: cost=1.611, accuracy=0.260/0.220 (0/23 secs)
#     Epoch 4: cost=1.608, accuracy=0.255/0.250 (1/24 secs)
#     Epoch 4: cost=1.604, accuracy=0.263/0.220 (0/24 secs)
#     Epoch 4: cost=1.608, accuracy=0.259/0.220 (1/25 secs)
#     Epoch 4: cost=1.605, accuracy=0.261/0.250 (0/25 secs)
#     Epoch 4: cost=1.608, accuracy=0.255/0.210 (1/26 secs)
#     Epoch 4: cost=1.609, accuracy=0.249/0.230 (0/26 secs)
#     Epoch 4: cost=1.610, accuracy=0.247/0.210 (0/26 secs)
#     Epoch 4: cost=1.610, accuracy=0.247/0.220 (1/27 secs)
#     Epoch 4: cost=1.609, accuracy=0.248/0.210 (0/27 secs)
#     Epoch 4: cost=1.608, accuracy=0.249/0.280 (1/28 secs)
#     Epoch 4: cost=1.608, accuracy=0.249/0.210 (0/28 secs)
#     Epoch 4: cost=1.609, accuracy=0.244/0.200 (1/29 secs)
#     Epoch 4: cost=1.610, accuracy=0.242/0.220 (0/29 secs)
#     Epoch 4: cost=1.610, accuracy=0.241/0.270 (1/30 secs)
#     Epoch 4: cost=1.609, accuracy=0.244/0.240 (0/30 secs)
#     Epoch 4: cost=1.608, accuracy=0.245/0.240 (1/31 secs)
#     Epoch 5: cost=1.615, accuracy=0.230/0.260 (0/31 secs)
#     Epoch 5: cost=1.606, accuracy=0.250/0.260 (1/32 secs)
#     Epoch 5: cost=1.609, accuracy=0.243/0.200 (0/32 secs)
#     Epoch 5: cost=1.604, accuracy=0.255/0.210 (1/33 secs)
#     Epoch 5: cost=1.605, accuracy=0.251/0.260 (1/34 secs)
#     Epoch 5: cost=1.601, accuracy=0.261/0.220 (1/35 secs)
#     Epoch 5: cost=1.600, accuracy=0.261/0.290 (1/36 secs)
#     Epoch 5: cost=1.601, accuracy=0.259/0.250 (1/37 secs)
#     Epoch 5: cost=1.605, accuracy=0.250/0.250 (1/38 secs)
#     Epoch 5: cost=1.606, accuracy=0.246/0.240 (1/39 secs)
#     Epoch 5: cost=1.605, accuracy=0.247/0.230 (1/40 secs)
#     Epoch 5: cost=1.606, accuracy=0.246/0.240 (1/41 secs)
#     Epoch 5: cost=1.607, accuracy=0.246/0.240 (1/42 secs)
#     Epoch 5: cost=1.607, accuracy=0.247/0.200 (1/43 secs)
#     Epoch 5: cost=1.606, accuracy=0.248/0.280 (1/44 secs)
#     Epoch 5: cost=1.607, accuracy=0.245/0.250 (1/45 secs)
#     Epoch 5: cost=1.608, accuracy=0.244/0.200 (1/46 secs)
#     Epoch 6: cost=1.618, accuracy=0.220/0.290 (1/47 secs)
#     Epoch 6: cost=1.620, accuracy=0.218/0.250 (1/48 secs)
#     Epoch 6: cost=1.608, accuracy=0.248/0.200 (1/49 secs)
#     Epoch 6: cost=1.611, accuracy=0.240/0.290 (1/50 secs)
#     Epoch 6: cost=1.609, accuracy=0.241/0.210 (1/51 secs)
#     Epoch 6: cost=1.611, accuracy=0.237/0.260 (1/52 secs)
#     Epoch 6: cost=1.607, accuracy=0.245/0.270 (1/53 secs)
#     Epoch 6: cost=1.607, accuracy=0.248/0.240 (1/54 secs)
#     Epoch 6: cost=1.607, accuracy=0.249/0.190 (1/55 secs)
#     Epoch 6: cost=1.606, accuracy=0.249/0.240 (1/56 secs)
#     Epoch 6: cost=1.607, accuracy=0.245/0.290 (1/57 secs)
#     Epoch 6: cost=1.608, accuracy=0.244/0.230 (1/58 secs)
#     Epoch 6: cost=1.609, accuracy=0.241/0.220 (1/59 secs)
#     Epoch 6: cost=1.608, accuracy=0.243/0.220 (1/60 secs)
#     Epoch 6: cost=1.609, accuracy=0.241/0.230 (1/61 secs)
#     Epoch 6: cost=1.608, accuracy=0.242/0.210 (1/62 secs)
#     Epoch 6: cost=1.607, accuracy=0.245/0.250 (1/63 secs)
#     Epoch 7: cost=1.608, accuracy=0.235/0.230 (1/64 secs)
#     Epoch 7: cost=1.610, accuracy=0.237/0.250 (1/65 secs)
#     Epoch 7: cost=1.614, accuracy=0.228/0.180 (1/66 secs)
#     Epoch 7: cost=1.614, accuracy=0.228/0.270 (1/67 secs)
#     Epoch 7: cost=1.614, accuracy=0.230/0.270 (1/68 secs)
#     Epoch 7: cost=1.616, accuracy=0.227/0.180 (0/68 secs)
#     Epoch 7: cost=1.612, accuracy=0.236/0.230 (1/69 secs)
#     Epoch 7: cost=1.611, accuracy=0.237/0.250 (1/70 secs)
#     Epoch 7: cost=1.611, accuracy=0.236/0.200 (1/71 secs)
#     Epoch 7: cost=1.609, accuracy=0.240/0.220 (1/72 secs)
#     Epoch 7: cost=1.609, accuracy=0.241/0.230 (1/73 secs)
#     Epoch 7: cost=1.609, accuracy=0.241/0.240 (1/74 secs)
#     Epoch 7: cost=1.608, accuracy=0.244/0.220 (1/75 secs)
#     Epoch 7: cost=1.608, accuracy=0.243/0.210 (1/76 secs)
#     Epoch 7: cost=1.606, accuracy=0.247/0.220 (1/77 secs)
#     Epoch 7: cost=1.607, accuracy=0.244/0.270 (1/78 secs)
#     Epoch 7: cost=1.607, accuracy=0.244/0.200 (1/79 secs)
#     Epoch 8: cost=1.594, accuracy=0.275/0.200 (1/80 secs)
#     Epoch 8: cost=1.599, accuracy=0.270/0.210 (1/81 secs)
#     Epoch 8: cost=1.598, accuracy=0.262/0.240 (1/82 secs)
#     Epoch 8: cost=1.608, accuracy=0.236/0.240 (1/83 secs)
#     Epoch 8: cost=1.608, accuracy=0.234/0.270 (1/84 secs)
#     Epoch 8: cost=1.605, accuracy=0.242/0.280 (2/86 secs)
#     Epoch 8: cost=1.607, accuracy=0.239/0.200 (1/87 secs)
#     Epoch 8: cost=1.608, accuracy=0.239/0.290 (1/88 secs)
#     Epoch 8: cost=1.608, accuracy=0.238/0.260 (1/89 secs)
#     Epoch 8: cost=1.606, accuracy=0.243/0.260 (2/91 secs)
#     Epoch 8: cost=1.605, accuracy=0.247/0.280 (1/92 secs)
#     Epoch 8: cost=1.605, accuracy=0.245/0.180 (1/93 secs)
#     Epoch 8: cost=1.607, accuracy=0.242/0.220 (1/94 secs)
#     Epoch 8: cost=1.606, accuracy=0.245/0.250 (1/95 secs)
#     Epoch 8: cost=1.607, accuracy=0.242/0.240 (1/96 secs)
#     Epoch 8: cost=1.606, accuracy=0.245/0.260 (1/97 secs)
#     Epoch 8: cost=1.606, accuracy=0.244/0.210 (1/98 secs)
#     Epoch 9: cost=1.602, accuracy=0.245/0.280 (1/99 secs)
#     Epoch 9: cost=1.607, accuracy=0.238/0.230 (1/100 secs)
#     Epoch 9: cost=1.606, accuracy=0.242/0.130 (1/101 secs)
#     Epoch 9: cost=1.605, accuracy=0.245/0.260 (1/102 secs)
#     Epoch 9: cost=1.604, accuracy=0.249/0.230 (1/103 secs)
#     Epoch 9: cost=1.605, accuracy=0.248/0.220 (1/104 secs)
#     Epoch 9: cost=1.605, accuracy=0.246/0.160 (1/105 secs)
#     Epoch 9: cost=1.604, accuracy=0.248/0.250 (1/106 secs)
#     Epoch 9: cost=1.603, accuracy=0.248/0.240 (1/107 secs)
#     Epoch 9: cost=1.604, accuracy=0.246/0.210 (1/108 secs)
#     Epoch 9: cost=1.604, accuracy=0.246/0.210 (2/110 secs)
#     Epoch 9: cost=1.604, accuracy=0.245/0.280 (1/111 secs)
#     Epoch 9: cost=1.605, accuracy=0.245/0.270 (1/112 secs)
#     Epoch 9: cost=1.606, accuracy=0.241/0.330 (1/113 secs)
#     Epoch 9: cost=1.606, accuracy=0.242/0.240 (1/114 secs)
#     Epoch 9: cost=1.605, accuracy=0.245/0.250 (1/115 secs)
#     Epoch 9: cost=1.606, accuracy=0.244/0.240 (1/116 secs)
#     Epoch 10: cost=1.602, accuracy=0.255/0.250 (1/117 secs)
#     Epoch 10: cost=1.609, accuracy=0.238/0.290 (1/118 secs)
#     Epoch 10: cost=1.613, accuracy=0.227/0.220 (1/119 secs)
#     Epoch 10: cost=1.614, accuracy=0.220/0.260 (1/120 secs)
#     Epoch 10: cost=1.613, accuracy=0.221/0.230 (1/121 secs)
#     Epoch 10: cost=1.611, accuracy=0.225/0.220 (1/122 secs)
#     Epoch 10: cost=1.610, accuracy=0.231/0.250 (2/124 secs)
#     Epoch 10: cost=1.609, accuracy=0.235/0.230 (1/125 secs)
#     Epoch 10: cost=1.609, accuracy=0.236/0.270 (1/126 secs)
#     Epoch 10: cost=1.608, accuracy=0.237/0.220 (1/127 secs)
#     Epoch 10: cost=1.607, accuracy=0.239/0.270 (1/128 secs)
#     Epoch 10: cost=1.607, accuracy=0.238/0.240 (1/129 secs)
#     Epoch 10: cost=1.607, accuracy=0.239/0.240 (1/130 secs)
#     Epoch 10: cost=1.606, accuracy=0.242/0.240 (1/131 secs)
#     Epoch 10: cost=1.607, accuracy=0.241/0.260 (1/132 secs)
#     Epoch 10: cost=1.606, accuracy=0.244/0.210 (1/133 secs)
#     Epoch 10: cost=1.606, accuracy=0.244/0.270 (1/134 secs)
# Model flowers_model_1 train ended in 134 secs:
# Model flowers_model_1 test report: accuracy = 0.241, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [20,26,17,18,19] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [20,26,17,18,19] => 추정 dandelion : 정답 sunflower => X
# 추정확률분포 [20,26,17,18,19] => 추정 dandelion : 정답 tulip => X

# %%
# fd = FlowersDataset()
# fm = Mlp_Torch('flowers_model_1', fd, [10])
# fm.exec_all(epoch_count=10, report=2)
