# %%
BASE_DIR = '../'*3
MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
PREPRO = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'
# %run {MLPMODEL}
# %run {PREPRO}
# Out:
# Using device: cuda
# GeForce GTX 1660 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.1 GB
# Using PyTorch version: 1.7.1

# %%
EPOCH = 10
BATCH_SIZE=30
NUM_WORKERS=0
LEARNING_RATE = 0.00005

# %%
#SGD
fd = FlowersDataset()
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1a7a74a1891b> in <module>
#       1 #SGD
# ----> 2 fd = FlowersDataset()
#       3 fm = Mlp_Torch('flowers_model_1', fd, [12])
#       4 fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
#       5            , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
#
# <ipython-input-11-a3991dff43bd> in flowers_init(self, resolution, input_shape)
#      15                 continue
#      16             imagepath = os.path.join(subpath, fname)
# ---> 17             pixels = load_image_pixels(imagepath, resolution, input_shape)
#      18             images.append(pixels)
#      19             idxs.append(dx)
#
# <ipython-input-11-f8a9af307e14> in load_image_pixels(imagepath, resolution, input_shape)
#       1 def load_image_pixels(imagepath, resolution, input_shape):
#       2     img = Image.open(imagepath)
# ----> 3     resized = img.resize(resolution)
#       4     return np.array(resized).reshape(input_shape)
#       5
#
# ~\Anaconda3\envs\testtorch\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1914             return im.convert(self.mode)
#    1915
# -> 1916         self.load()
#    1917
#    1918         if reducing_gap is not None and resample != NEAREST:
#
# ~\Anaconda3\envs\testtorch\lib\site-packages\PIL\ImageFile.py in load(self)
#     263
#     264                             b = b + s
# --> 265                             n, err_code = decoder.decode(b)
#     266                             if n < 0:
#     267                                 break
#
# KeyboardInterrupt:

# %%
# Adam
fd = FlowersDataset()
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
#     Epoch 1: cost=11.743, accuracy=0.162/0.190 (0/0 secs)
#     Epoch 1: cost=6.692, accuracy=0.169/0.140 (0/0 secs)
#     Epoch 1: cost=5.008, accuracy=0.170/0.170 (0/0 secs)
#     Epoch 1: cost=4.166, accuracy=0.172/0.120 (0/0 secs)
#     Epoch 2: cost=1.633, accuracy=0.159/0.180 (0/0 secs)
#     Epoch 2: cost=1.634, accuracy=0.161/0.180 (1/1 secs)
#     Epoch 2: cost=1.632, accuracy=0.167/0.120 (0/1 secs)
#     Epoch 2: cost=1.632, accuracy=0.172/0.150 (0/1 secs)
#     Epoch 3: cost=1.623, accuracy=0.178/0.160 (0/1 secs)
#     Epoch 3: cost=1.626, accuracy=0.161/0.120 (0/1 secs)
#     Epoch 3: cost=1.624, accuracy=0.171/0.160 (0/1 secs)
#     Epoch 3: cost=1.623, accuracy=0.174/0.120 (0/1 secs)
#     Epoch 4: cost=1.617, accuracy=0.192/0.140 (1/2 secs)
#     Epoch 4: cost=1.618, accuracy=0.179/0.140 (0/2 secs)
#     Epoch 4: cost=1.617, accuracy=0.172/0.100 (0/2 secs)
#     Epoch 4: cost=1.617, accuracy=0.169/0.080 (0/2 secs)
#     Epoch 5: cost=1.611, accuracy=0.179/0.210 (0/2 secs)
#     Epoch 5: cost=1.612, accuracy=0.161/0.100 (0/2 secs)
#     Epoch 5: cost=1.612, accuracy=0.172/0.150 (1/3 secs)
#     Epoch 5: cost=1.612, accuracy=0.169/0.150 (0/3 secs)
#     Epoch 6: cost=1.610, accuracy=0.184/0.230 (0/3 secs)
#     Epoch 6: cost=1.609, accuracy=0.206/0.260 (0/3 secs)
#     Epoch 6: cost=1.609, accuracy=0.211/0.170 (0/3 secs)
#     Epoch 6: cost=1.608, accuracy=0.218/0.120 (0/3 secs)
#     Epoch 7: cost=1.605, accuracy=0.248/0.250 (0/3 secs)
#     Epoch 7: cost=1.606, accuracy=0.227/0.250 (1/4 secs)
#     Epoch 7: cost=1.606, accuracy=0.229/0.270 (0/4 secs)
#     Epoch 7: cost=1.605, accuracy=0.232/0.210 (0/4 secs)
#     Epoch 8: cost=1.602, accuracy=0.251/0.240 (0/4 secs)
#     Epoch 8: cost=1.602, accuracy=0.233/0.180 (0/4 secs)
#     Epoch 8: cost=1.602, accuracy=0.237/0.250 (0/4 secs)
#     Epoch 8: cost=1.603, accuracy=0.234/0.260 (0/4 secs)
#     Epoch 9: cost=1.602, accuracy=0.226/0.170 (1/5 secs)
#     Epoch 9: cost=1.603, accuracy=0.232/0.250 (0/5 secs)
#     Epoch 9: cost=1.601, accuracy=0.244/0.220 (0/5 secs)
#     Epoch 9: cost=1.602, accuracy=0.244/0.200 (0/5 secs)
#     Epoch 10: cost=1.600, accuracy=0.244/0.270 (0/5 secs)
#     Epoch 10: cost=1.601, accuracy=0.241/0.240 (0/5 secs)
#     Epoch 10: cost=1.601, accuracy=0.235/0.200 (0/5 secs)
#     Epoch 10: cost=1.601, accuracy=0.243/0.320 (1/6 secs)
# Model flowers_model_1 train ended in 6 secs:
# Model flowers_model_1 test report: accuracy = 0.245, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [18,22,19,18,22] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [18,22,19,18,22] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [18,22,19,18,22] => 추정 dandelion : 정답 rose => X

# %%
fd = FlowersDataset()
fm = Mlp_Torch('flowers_model_1', fd, [40,30,10])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=40, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=40, out_features=30, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=30, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~\Anaconda3\envs\testtorch\lib\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#     871         try:
# --> 872             data = self._data_queue.get(timeout=timeout)
#     873             return (True, data)
#
# ~\Anaconda3\envs\testtorch\lib\multiprocessing\queues.py in get(self, block, timeout)
#     104                     if not self._poll(timeout):
# --> 105                         raise Empty
#     106                 elif not self._poll():
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-a15cbc14c177> in <module>
#       2 fm = Mlp_Torch('flowers_model_1', fd, [40,30,10])
#       3 fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
# ----> 4            , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
#
# <ipython-input-9-40f654676043> in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, num_workers)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3, num_workers=0):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report, num_workers)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# <ipython-input-9-7118317d755b> in train_torch(self, epoch_count, batch_size, learning_rate, report, num_workers)
#      29         accs = []
#      30
# ---> 31         for batch_idx, samples in enumerate(train_loader):
#      32
#      33             X_train, y_train = samples
#
# ~\Anaconda3\envs\testtorch\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\Anaconda3\envs\testtorch\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#    1066
#    1067             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1068             idx, data = self._get_data()
#    1069             self._tasks_outstanding -= 1
#    1070             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~\Anaconda3\envs\testtorch\lib\site-packages\torch\utils\data\dataloader.py in _get_data(self)
#    1032         else:
#    1033             while True:
# -> 1034                 success, data = self._try_get_data()
#    1035                 if success:
#    1036                     return data
#
# ~\Anaconda3\envs\testtorch\lib\site-packages\torch\utils\data\dataloader.py in _try_get_data(self, timeout)
#     883             if len(failed_workers) > 0:
#     884                 pids_str = ', '.join(str(w.pid) for w in failed_workers)
# --> 885                 raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#     886             if isinstance(e, queue.Empty):
#     887                 return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 23692, 32872) exited unexpectedly

# %%
# fd = FlowersDataset()?
fm = Mlp_Torch('flowers_model_1', fd, [12])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=30000, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0005
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8808/1026971213.py in <module>
#       2 fm = Mlp_Torch('flowers_model_1', fd, [12])
#       3 fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
# ----> 4            , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
#
# ~\AppData\Local\Temp/ipykernel_8808/4054610662.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, num_workers)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3, num_workers=0):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report, num_workers)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# ~\AppData\Local\Temp/ipykernel_8808/2384071044.py in train_torch(self, epoch_count, batch_size, learning_rate, report, num_workers)
#      46             acc = self.eval_accuracy(X_train, y_train, output)
#      47
# ---> 48             loss.backward()
#      49             optimizer.step()
#      50
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:
