# %%
BASE_DIR = '../'*3
# DATASET = BASE_DIR + 'code/UTIL/dataset/dataset.ipynb'
MLPMODEL = BASE_DIR +'code/MLP/MLP_MODEL/mlp_model.ipynb'
PREPRO = BASE_DIR + 'code/UTIL/dataset/abalone_prepro.ipynb'
# %run {DATASET}
# %run {MLPMODEL}
# %run {PREPRO}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
EPOCH = 10
BATCH_SIZE=20
NUM_WORKERS=0
LEARNING_RATE = 0.001

# %%
ad = AbaloneDataset()
print(ad,'\n')
am = Mlp_Torch('abalone_model', ad, [10,10])
am.exec_all(epoch_count=EPOCH, report=2,batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS)
# Out:
# abalone(regression, 3340+629+208)
#
# Model abalone_model train started
#
#
# 레이어는 아래와 같습니다.
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=10, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
#
#  !!!start!!!!
#
# Epoch    1/10 Batch_Data 20/3340 Cost: 86.201820 ACC :-0.037374
# Epoch    1/10 Batch_Data 40/3340 Cost: 110.169617 ACC :-0.042749
# Epoch    1/10 Batch_Data 60/3340 Cost: 106.199059 ACC :-0.041152
# Epoch    1/10 Batch_Data 80/3340 Cost: 100.566788 ACC :-0.043713
# Epoch    1/10 Batch_Data 100/3340 Cost: 98.890564 ACC :-0.043695
# Epoch    1/10 Batch_Data 120/3340 Cost: 111.015648 ACC :-0.043732
# Epoch    1/10 Batch_Data 140/3340 Cost: 109.698494 ACC :-0.041703
# Epoch    1/10 Batch_Data 160/3340 Cost: 109.598587 ACC :-0.044596
# Epoch    1/10 Batch_Data 180/3340 Cost: 114.393486 ACC :-0.044907
# ...

# %%
# 내일할것 -> 코드 정리 및 테스트, 평가, 배치사이즈 잘 나오게 하기 등등

# %%
# dataset.tr_xs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12748/861982889.py in <module>
# ----> 1 dataset.tr_xs
#
# NameError: name 'dataset' is not defined

# %%
# a=torch.tensor([1]).float()
# print(a)
# b=torch.tensor([2]).float()
# print(b)
# output=[a,b]

# torch.mean(torch.cat(output))
# Out:
# tensor([1.])
# tensor([2.])
# tensor(1.5000)

# %%
torch.no_grad
