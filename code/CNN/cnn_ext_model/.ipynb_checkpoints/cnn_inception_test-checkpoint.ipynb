# %%
BASE_DIR = '../'*3
DATASET_DIR = BASE_DIR+'code/util/dataset/dataset_dummy.ipynb'
EXTMODEL_DIR = BASE_DIR + 'code/CNN/cnn_ext_model/ext_model.ipynb'

# %%
# %run {DATASET_DIR}
# %run {EXTMODEL_DIR}
# Out:
# Using device: cuda
# GeForce GTX 1660 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.8 GB
# Using PyTorch version: 1.10.0

# %%
imagenet = DummyDataset('imagenet', 'select',[3,299,299],200)
# Out:
# 200

# %%
CnnExtModel.set_macro('v3_preproc', 
          ['serial',
              ['conv',{'ksize':3,'stride':2,'chn':32, 'padding':'VALID'}],
              ['conv',{'ksize':3,'chn':32, 'padding':'VALID'}],
              ['conv',{'ksize':3,'chn':64, 'padding':'SAME'}],
              ['max',{'ksize':3, 'stride':2, 'padding':'VALID'}],
              ['conv',{'ksize':1,'chn':80,'padding':'VALID'}],
              ['conv',{'ksize':3,'chn':192,'padding':'VALID'}],
              ['max',{'ksize':3, 'stride':2,'padding':'VALID'}]
          
          ]
                     )

# %%
CnnExtModel.set_macro('v3_inception1',
        ['parallel',
            ['conv',{'ksize':1, 'chn':64}],
         
            ['serial',
                ['conv',{'ksize':1,'chn':48}],
                ['conv',{'ksize':5, 'chn':64}]],
         
            ['serial',
                ['conv',{'ksize':1,'chn':64}],
                 ['conv',{'ksize':3,'chn':96}],
                 ['conv',{'ksize':3,'chn':96}]],
         
            ['serial',
                ['avg',{'ksize':3,'stride':1}],
                ['conv',{'ksize':1,'chn':'#chn'}]]
        
        ]
                    
                     )

# %%
CnnExtModel.set_macro('v3_resize1',
            ['parallel',
                ['conv',{'ksize':3,'stride':2,'chn':384}],
                ['serial',
                 ['conv',{'ksize':1,'chn':64}],
                 ['conv',{'ksize':3,'chn':94}],
                 ['conv',{'ksize':3,'stride':2,'chn':96}]],
                ['max',{'ksize':3,'stride':2}]
            
            ]                     
                    
                     )

# %%
CnnExtModel.set_macro('v3_inception2',
    ['parallel',
        ['conv', {'ksize':1, 'chn':192}],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':'#chn'}],
            ['conv', {'ksize':[1,7], 'chn':'#chn'}],
            ['conv', {'ksize':[7,1], 'chn':192}]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':'#chn'}],
            ['conv', {'ksize':[7,1], 'chn':'#chn'}],
            ['conv', {'ksize':[1,7], 'chn':'#chn'}],
            ['conv', {'ksize':[7,1], 'chn':'#chn'}],
            ['conv', {'ksize':[1,7], 'chn':192}]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':192}]]])

# %%
CnnExtModel.set_macro('v3_resize2',
    ['parallel',
        ['serial',
            ['conv', {'ksize':1, 'chn':192}],
            ['conv', {'ksize':3, 'stride':2, 'chn':320}]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':192}],
            ['conv', {'ksize':[1,7], 'chn':192}],
            ['conv', {'ksize':[7,1], 'chn':192}],
            ['conv', {'ksize':[3,3], 'stride':[2,2], 'chn':192}]],
        ['max', {'ksize':3, 'stride':2}]])

# %%
CnnExtModel.set_macro('v3_inception3',
    ['parallel',
        ['conv', {'ksize':1, 'chn':320}],
        ['serial',
            ['conv', {'ksize':[3,3], 'chn':384}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':384}],
                ['conv', {'ksize':[3,1], 'chn':384}]]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':448}],
            ['conv', {'ksize':[3,3], 'chn':384}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':384}],
                ['conv', {'ksize':[3,1], 'chn':384}]]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':192}]]])

# %%
CnnExtModel.set_macro('v3_postproc',
    ['serial',
        ['avg', {'stride':8}],
        ['dropout', {'keep_prob':0.7}]])

# %%
CnnExtModel.set_macro('inception_v3',
    ['serial',
        ['custom', {'name':'v3_preproc'}],
        ['custom', {'name':'v3_inception1', 'args':{'#chn':32}}],
        ['custom', {'name':'v3_inception1', 'args':{'#chn':64}}],
        ['custom', {'name':'v3_inception1', 'args':{'#chn':64}}],
        ['custom', {'name':'v3_resize1'}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':128}}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':160}}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':160}}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':192}}],
        ['custom', {'name':'v3_resize2'}],
        ['custom', {'name':'v3_inception3'}],
        ['custom', {'name':'v3_inception3'}],
        ['custom', {'name':'v3_postproc'}]])

# %%
inception_v3 = CnnExtModel('inception_v3', imagenet,
                   [['custom', {'name':'inception_v3'}]], dump_structure=True)
# Out:
# custom inception_v3
#   serial
#     custom v3_preproc
#       serial
#         1: conv, [3, 299, 299]=>[32, 148, 148]pm : 32x3x3x3+32 = 896
#         2: conv, [32, 148, 148]=>[32, 146, 146]pm : 32x32x3x3+32 = 9248
#         3: conv, [32, 146, 146]=>[64, 146, 146]pm : 64x32x3x3+64 = 18496
#         4: max, [64, 146, 146]=>[64, 72, 72]
#         5: conv, [64, 72, 72]=>[80, 72, 72]pm : 80x64x1x1+80 = 5200
#         6: conv, [80, 72, 72]=>[192, 70, 70]pm : 192x80x3x3+192 = 138432
#         7: max, [192, 70, 70]=>[192, 34, 34]
#     custom v3_inception1
#       parallel
#         8: conv, [192, 34, 34]=>[64, 34, 34]pm : 64x192x1x1+64 = 12352
#         serial
#           9: conv, [192, 34, 34]=>[48, 34, 34]pm : 48x192x1x1+48 = 9264
#           10: conv, [48, 34, 34]=>[64, 34, 34]pm : 64x48x5x5+64 = 76864
#         serial
#           11: conv, [192, 34, 34]=>[64, 34, 34]pm : 64x192x1x1+64 = 12352
#           12: conv, [64, 34, 34]=>[96, 34, 34]pm : 96x64x3x3+96 = 55392
#           13: conv, [96, 34, 34]=>[96, 34, 34]pm : 96x96x3x3+96 = 83040
#         serial
#           14: avg, [192, 34, 34]=>[192, 34, 34]
#           15: conv, [192, 34, 34]=>[32, 34, 34]pm : 32x192x1x1+32 = 6176
#     custom v3_inception1
#       parallel
#         16: conv, [256, 34, 34]=>[64, 34, 34]pm : 64x256x1x1+64 = 16448
#         serial
#           17: conv, [256, 34, 34]=>[48, 34, 34]pm : 48x256x1x1+48 = 12336
#           18: conv, [48, 34, 34]=>[64, 34, 34]pm : 64x48x5x5+64 = 76864
#         serial
#           19: conv, [256, 34, 34]=>[64, 34, 34]pm : 64x256x1x1+64 = 16448
#           20: conv, [64, 34, 34]=>[96, 34, 34]pm : 96x64x3x3+96 = 55392
#           21: conv, [96, 34, 34]=>[96, 34, 34]pm : 96x96x3x3+96 = 83040
#         serial
#           22: avg, [256, 34, 34]=>[256, 34, 34]
#           23: conv, [256, 34, 34]=>[64, 34, 34]pm : 64x256x1x1+64 = 16448
#     custom v3_inception1
#       parallel
#         24: conv, [288, 34, 34]=>[64, 34, 34]pm : 64x288x1x1+64 = 18496
#         serial
#           25: conv, [288, 34, 34]=>[48, 34, 34]pm : 48x288x1x1+48 = 13872
#           26: conv, [48, 34, 34]=>[64, 34, 34]pm : 64x48x5x5+64 = 76864
#         serial
#           27: conv, [288, 34, 34]=>[64, 34, 34]pm : 64x288x1x1+64 = 18496
#           28: conv, [64, 34, 34]=>[96, 34, 34]pm : 96x64x3x3+96 = 55392
#           29: conv, [96, 34, 34]=>[96, 34, 34]pm : 96x96x3x3+96 = 83040
#         serial
#           30: avg, [288, 34, 34]=>[288, 34, 34]
#           31: conv, [288, 34, 34]=>[64, 34, 34]pm : 64x288x1x1+64 = 18496
#     custom v3_resize1
#       parallel
#         32: conv, [288, 34, 34]=>[384, 17, 17]pm : 384x288x3x3+384 = 995712
#         serial
#           33: conv, [288, 34, 34]=>[64, 34, 34]pm : 64x288x1x1+64 = 18496
#           34: conv, [64, 34, 34]=>[94, 34, 34]pm : 94x64x3x3+94 = 54238
#           35: conv, [94, 34, 34]=>[96, 17, 17]pm : 96x94x3x3+96 = 81312
#         36: max, [288, 34, 34]=>[288, 17, 17]
#     custom v3_inception2
#       parallel
#         37: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#         serial
#           38: conv, [768, 17, 17]=>[128, 17, 17]pm : 128x768x1x1+128 = 98432
#           39: conv, [128, 17, 17]=>[128, 17, 17]pm : 128x128x1x7+128 = 114816
#           40: conv, [128, 17, 17]=>[192, 17, 17]pm : 192x128x7x1+192 = 172224
#         serial
#           41: conv, [768, 17, 17]=>[128, 17, 17]pm : 128x768x1x1+128 = 98432
#           42: conv, [128, 17, 17]=>[128, 17, 17]pm : 128x128x7x1+128 = 114816
#           43: conv, [128, 17, 17]=>[128, 17, 17]pm : 128x128x1x7+128 = 114816
#           44: conv, [128, 17, 17]=>[128, 17, 17]pm : 128x128x7x1+128 = 114816
#           45: conv, [128, 17, 17]=>[192, 17, 17]pm : 192x128x1x7+192 = 172224
#         serial
#           46: avg, [768, 17, 17]=>[768, 17, 17]
#           47: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#     custom v3_inception2
#       parallel
#         48: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#         serial
#           49: conv, [768, 17, 17]=>[160, 17, 17]pm : 160x768x1x1+160 = 123040
#           50: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x1x7+160 = 179360
#           51: conv, [160, 17, 17]=>[192, 17, 17]pm : 192x160x7x1+192 = 215232
#         serial
#           52: conv, [768, 17, 17]=>[160, 17, 17]pm : 160x768x1x1+160 = 123040
#           53: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x7x1+160 = 179360
#           54: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x1x7+160 = 179360
#           55: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x7x1+160 = 179360
#           56: conv, [160, 17, 17]=>[192, 17, 17]pm : 192x160x1x7+192 = 215232
#         serial
#           57: avg, [768, 17, 17]=>[768, 17, 17]
#           58: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#     custom v3_inception2
#       parallel
#         59: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#         serial
#           60: conv, [768, 17, 17]=>[160, 17, 17]pm : 160x768x1x1+160 = 123040
#           61: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x1x7+160 = 179360
#           62: conv, [160, 17, 17]=>[192, 17, 17]pm : 192x160x7x1+192 = 215232
#         serial
#           63: conv, [768, 17, 17]=>[160, 17, 17]pm : 160x768x1x1+160 = 123040
#           64: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x7x1+160 = 179360
#           65: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x1x7+160 = 179360
#           66: conv, [160, 17, 17]=>[160, 17, 17]pm : 160x160x7x1+160 = 179360
#           67: conv, [160, 17, 17]=>[192, 17, 17]pm : 192x160x1x7+192 = 215232
#         serial
#           68: avg, [768, 17, 17]=>[768, 17, 17]
#           69: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#     custom v3_inception2
#       parallel
#         70: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#         serial
#           71: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#           72: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x1x7+192 = 258240
#           73: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x7x1+192 = 258240
#         serial
#           74: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#           75: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x7x1+192 = 258240
#           76: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x1x7+192 = 258240
#           77: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x7x1+192 = 258240
#           78: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x1x7+192 = 258240
#         serial
#           79: avg, [768, 17, 17]=>[768, 17, 17]
#           80: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#     custom v3_resize2
#       parallel
#         serial
#           81: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#           82: conv, [192, 17, 17]=>[320, 8, 8]pm : 320x192x3x3+320 = 553280
#         serial
#           83: conv, [768, 17, 17]=>[192, 17, 17]pm : 192x768x1x1+192 = 147648
#           84: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x1x7+192 = 258240
#           85: conv, [192, 17, 17]=>[192, 17, 17]pm : 192x192x7x1+192 = 258240
#           86: conv, [192, 17, 17]=>[192, 8, 8]pm : 192x192x3x3+192 = 331968
#         87: max, [768, 17, 17]=>[768, 8, 8]
#     custom v3_inception3
#       parallel
#         88: conv, [1280, 8, 8]=>[320, 8, 8]pm : 320x1280x1x1+320 = 409920
#         serial
#           89: conv, [1280, 8, 8]=>[384, 8, 8]pm : 384x1280x3x3+384 = 4424064
#           parallel
#             90: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x1x3+384 = 442752
#             91: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x3x1+384 = 442752
#         serial
#           92: conv, [1280, 8, 8]=>[448, 8, 8]pm : 448x1280x1x1+448 = 573888
#           93: conv, [448, 8, 8]=>[384, 8, 8]pm : 384x448x3x3+384 = 1548672
#           parallel
#             94: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x1x3+384 = 442752
#             95: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x3x1+384 = 442752
#         serial
#           96: avg, [1280, 8, 8]=>[1280, 8, 8]
#           97: conv, [1280, 8, 8]=>[192, 8, 8]pm : 192x1280x1x1+192 = 245952
#     custom v3_inception3
#       parallel
#         98: conv, [2048, 8, 8]=>[320, 8, 8]pm : 320x2048x1x1+320 = 655680
#         serial
#           99: conv, [2048, 8, 8]=>[384, 8, 8]pm : 384x2048x3x3+384 = 7078272
#           parallel
#             100: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x1x3+384 = 442752
#             101: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x3x1+384 = 442752
#         serial
#           102: conv, [2048, 8, 8]=>[448, 8, 8]pm : 448x2048x1x1+448 = 917952
#           103: conv, [448, 8, 8]=>[384, 8, 8]pm : 384x448x3x3+384 = 1548672
#           parallel
#             104: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x1x3+384 = 442752
#             105: conv, [384, 8, 8]=>[384, 8, 8]pm : 384x384x3x1+384 = 442752
#         serial
#           106: avg, [2048, 8, 8]=>[2048, 8, 8]
#           107: conv, [2048, 8, 8]=>[192, 8, 8]pm : 192x2048x1x1+192 = 393408
#     custom v3_postproc
#       serial
#         108: avg, [2048, 8, 8]=>[2048, 1, 1]
#         109: dropout, [2048, 1, 1]=>[2048, 1, 1]
#
# 110: full, [2048, 1, 1]=>[200]pm :200x2048+200=409800
# Total parameter count : 32398886

# %%
import torch.nn as nn
nn.ReLU()
# Out:
# ReLU()

# %%
F_DATA_DIR = BASE_DIR+ 'code/util/dataset/flower_prepro.ipynb'

# %run {F_DATA_DIR}

fd = FlowersDataset([96,96], [3,96,96])
# Out:
# Using device: cuda
# GeForce GTX 1660 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.8 GB
# Using PyTorch version: 1.10.0

# %%
CnnExtModel.set_macro('flower_preproc',
    ['serial',
        ['conv', {'ksize':3, 'stride':2, 'chn':6, 'actions':'#act'}]])

CnnExtModel.set_macro('flower_inception1',
    ['parallel',
        ['conv', {'ksize':1, 'chn':4, 'actions':'#act'}],
        ['conv', {'ksize':3, 'chn':6, 'actions':'#act'}],
        ['serial',
            ['conv', {'ksize':3, 'chn':6, 'actions':'#act'}],
            ['conv', {'ksize':3, 'chn':6, 'actions':'#act'}]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':4, 'actions':'#act'}]]])

CnnExtModel.set_macro('flower_resize',
    ['parallel',
        ['conv', {'ksize':3, 'stride':2, 'chn':12, 'actions':'#act'}],
        ['serial',
            ['conv', {'ksize':3, 'chn':12, 'actions':'#act'}],
            ['conv', {'ksize':3, 'stride':2, 'chn':12, 'actions':'#act'}]],
        ['avg', {'ksize':3, 'stride':2}]])

CnnExtModel.set_macro('flower_inception2',
    ['parallel',
        ['conv', {'ksize':1, 'chn':8, 'actions':'#act'}],
        ['serial',
            ['conv', {'ksize':[3,3], 'chn':8, 'actions':'#act'}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':8, 'actions':'#act'}],
                ['conv', {'ksize':[3,1], 'chn':8, 'actions':'#act'}]]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':8, 'actions':'#act'}],
            ['conv', {'ksize':[3,3], 'chn':8, 'actions':'#act'}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':8, 'actions':'#act'}],
                ['conv', {'ksize':[3,1], 'chn':8, 'actions':'#act'}]]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':8, 'actions':'#act'}]]])

CnnExtModel.set_macro('flower_postproc',
    ['serial',
        ['avg', {'stride':6}],
        ['dropout', {'keep_prob':0.7}]])

# %%
CnnExtModel.set_macro('inception_flower',
    ['serial',
        ['custom', {'name':'flower_preproc', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception1', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_resize', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception1', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_resize', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception2', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_resize', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception2', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_postproc', 'args':{'#act':'#act'}}]])

# %%
conf_flower_LA = ['custom', {'name':'inception_flower', 'args':{'#act':'LA'}}]
model_flower_LA = CnnExtModel('model_flower_LA', fd, 
                         conf_flower_LA, dump_structure=True)
# Out:
# custom inception_flower
#   serial
#     custom flower_preproc
#       serial
#         1: conv, (3, 96, 96)=>[6, 48, 48]pm : 6x3x3x3+6 = 168
#     custom flower_inception1
#       parallel
#         2: conv, [6, 48, 48]=>[4, 48, 48]pm : 4x6x1x1+4 = 28
#         3: conv, [6, 48, 48]=>[6, 48, 48]pm : 6x6x3x3+6 = 330
#         serial
#           4: conv, [6, 48, 48]=>[6, 48, 48]pm : 6x6x3x3+6 = 330
#           5: conv, [6, 48, 48]=>[6, 48, 48]pm : 6x6x3x3+6 = 330
#         serial
#           6: avg, [6, 48, 48]=>[6, 48, 48]
#           7: conv, [6, 48, 48]=>[4, 48, 48]pm : 4x6x1x1+4 = 28
#     custom flower_resize
#       parallel
#         8: conv, [20, 48, 48]=>[12, 24, 24]pm : 12x20x3x3+12 = 2172
#         serial
#           9: conv, [20, 48, 48]=>[12, 48, 48]pm : 12x20x3x3+12 = 2172
#           10: conv, [12, 48, 48]=>[12, 24, 24]pm : 12x12x3x3+12 = 1308
#         11: avg, [20, 48, 48]=>[20, 24, 24]
#     custom flower_inception1
#       parallel
#         12: conv, [44, 24, 24]=>[4, 24, 24]pm : 4x44x1x1+4 = 180
#         13: conv, [44, 24, 24]=>[6, 24, 24]pm : 6x44x3x3+6 = 2382
#         serial
#           14: conv, [44, 24, 24]=>[6, 24, 24]pm : 6x44x3x3+6 = 2382
#           15: conv, [6, 24, 24]=>[6, 24, 24]pm : 6x6x3x3+6 = 330
#         serial
#           16: avg, [44, 24, 24]=>[44, 24, 24]
#           17: conv, [44, 24, 24]=>[4, 24, 24]pm : 4x44x1x1+4 = 180
#     custom flower_resize
#       parallel
#         18: conv, [20, 24, 24]=>[12, 12, 12]pm : 12x20x3x3+12 = 2172
#         serial
#           19: conv, [20, 24, 24]=>[12, 24, 24]pm : 12x20x3x3+12 = 2172
#           20: conv, [12, 24, 24]=>[12, 12, 12]pm : 12x12x3x3+12 = 1308
#         21: avg, [20, 24, 24]=>[20, 12, 12]
#     custom flower_inception2
#       parallel
#         22: conv, [44, 12, 12]=>[8, 12, 12]pm : 8x44x1x1+8 = 360
#         serial
#           23: conv, [44, 12, 12]=>[8, 12, 12]pm : 8x44x3x3+8 = 3176
#           parallel
#             24: conv, [8, 12, 12]=>[8, 12, 12]pm : 8x8x1x3+8 = 200
#             25: conv, [8, 12, 12]=>[8, 12, 12]pm : 8x8x3x1+8 = 200
#         serial
#           26: conv, [44, 12, 12]=>[8, 12, 12]pm : 8x44x1x1+8 = 360
#           27: conv, [8, 12, 12]=>[8, 12, 12]pm : 8x8x3x3+8 = 584
#           parallel
#             28: conv, [8, 12, 12]=>[8, 12, 12]pm : 8x8x1x3+8 = 200
#             29: conv, [8, 12, 12]=>[8, 12, 12]pm : 8x8x3x1+8 = 200
#         serial
#           30: avg, [44, 12, 12]=>[44, 12, 12]
#           31: conv, [44, 12, 12]=>[8, 12, 12]pm : 8x44x1x1+8 = 360
#     custom flower_resize
#       parallel
#         32: conv, [48, 12, 12]=>[12, 6, 6]pm : 12x48x3x3+12 = 5196
#         serial
#           33: conv, [48, 12, 12]=>[12, 12, 12]pm : 12x48x3x3+12 = 5196
#           34: conv, [12, 12, 12]=>[12, 6, 6]pm : 12x12x3x3+12 = 1308
#         35: avg, [48, 12, 12]=>[48, 6, 6]
#     custom flower_inception2
#       parallel
#         36: conv, [72, 6, 6]=>[8, 6, 6]pm : 8x72x1x1+8 = 584
#         serial
#           37: conv, [72, 6, 6]=>[8, 6, 6]pm : 8x72x3x3+8 = 5192
#           parallel
#             38: conv, [8, 6, 6]=>[8, 6, 6]pm : 8x8x1x3+8 = 200
#             39: conv, [8, 6, 6]=>[8, 6, 6]pm : 8x8x3x1+8 = 200
#         serial
#           40: conv, [72, 6, 6]=>[8, 6, 6]pm : 8x72x1x1+8 = 584
#           41: conv, [8, 6, 6]=>[8, 6, 6]pm : 8x8x3x3+8 = 584
#           parallel
#             42: conv, [8, 6, 6]=>[8, 6, 6]pm : 8x8x1x3+8 = 200
#             43: conv, [8, 6, 6]=>[8, 6, 6]pm : 8x8x3x1+8 = 200
#         serial
#           44: avg, [72, 6, 6]=>[72, 6, 6]
#           45: conv, [72, 6, 6]=>[8, 6, 6]pm : 8x72x1x1+8 = 584
#     custom flower_postproc
#       serial
#         46: avg, [48, 6, 6]=>[48, 1, 1]
#         47: dropout, [48, 1, 1]=>[48, 1, 1]
#
# 48: full, [48, 1, 1]=>[5]pm :5x48+5=245
# Total parameter count : 43885

# %%
EPOCH = 100
BATCH_SIZE=20
NUM_WORKERS=0
LEARNING_RATE = 0.0003

# %%
model_flower_LA.exec_all(epoch_count=EPOCH, report=80, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# model_flower_LA.exec_all(report=1)
# Out:
# Model model_flower_LA train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): P_Block(
#       (flower_preproc_1): Sequential(
#         (dict): ModuleDict(
#           (flower_preproc_1_1): Conv2d(3, 6, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (1): ReLU()
#     (2): P_Block(
#       (flower_inception1_2): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_2_1): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_2_2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_2_6): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (3): ReLU()
#     (4): P_Block(
#       (flower_resize_3): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_3_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (5): ReLU()
#     (6): P_Block(
#       (flower_inception1_4): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_4_1): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_4_2): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_3): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_4_6): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (7): ReLU()
#     (8): P_Block(
#       (flower_resize_5): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_5_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_5_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (9): ReLU()
#     (10): P_Block(
#       (flower_inception2_6): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_6_1): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_2): Conv2d(44, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_5): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_6_10): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (11): ReLU()
#     (12): P_Block(
#       (flower_resize_7): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_7_1): Conv2d(48, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_7_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (13): ReLU()
#     (14): P_Block(
#       (flower_inception2_8): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_8_1): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_2): Conv2d(72, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_5): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_8_10): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (15): ReLU()
#     (16): normal(
#       (layer): Sequential(
#         (0): AvgPool2d(kernel_size=(6, 6), stride=(6, 6), padding=(0, 0))
#         (1): Dropout2d(p=0.7, inplace=False)
#       )
#     )
#     (17): ReLU()
#     (18): Flatten(start_dim=1, end_dim=-1)
#     (19): Linear(in_features=48, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0003
#     weight_decay: 0
# )
#     Epoch 1: cost=1.609, accuracy=0.250/0.250 (2/2 secs)
#     Epoch 1: cost=1.607, accuracy=0.246/0.330 (1/3 secs)
#     Epoch 2: cost=1.606, accuracy=0.233/0.220 (2/5 secs)
#     Epoch 2: cost=1.605, accuracy=0.239/0.220 (2/7 secs)
#     Epoch 3: cost=1.591, accuracy=0.234/0.280 (2/9 secs)
#     Epoch 3: cost=1.591, accuracy=0.247/0.260 (2/11 secs)
#     Epoch 4: cost=1.572, accuracy=0.257/0.300 (2/13 secs)
#     Epoch 4: cost=1.560, accuracy=0.267/0.230 (2/15 secs)
#     Epoch 5: cost=1.530, accuracy=0.284/0.350 (2/17 secs)
#     Epoch 5: cost=1.518, accuracy=0.298/0.170 (1/18 secs)
#     Epoch 6: cost=1.488, accuracy=0.322/0.340 (2/20 secs)
#     Epoch 6: cost=1.490, accuracy=0.319/0.360 (2/22 secs)
#     Epoch 7: cost=1.465, accuracy=0.321/0.420 (2/24 secs)
#     Epoch 7: cost=1.474, accuracy=0.316/0.360 (2/26 secs)
#     Epoch 8: cost=1.440, accuracy=0.334/0.420 (2/28 secs)
#     Epoch 8: cost=1.457, accuracy=0.320/0.340 (1/29 secs)
#     Epoch 9: cost=1.439, accuracy=0.324/0.280 (2/31 secs)
#     Epoch 9: cost=1.454, accuracy=0.321/0.340 (2/33 secs)
#     Epoch 10: cost=1.433, accuracy=0.331/0.410 (2/35 secs)
#     Epoch 10: cost=1.444, accuracy=0.327/0.390 (2/37 secs)
#     Epoch 11: cost=1.431, accuracy=0.325/0.370 (2/39 secs)
#     Epoch 11: cost=1.436, accuracy=0.338/0.390 (1/40 secs)
#     Epoch 12: cost=1.431, accuracy=0.338/0.400 (2/42 secs)
#     Epoch 12: cost=1.428, accuracy=0.345/0.350 (2/44 secs)
#     Epoch 13: cost=1.430, accuracy=0.335/0.360 (2/46 secs)
#     Epoch 13: cost=1.428, accuracy=0.337/0.310 (2/48 secs)
#     Epoch 14: cost=1.423, accuracy=0.358/0.320 (2/50 secs)
#     Epoch 14: cost=1.407, accuracy=0.357/0.340 (1/51 secs)
#     Epoch 15: cost=1.422, accuracy=0.362/0.330 (2/53 secs)
#     Epoch 15: cost=1.411, accuracy=0.361/0.320 (2/55 secs)
#     Epoch 16: cost=1.376, accuracy=0.372/0.320 (2/57 secs)
#     Epoch 16: cost=1.387, accuracy=0.361/0.330 (2/59 secs)
#     Epoch 17: cost=1.388, accuracy=0.362/0.390 (2/61 secs)
#     Epoch 17: cost=1.383, accuracy=0.362/0.400 (1/62 secs)
#     Epoch 18: cost=1.384, accuracy=0.376/0.320 (2/64 secs)
#     Epoch 18: cost=1.384, accuracy=0.375/0.410 (2/66 secs)
#     Epoch 19: cost=1.401, accuracy=0.378/0.480 (2/68 secs)
#     Epoch 19: cost=1.392, accuracy=0.383/0.350 (2/70 secs)
#     Epoch 20: cost=1.376, accuracy=0.377/0.390 (2/72 secs)
#     Epoch 20: cost=1.382, accuracy=0.365/0.400 (1/73 secs)
#     Epoch 21: cost=1.370, accuracy=0.372/0.370 (2/75 secs)
#     Epoch 21: cost=1.376, accuracy=0.377/0.360 (2/77 secs)
#     Epoch 22: cost=1.364, accuracy=0.387/0.360 (2/79 secs)
#     Epoch 22: cost=1.363, accuracy=0.382/0.360 (2/81 secs)
#     Epoch 23: cost=1.370, accuracy=0.379/0.420 (2/83 secs)
#     Epoch 23: cost=1.376, accuracy=0.374/0.380 (1/84 secs)
#     Epoch 24: cost=1.364, accuracy=0.384/0.280 (2/86 secs)
#     Epoch 24: cost=1.373, accuracy=0.377/0.360 (2/88 secs)
#     Epoch 25: cost=1.372, accuracy=0.381/0.370 (2/90 secs)
#     Epoch 25: cost=1.370, accuracy=0.389/0.360 (2/92 secs)
#     Epoch 26: cost=1.356, accuracy=0.394/0.410 (2/94 secs)
#     Epoch 26: cost=1.364, accuracy=0.384/0.370 (1/95 secs)
#     Epoch 27: cost=1.386, accuracy=0.376/0.360 (2/97 secs)
#     Epoch 27: cost=1.358, accuracy=0.389/0.290 (2/99 secs)
#     Epoch 28: cost=1.369, accuracy=0.387/0.390 (2/101 secs)
#     Epoch 28: cost=1.357, accuracy=0.394/0.350 (2/103 secs)
#     Epoch 29: cost=1.355, accuracy=0.399/0.430 (2/105 secs)
#     Epoch 29: cost=1.344, accuracy=0.399/0.400 (2/107 secs)
#     Epoch 30: cost=1.359, accuracy=0.406/0.330 (2/109 secs)
#     Epoch 30: cost=1.339, accuracy=0.411/0.390 (1/110 secs)
#     Epoch 31: cost=1.315, accuracy=0.415/0.380 (2/112 secs)
#     Epoch 31: cost=1.345, accuracy=0.412/0.400 (2/114 secs)
#     Epoch 32: cost=1.316, accuracy=0.420/0.400 (2/116 secs)
#     Epoch 32: cost=1.336, accuracy=0.406/0.410 (2/118 secs)
#     Epoch 33: cost=1.311, accuracy=0.417/0.420 (2/120 secs)
#     Epoch 33: cost=1.322, accuracy=0.416/0.310 (2/122 secs)
#     Epoch 34: cost=1.329, accuracy=0.420/0.460 (2/124 secs)
#     Epoch 34: cost=1.319, accuracy=0.426/0.380 (1/125 secs)
#     Epoch 35: cost=1.304, accuracy=0.434/0.410 (2/127 secs)
#     Epoch 35: cost=1.285, accuracy=0.441/0.490 (2/129 secs)
#     Epoch 36: cost=1.282, accuracy=0.436/0.440 (2/131 secs)
#     Epoch 36: cost=1.273, accuracy=0.444/0.500 (2/133 secs)
#     Epoch 37: cost=1.245, accuracy=0.446/0.440 (2/135 secs)
#     Epoch 37: cost=1.243, accuracy=0.461/0.450 (1/136 secs)
#     Epoch 38: cost=1.213, accuracy=0.473/0.460 (2/138 secs)
#     Epoch 38: cost=1.233, accuracy=0.463/0.430 (2/140 secs)
#     Epoch 39: cost=1.221, accuracy=0.447/0.430 (2/142 secs)
#     Epoch 39: cost=1.221, accuracy=0.466/0.430 (2/144 secs)
#     Epoch 40: cost=1.191, accuracy=0.473/0.450 (2/146 secs)
#     Epoch 40: cost=1.204, accuracy=0.479/0.410 (1/147 secs)
#     Epoch 41: cost=1.197, accuracy=0.474/0.430 (2/149 secs)
#     Epoch 41: cost=1.202, accuracy=0.473/0.390 (2/151 secs)
#     Epoch 42: cost=1.183, accuracy=0.482/0.460 (2/153 secs)
#     Epoch 42: cost=1.176, accuracy=0.495/0.430 (2/155 secs)
#     Epoch 43: cost=1.178, accuracy=0.483/0.440 (2/157 secs)
#     Epoch 43: cost=1.193, accuracy=0.479/0.440 (1/158 secs)
#     Epoch 44: cost=1.164, accuracy=0.499/0.460 (2/160 secs)
#     Epoch 44: cost=1.170, accuracy=0.494/0.530 (2/162 secs)
#     Epoch 45: cost=1.188, accuracy=0.493/0.450 (2/164 secs)
#     Epoch 45: cost=1.164, accuracy=0.496/0.440 (2/166 secs)
#     Epoch 46: cost=1.160, accuracy=0.508/0.430 (2/168 secs)
#     Epoch 46: cost=1.160, accuracy=0.507/0.460 (1/169 secs)
#     Epoch 47: cost=1.131, accuracy=0.513/0.430 (2/171 secs)
#     Epoch 47: cost=1.148, accuracy=0.516/0.500 (2/173 secs)
#     Epoch 48: cost=1.148, accuracy=0.520/0.440 (2/175 secs)
#     Epoch 48: cost=1.148, accuracy=0.512/0.510 (2/177 secs)
#     Epoch 49: cost=1.140, accuracy=0.507/0.420 (2/179 secs)
#     Epoch 49: cost=1.132, accuracy=0.522/0.530 (1/180 secs)
#     Epoch 50: cost=1.105, accuracy=0.532/0.460 (2/182 secs)
#     Epoch 50: cost=1.118, accuracy=0.525/0.480 (2/184 secs)
#     Epoch 51: cost=1.107, accuracy=0.541/0.500 (2/186 secs)
#     Epoch 51: cost=1.121, accuracy=0.532/0.570 (2/188 secs)
#     Epoch 52: cost=1.102, accuracy=0.539/0.460 (2/190 secs)
#     Epoch 52: cost=1.123, accuracy=0.532/0.520 (1/191 secs)
#     Epoch 53: cost=1.105, accuracy=0.539/0.490 (2/193 secs)
#     Epoch 53: cost=1.125, accuracy=0.534/0.410 (2/195 secs)
#     Epoch 54: cost=1.115, accuracy=0.528/0.490 (2/197 secs)
#     Epoch 54: cost=1.114, accuracy=0.533/0.470 (2/199 secs)
#     Epoch 55: cost=1.103, accuracy=0.536/0.490 (2/201 secs)
#     Epoch 55: cost=1.110, accuracy=0.529/0.490 (1/202 secs)
#     Epoch 56: cost=1.103, accuracy=0.543/0.420 (3/205 secs)
#     Epoch 56: cost=1.106, accuracy=0.537/0.470 (1/206 secs)
#     Epoch 57: cost=1.075, accuracy=0.567/0.460 (2/208 secs)
#     Epoch 57: cost=1.087, accuracy=0.553/0.530 (2/210 secs)
#     Epoch 58: cost=1.108, accuracy=0.540/0.450 (2/212 secs)
#     Epoch 58: cost=1.103, accuracy=0.553/0.480 (2/214 secs)
#     Epoch 59: cost=1.109, accuracy=0.549/0.500 (2/216 secs)
#     Epoch 59: cost=1.104, accuracy=0.559/0.480 (1/217 secs)
#     Epoch 60: cost=1.112, accuracy=0.550/0.510 (2/219 secs)
#     Epoch 60: cost=1.094, accuracy=0.553/0.540 (2/221 secs)
#     Epoch 61: cost=1.081, accuracy=0.549/0.550 (2/223 secs)
#     Epoch 61: cost=1.080, accuracy=0.555/0.500 (2/225 secs)
#     Epoch 62: cost=1.049, accuracy=0.584/0.540 (2/227 secs)
#     Epoch 62: cost=1.068, accuracy=0.566/0.490 (1/228 secs)
#     Epoch 63: cost=1.040, accuracy=0.579/0.510 (2/230 secs)
#     Epoch 63: cost=1.061, accuracy=0.572/0.470 (2/232 secs)
#     Epoch 64: cost=1.069, accuracy=0.571/0.440 (2/234 secs)
#     Epoch 64: cost=1.070, accuracy=0.566/0.500 (2/236 secs)
#     Epoch 65: cost=1.034, accuracy=0.591/0.510 (2/238 secs)
#     Epoch 65: cost=1.054, accuracy=0.574/0.570 (1/239 secs)
#     Epoch 66: cost=1.059, accuracy=0.557/0.480 (2/241 secs)
#     Epoch 66: cost=1.061, accuracy=0.570/0.370 (2/243 secs)
#     Epoch 67: cost=1.063, accuracy=0.577/0.560 (2/245 secs)
#     Epoch 67: cost=1.051, accuracy=0.581/0.510 (2/247 secs)
#     Epoch 68: cost=1.029, accuracy=0.593/0.490 (2/249 secs)
#     Epoch 68: cost=1.061, accuracy=0.570/0.480 (1/250 secs)
#     Epoch 69: cost=1.046, accuracy=0.580/0.460 (2/252 secs)
#     Epoch 69: cost=1.049, accuracy=0.577/0.500 (2/254 secs)
#     Epoch 70: cost=1.072, accuracy=0.556/0.460 (2/256 secs)
#     Epoch 70: cost=1.051, accuracy=0.573/0.510 (3/259 secs)
#     Epoch 71: cost=1.038, accuracy=0.584/0.470 (3/262 secs)
#     Epoch 71: cost=1.027, accuracy=0.579/0.520 (2/264 secs)
#     Epoch 72: cost=1.050, accuracy=0.588/0.540 (2/266 secs)
#     Epoch 72: cost=1.041, accuracy=0.584/0.510 (2/268 secs)
#     Epoch 73: cost=0.996, accuracy=0.601/0.490 (3/271 secs)
#     Epoch 73: cost=1.012, accuracy=0.595/0.560 (2/273 secs)
#     Epoch 74: cost=1.038, accuracy=0.602/0.470 (2/275 secs)
#     Epoch 74: cost=1.031, accuracy=0.593/0.480 (2/277 secs)
#     Epoch 75: cost=1.033, accuracy=0.584/0.530 (2/279 secs)
#     Epoch 75: cost=1.036, accuracy=0.580/0.430 (2/281 secs)
#     Epoch 76: cost=1.036, accuracy=0.574/0.530 (2/283 secs)
#     Epoch 76: cost=1.010, accuracy=0.582/0.550 (2/285 secs)
#     Epoch 77: cost=1.026, accuracy=0.575/0.540 (2/287 secs)
#     Epoch 77: cost=1.025, accuracy=0.590/0.520 (2/289 secs)
#     Epoch 78: cost=1.038, accuracy=0.571/0.540 (3/292 secs)
#     Epoch 78: cost=1.019, accuracy=0.589/0.510 (2/294 secs)
#     Epoch 79: cost=1.003, accuracy=0.613/0.540 (2/296 secs)
#     Epoch 79: cost=1.022, accuracy=0.597/0.490 (2/298 secs)
#     Epoch 80: cost=1.005, accuracy=0.602/0.530 (2/300 secs)
#     Epoch 80: cost=1.009, accuracy=0.598/0.570 (2/302 secs)
#     Epoch 81: cost=1.020, accuracy=0.589/0.470 (2/304 secs)
#     Epoch 81: cost=1.020, accuracy=0.594/0.490 (2/306 secs)
#     Epoch 82: cost=0.973, accuracy=0.608/0.550 (4/310 secs)
#     Epoch 82: cost=0.993, accuracy=0.600/0.550 (2/312 secs)
#     Epoch 83: cost=1.013, accuracy=0.599/0.570 (3/315 secs)
#     Epoch 83: cost=1.003, accuracy=0.596/0.520 (2/317 secs)
#     Epoch 84: cost=0.947, accuracy=0.617/0.560 (2/319 secs)
#     Epoch 84: cost=0.985, accuracy=0.601/0.460 (2/321 secs)
#     Epoch 85: cost=0.974, accuracy=0.609/0.400 (2/323 secs)
#     Epoch 85: cost=0.990, accuracy=0.603/0.550 (2/325 secs)
#     Epoch 86: cost=0.978, accuracy=0.613/0.430 (2/327 secs)
#     Epoch 86: cost=0.987, accuracy=0.605/0.450 (2/329 secs)
#     Epoch 87: cost=1.003, accuracy=0.606/0.540 (3/332 secs)
#     Epoch 87: cost=0.992, accuracy=0.607/0.550 (2/334 secs)
#     Epoch 88: cost=0.955, accuracy=0.619/0.460 (2/336 secs)
#     Epoch 88: cost=0.983, accuracy=0.606/0.560 (2/338 secs)
#     Epoch 89: cost=0.984, accuracy=0.602/0.510 (2/340 secs)
#     Epoch 89: cost=0.976, accuracy=0.613/0.500 (2/342 secs)
#     Epoch 90: cost=0.970, accuracy=0.618/0.470 (2/344 secs)
#     Epoch 90: cost=0.972, accuracy=0.616/0.500 (2/346 secs)
#     Epoch 91: cost=0.981, accuracy=0.618/0.500 (2/348 secs)
#     Epoch 91: cost=0.981, accuracy=0.616/0.490 (2/350 secs)
#     Epoch 92: cost=0.975, accuracy=0.624/0.470 (2/352 secs)
#     Epoch 92: cost=0.981, accuracy=0.621/0.560 (2/354 secs)
#     Epoch 93: cost=0.961, accuracy=0.619/0.550 (2/356 secs)
#     Epoch 93: cost=0.962, accuracy=0.615/0.490 (2/358 secs)
#     Epoch 94: cost=0.944, accuracy=0.627/0.550 (2/360 secs)
#     Epoch 94: cost=0.948, accuracy=0.623/0.520 (2/362 secs)
#     Epoch 95: cost=0.948, accuracy=0.624/0.510 (2/364 secs)
#     Epoch 95: cost=0.961, accuracy=0.621/0.520 (2/366 secs)
#     Epoch 96: cost=0.950, accuracy=0.616/0.530 (2/368 secs)
#     Epoch 96: cost=0.944, accuracy=0.617/0.500 (2/370 secs)
#     Epoch 97: cost=0.965, accuracy=0.610/0.540 (2/372 secs)
#     Epoch 97: cost=0.953, accuracy=0.624/0.490 (2/374 secs)
#     Epoch 98: cost=0.947, accuracy=0.619/0.520 (2/376 secs)
#     Epoch 98: cost=0.943, accuracy=0.624/0.530 (2/378 secs)
#     Epoch 99: cost=0.935, accuracy=0.636/0.560 (2/380 secs)
#     Epoch 99: cost=0.944, accuracy=0.631/0.500 (2/382 secs)
#     Epoch 100: cost=0.981, accuracy=0.607/0.460 (2/384 secs)
#     Epoch 100: cost=0.950, accuracy=0.620/0.580 (2/386 secs)
# Model model_flower_LA train ended in 386 secs:
# <bound method Module.parameters of Net(
#   (layer1): Sequential(
#     (0): P_Block(
#       (flower_preproc_1): Sequential(
#         (dict): ModuleDict(
#           (flower_preproc_1_1): Conv2d(3, 6, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (1): ReLU()
#     (2): P_Block(
#       (flower_inception1_2): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_2_1): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_2_2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_2_6): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (3): ReLU()
#     (4): P_Block(
#       (flower_resize_3): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_3_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (5): ReLU()
#     (6): P_Block(
#       (flower_inception1_4): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_4_1): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_4_2): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_3): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_4_6): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (7): ReLU()
#     (8): P_Block(
#       (flower_resize_5): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_5_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_5_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (9): ReLU()
#     (10): P_Block(
#       (flower_inception2_6): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_6_1): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_2): Conv2d(44, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_5): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_6_10): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (11): ReLU()
#     (12): P_Block(
#       (flower_resize_7): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_7_1): Conv2d(48, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_7_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (13): ReLU()
#     (14): P_Block(
#       (flower_inception2_8): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_8_1): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_2): Conv2d(72, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_5): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_8_10): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (15): ReLU()
#     (16): normal(
#       (layer): Sequential(
#         (0): AvgPool2d(kernel_size=(6, 6), stride=(6, 6), padding=(0, 0))
#         (1): Dropout2d(p=0.7, inplace=False)
#       )
#     )
#     (17): ReLU()
#     (18): Flatten(start_dim=1, end_dim=-1)
#     (19): Linear(in_features=48, out_features=5, bias=True)
#   )
# )>
# Model model_flower_LA test report: accuracy = 0.557, (0 secs)
#
# Model model_flower_LA Visualization
# 추정확률분포 [36,30,18, 2,14] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [ 0, 0,58, 0,41] => 추정 rose : 정답 daisy => X
# 추정확률분포 [ 7,90, 1, 0, 2] => 추정 dandelion : 정답 dandelion => O

# %%
# F_DATA_DIR = BASE_DIR+ 'code/util/dataset/flower_prepro.ipynb'

# %run {F_DATA_DIR}

# fd = FlowersDataset([96,96], [3,96,96])
