# %%
BASE_DIR = '../'*3
DATASET_DIR = BASE_DIR+'code/util/dataset/dataset_dummy.ipynb'
EXTMODEL_DIR = BASE_DIR + 'code/CNN/cnn_ext_model/ext_model.ipynb'

# %%
# %run {DATASET_DIR}
# %run {EXTMODEL_DIR}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
imagenet = DummyDataset('imagenet', 'select',[3,299,299],200)
# Out:
# 200

# %%
CnnExtModel.set_macro('v3_preproc', 
          ['serial',
              ['conv',{'ksize':3,'stride':2,'chn':32, 'padding':'VALID'}],
              ['conv',{'ksize':3,'chn':32, 'padding':'VALID'}],
              ['conv',{'ksize':3,'chn':64, 'padding':'SAME'}],
              ['max',{'ksize':3, 'stride':2, 'padding':'VALID'}],
              ['conv',{'ksize':1,'chn':80,'padding':'VALID'}],
              ['conv',{'ksize':3,'chn':192,'padding':'VALID'}],
              ['max',{'ksize':3, 'stride':2,'padding':'VALID'}]
          
          ]
                     )

# %%
CnnExtModel.set_macro('v3_inception1',
        ['parallel',
            ['conv',{'ksize':1, 'chn':64}],
         
            ['serial',
                ['conv',{'ksize':1,'chn':48}],
                ['conv',{'ksize':5, 'chn':64}]],
         
            ['serial',
                ['conv',{'ksize':1,'chn':64}],
                 ['conv',{'ksize':3,'chn':96}],
                 ['conv',{'ksize':3,'chn':96}]],
         
            ['serial',
                ['avg',{'ksize':3,'stride':1}],
                ['conv',{'ksize':1,'chn':'#chn'}]]
        
        ]
                    
                     )

# %%
CnnExtModel.set_macro('v3_resize1',
            ['parallel',
                ['conv',{'ksize':3,'stride':2,'chn':384}],
                ['serial',
                 ['conv',{'ksize':1,'chn':64}],
                 ['conv',{'ksize':3,'chn':94}],
                 ['conv',{'ksize':3,'stride':2,'chn':96}]],
                ['max',{'ksize':3,'stride':2}]
            
            ]                     
                    
                     )

# %%
CnnExtModel.set_macro('v3_inception2',
    ['parallel',
        ['conv', {'ksize':1, 'chn':192}],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':'#chn'}],
            ['conv', {'ksize':[1,7], 'chn':'#chn'}],
            ['conv', {'ksize':[7,1], 'chn':192}]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':'#chn'}],
            ['conv', {'ksize':[7,1], 'chn':'#chn'}],
            ['conv', {'ksize':[1,7], 'chn':'#chn'}],
            ['conv', {'ksize':[7,1], 'chn':'#chn'}],
            ['conv', {'ksize':[1,7], 'chn':192}]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':192}]]])

# %%
CnnExtModel.set_macro('v3_resize2',
    ['parallel',
        ['serial',
            ['conv', {'ksize':1, 'chn':192}],
            ['conv', {'ksize':3, 'stride':2, 'chn':320}]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':192}],
            ['conv', {'ksize':[1,7], 'chn':192}],
            ['conv', {'ksize':[7,1], 'chn':192}],
            ['conv', {'ksize':[3,3], 'stride':[2,2], 'chn':192}]],
        ['max', {'ksize':3, 'stride':2}]])

# %%
CnnExtModel.set_macro('v3_inception3',
    ['parallel',
        ['conv', {'ksize':1, 'chn':320}],
        ['serial',
            ['conv', {'ksize':[3,3], 'chn':384}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':384}],
                ['conv', {'ksize':[3,1], 'chn':384}]]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':448}],
            ['conv', {'ksize':[3,3], 'chn':384}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':384}],
                ['conv', {'ksize':[3,1], 'chn':384}]]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':192}]]])

# %%
CnnExtModel.set_macro('v3_postproc',
    ['serial',
        ['avg', {'stride':8}],
        ['dropout', {'keep_prob':0.7}]])

# %%
CnnExtModel.set_macro('inception_v3',
    ['serial',
        ['custom', {'name':'v3_preproc'}],
        ['custom', {'name':'v3_inception1', 'args':{'#chn':32}}],
        ['custom', {'name':'v3_inception1', 'args':{'#chn':64}}],
        ['custom', {'name':'v3_inception1', 'args':{'#chn':64}}],
        ['custom', {'name':'v3_resize1'}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':128}}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':160}}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':160}}],
        ['custom', {'name':'v3_inception2', 'args':{'#chn':192}}],
        ['custom', {'name':'v3_resize2'}],
        ['custom', {'name':'v3_inception3'}],
        ['custom', {'name':'v3_inception3'}],
        ['custom', {'name':'v3_postproc'}]])

# %%
inception_v3 = CnnExtModel('inception_v3', imagenet,
                   [['custom', {'name':'inception_v3'}]], dump_structure=False)
# Out:
# check
# v3_preproc_1
# endendendend
# check
# v3_inception1_2
# endendendend
# check
# v3_inception1_3
# endendendend
# check
# v3_inception1_4
# endendendend
# check
# v3_resize1_5
# endendendend
# check
# v3_inception2_6
# endendendend
# check
# v3_inception2_7
# endendendend
# check
# v3_inception2_8
# endendendend
# check
# v3_inception2_9
# endendendend
# check
# v3_resize2_10
# endendendend
# check
# v3_inception3_11
# endendendend
# check
# v3_inception3_12
# endendendend
# check
# v3_postproc_13
# endendendend
# [Linear(in_features=2048, out_features=200, bias=True)]

# %%
a=['serial', ['custom', {'name': 'v3_preproc'}], ['custom', {'name': 'v3_inception1', 'args': {'#chn': 32}}], ['custom', {'name': 'v3_inception1', 'args': {'#chn': 64}}], ['custom', {'name': 'v3_inception1', 'args': {'#chn': 64}}], ['custom', {'name': 'v3_resize1'}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 128}}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 160}}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 160}}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 192}}], ['custom', {'name': 'v3_resize2'}], ['custom', {'name': 'v3_inception3'}], ['custom', {'name': 'v3_inception3'}], ['custom', {'name': 'v3_postproc'}]]
  serial
['serial', ['custom', {'name': 'v3_preproc'}], ['custom', {'name': 'v3_inception1', 'args': {'#chn': 32}}], ['custom', {'name': 'v3_inception1', 'args': {'#chn': 64}}], ['custom', {'name': 'v3_inception1', 'args': {'#chn': 64}}], ['custom', {'name': 'v3_resize1'}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 128}}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 160}}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 160}}], ['custom', {'name': 'v3_inception2', 'args': {'#chn': 192}}], ['custom', {'name': 'v3_resize2'}], ['custom', {'name': 'v3_inception3'}], ['custom', {'name': 'v3_inception3'}], ['custom', {'name': 'v3_postproc'}]]
# Out:
#   File "C:\Users\oh\AppData\Local\Temp/ipykernel_13156/2898639130.py", line 2
#     serial
#     ^
# IndentationError: unexpected indent

# %%
inception_v3.net
# Out:
# [normal(
#    (layer): Sequential(
#      (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=valid)
#      (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#      (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#      (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      (4): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), padding=valid)
#      (5): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#      (6): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#    )
#  ),
#  P_Block(
#    (v3_inception1_2): Sequential(
#      (dict): ModuleDict(
#        (v3_inception1_2_1): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_2_2): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_2_3): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#        (v3_inception1_2_4): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_2_5): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception1_2_6): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception1_2_7): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception1_2_8): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception1_3): Sequential(
#      (dict): ModuleDict(
#        (v3_inception1_3_1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_3_2): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_3_3): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#        (v3_inception1_3_4): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_3_5): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception1_3_6): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception1_3_7): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception1_3_8): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception1_4): Sequential(
#      (dict): ModuleDict(
#        (v3_inception1_4_1): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_4_2): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_4_3): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#        (v3_inception1_4_4): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception1_4_5): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception1_4_6): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception1_4_7): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception1_4_8): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_resize1_5): Sequential(
#      (dict): ModuleDict(
#        (v3_resize1_5_1): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (v3_resize1_5_2): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_resize1_5_3): Conv2d(64, 94, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_resize1_5_4): Conv2d(94, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (v3_resize1_5_5): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception2_6): Sequential(
#      (dict): ModuleDict(
#        (v3_inception2_6_1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_6_2): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_6_3): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_6_4): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_6_5): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_6_6): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_6_7): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_6_8): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_6_9): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_6_10): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception2_6_11): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception2_7): Sequential(
#      (dict): ModuleDict(
#        (v3_inception2_7_1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_7_2): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_7_3): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_7_4): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_7_5): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_7_6): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_7_7): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_7_8): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_7_9): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_7_10): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception2_7_11): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception2_8): Sequential(
#      (dict): ModuleDict(
#        (v3_inception2_8_1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_8_2): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_8_3): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_8_4): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_8_5): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_8_6): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_8_7): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_8_8): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_8_9): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_8_10): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception2_8_11): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception2_9): Sequential(
#      (dict): ModuleDict(
#        (v3_inception2_9_1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_9_2): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_9_3): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_9_4): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_9_5): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception2_9_6): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_9_7): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_9_8): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_inception2_9_9): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_inception2_9_10): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception2_9_11): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_resize2_10): Sequential(
#      (dict): ModuleDict(
#        (v3_resize2_10_1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_resize2_10_2): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2))
#        (v3_resize2_10_3): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_resize2_10_4): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)
#        (v3_resize2_10_5): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)
#        (v3_resize2_10_6): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2))
#        (v3_resize2_10_7): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception3_11): Sequential(
#      (dict): ModuleDict(
#        (v3_inception3_11_1): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception3_11_2): Conv2d(1280, 384, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception3_11_3): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (v3_inception3_11_4): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (v3_inception3_11_5): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception3_11_6): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception3_11_7): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (v3_inception3_11_8): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (v3_inception3_11_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception3_11_10): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (v3_inception3_12): Sequential(
#      (dict): ModuleDict(
#        (v3_inception3_12_1): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception3_12_2): Conv2d(2048, 384, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception3_12_3): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (v3_inception3_12_4): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (v3_inception3_12_5): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (v3_inception3_12_6): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (v3_inception3_12_7): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (v3_inception3_12_8): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (v3_inception3_12_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (v3_inception3_12_10): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  normal(
#    (layer): Sequential(
#      (0): AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=(0, 0))
#      (1): Dropout2d(p=0.7, inplace=False)
#    )
#  )]

# %%
inception_v3.modules
# Out:
# {'v3_preproc_1': [Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=valid),
#   Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=valid),
#   Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same),
#   MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False),
#   Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), padding=valid),
#   Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), padding=valid),
#   MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)],
#  'v3_inception1_2': [Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)],
#   [Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_inception1_3': [Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)],
#   [Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_inception1_4': [Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)],
#   [Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_resize1_5': [Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)),
#   [Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(64, 94, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    Conv2d(94, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))],
#   MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)],
#  'v3_inception2_6': [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)],
#   [Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_inception2_7': [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)],
#   [Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_inception2_8': [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)],
#   [Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_inception2_9': [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same)],
#   [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same)],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_resize2_10': [[Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2))],
#   [Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=same),
#    Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2))],
#   MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)],
#  'v3_inception3_11': [Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(1280, 384, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    [Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same),
#     Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)]],
#   [Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    [Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same),
#     Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)]],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_inception3_12': [Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), padding=same),
#   [Conv2d(2048, 384, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    [Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same),
#     Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)]],
#   [Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), padding=same),
#    Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=same),
#    [Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=same),
#     Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=same)]],
#   [AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
#    Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), padding=same)]],
#  'v3_postproc_13': [AvgPool2d(kernel_size=(8, 8), stride=(8, 8), padding=(0, 0)),
#   Dropout2d(p=0.7, inplace=False)]}

# %%
print(x)

# %%
# F_DATA_DIR = BASE_DIR+ 'code/util/dataset/flower_prepro.ipynb'

# %run {F_DATA_DIR}

# fd = FlowersDataset([96,96], [3,96,96])

# %%
CnnExtModel.set_macro('flower_preproc',
    ['serial',
        ['conv', {'ksize':3, 'stride':2, 'chn':6, 'actions':'#act'}]])

CnnExtModel.set_macro('flower_inception1',
    ['parallel',
        ['conv', {'ksize':1, 'chn':4, 'actions':'#act'}],
        ['conv', {'ksize':3, 'chn':6, 'actions':'#act'}],
        ['serial',
            ['conv', {'ksize':3, 'chn':6, 'actions':'#act'}],
            ['conv', {'ksize':3, 'chn':6, 'actions':'#act'}]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':4, 'actions':'#act'}]]])

CnnExtModel.set_macro('flower_resize',
    ['parallel',
        ['conv', {'ksize':3, 'stride':2, 'chn':12, 'actions':'#act'}],
        ['serial',
            ['conv', {'ksize':3, 'chn':12, 'actions':'#act'}],
            ['conv', {'ksize':3, 'stride':2, 'chn':12, 'actions':'#act'}]],
        ['avg', {'ksize':3, 'stride':2}]])

CnnExtModel.set_macro('flower_inception2',
    ['parallel',
        ['conv', {'ksize':1, 'chn':8, 'actions':'#act'}],
        ['serial',
            ['conv', {'ksize':[3,3], 'chn':8, 'actions':'#act'}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':8, 'actions':'#act'}],
                ['conv', {'ksize':[3,1], 'chn':8, 'actions':'#act'}]]],
        ['serial',
            ['conv', {'ksize':[1,1], 'chn':8, 'actions':'#act'}],
            ['conv', {'ksize':[3,3], 'chn':8, 'actions':'#act'}],
            ['parallel',
                ['conv', {'ksize':[1,3], 'chn':8, 'actions':'#act'}],
                ['conv', {'ksize':[3,1], 'chn':8, 'actions':'#act'}]]],
        ['serial',
            ['avg', {'ksize':3, 'stride':1}],
            ['conv', {'ksize':1, 'chn':8, 'actions':'#act'}]]])

CnnExtModel.set_macro('flower_postproc',
    ['serial',
        ['avg', {'stride':6}],
        ['dropout', {'keep_prob':0.7}]])

# %%
CnnExtModel.set_macro('inception_flower',
    ['serial',
        ['custom', {'name':'flower_preproc', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception1', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_resize', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception1', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_resize', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception2', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_resize', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_inception2', 'args':{'#act':'#act'}}],
        ['custom', {'name':'flower_postproc', 'args':{'#act':'#act'}}]])

# %%
conf_flower_LA = ['custom', {'name':'inception_flower', 'args':{'#act':'LA'}}]
model_flower_LA = CnnExtModel('inception_flower', fd, 
                         conf_flower_LA, dump_structure=False)
# Out:
# check
# flower_preproc_1
# endendendend
# check
# flower_inception1_2
# endendendend
# check
# flower_resize_3
# endendendend
# check
# flower_inception1_4
# endendendend
# check
# flower_resize_5
# endendendend
# check
# flower_inception2_6
# endendendend
# check
# flower_resize_7
# endendendend
# check
# flower_inception2_8
# endendendend
# check
# flower_postproc_9
# endendendend
# [Linear(in_features=48, out_features=5, bias=True)]

# %%
model_flower_LA.layers
# Out:
# [normal(
#    (layer): Sequential(
#      (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#    )
#  ),
#  P_Block(
#    (flower_inception1_2): Sequential(
#      (dict): ModuleDict(
#        (flower_inception1_2_1): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (flower_inception1_2_2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception1_2_3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception1_2_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception1_2_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (flower_inception1_2_6): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (flower_resize_3): Sequential(
#      (dict): ModuleDict(
#        (flower_resize_3_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (flower_resize_3_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_resize_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (flower_resize_3_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#      )
#    )
#  ),
#  P_Block(
#    (flower_inception1_4): Sequential(
#      (dict): ModuleDict(
#        (flower_inception1_4_1): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (flower_inception1_4_2): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception1_4_3): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception1_4_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception1_4_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (flower_inception1_4_6): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (flower_resize_5): Sequential(
#      (dict): ModuleDict(
#        (flower_resize_5_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (flower_resize_5_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_resize_5_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (flower_resize_5_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#      )
#    )
#  ),
#  P_Block(
#    (flower_inception2_6): Sequential(
#      (dict): ModuleDict(
#        (flower_inception2_6_1): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (flower_inception2_6_2): Conv2d(44, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception2_6_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (flower_inception2_6_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (flower_inception2_6_5): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (flower_inception2_6_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception2_6_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (flower_inception2_6_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (flower_inception2_6_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (flower_inception2_6_10): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  P_Block(
#    (flower_resize_7): Sequential(
#      (dict): ModuleDict(
#        (flower_resize_7_1): Conv2d(48, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (flower_resize_7_2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_resize_7_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#        (flower_resize_7_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#      )
#    )
#  ),
#  P_Block(
#    (flower_inception2_8): Sequential(
#      (dict): ModuleDict(
#        (flower_inception2_8_1): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (flower_inception2_8_2): Conv2d(72, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception2_8_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (flower_inception2_8_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (flower_inception2_8_5): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#        (flower_inception2_8_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (flower_inception2_8_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#        (flower_inception2_8_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#        (flower_inception2_8_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (flower_inception2_8_10): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#      )
#    )
#  ),
#  normal(
#    (layer): Sequential(
#      (0): AvgPool2d(kernel_size=(6, 6), stride=(6, 6), padding=(0, 0))
#      (1): Dropout2d(p=0.7, inplace=False)
#    )
#  ),
#  Flatten(start_dim=1, end_dim=-1),
#  Linear(in_features=48, out_features=5, bias=True)]

# %%
EPOCH = 1
BATCH_SIZE=20
NUM_WORKERS=0
LEARNING_RATE = 0.0003

# %%
model_flower_LA.exec_all(epoch_count=EPOCH, report=20, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# model_flower_LA.exec_all(report=1)
# Out:
# Model inception_flower train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): normal(
#       (layer): Sequential(
#         (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (1): P_Block(
#       (flower_inception1_2): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_2_1): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_2_2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_2_6): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (2): P_Block(
#       (flower_resize_3): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_3_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (3): P_Block(
#       (flower_inception1_4): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_4_1): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_4_2): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_3): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_4_6): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (4): P_Block(
#       (flower_resize_5): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_5_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_5_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (5): P_Block(
#       (flower_inception2_6): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_6_1): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_2): Conv2d(44, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_5): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_6_10): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (6): P_Block(
#       (flower_resize_7): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_7_1): Conv2d(48, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_7_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (7): P_Block(
#       (flower_inception2_8): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_8_1): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_2): Conv2d(72, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_5): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_8_10): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (8): normal(
#       (layer): Sequential(
#         (0): AvgPool2d(kernel_size=(6, 6), stride=(6, 6), padding=(0, 0))
#         (1): Dropout2d(p=0.7, inplace=False)
#       )
#     )
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=48, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0003
#     weight_decay: 0
# )
#     Epoch 1: cost=1.610, accuracy=0.185/0.280 (40/40 secs)
#     Epoch 1: cost=1.609, accuracy=0.223/0.260 (38/78 secs)
#     Epoch 1: cost=1.609, accuracy=0.228/0.320 (37/115 secs)
#     Epoch 1: cost=1.608, accuracy=0.232/0.260 (37/152 secs)
#     Epoch 1: cost=1.608, accuracy=0.228/0.210 (38/190 secs)
#     Epoch 1: cost=1.608, accuracy=0.229/0.340 (42/232 secs)
#     Epoch 1: cost=1.608, accuracy=0.226/0.280 (41/273 secs)
#     Epoch 1: cost=1.607, accuracy=0.226/0.260 (44/317 secs)
# Model inception_flower train ended in 345 secs:
# <bound method Module.parameters of Net(
#   (layer1): Sequential(
#     (0): normal(
#       (layer): Sequential(
#         (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (1): P_Block(
#       (flower_inception1_2): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_2_1): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_2_2): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_3): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_2_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_2_6): Conv2d(6, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (2): P_Block(
#       (flower_resize_3): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_3_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_3_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (3): P_Block(
#       (flower_inception1_4): Sequential(
#         (dict): ModuleDict(
#           (flower_inception1_4_1): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception1_4_2): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_3): Conv2d(44, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_4): Conv2d(6, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception1_4_5): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception1_4_6): Conv2d(44, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (4): P_Block(
#       (flower_resize_5): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_5_1): Conv2d(20, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_2): Conv2d(20, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_5_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_5_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (5): P_Block(
#       (flower_inception2_6): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_6_1): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_2): Conv2d(44, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_5): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_6_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_6_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_6_10): Conv2d(44, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (6): P_Block(
#       (flower_resize_7): Sequential(
#         (dict): ModuleDict(
#           (flower_resize_7_1): Conv2d(48, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_2): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_resize_7_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (flower_resize_7_4): AvgPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#       )
#     )
#     (7): P_Block(
#       (flower_inception2_8): Sequential(
#         (dict): ModuleDict(
#           (flower_inception2_8_1): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_2): Conv2d(72, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_3): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_4): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_5): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_6): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_7): Conv2d(8, 8, kernel_size=(1, 3), stride=(1, 1), padding=same)
#           (flower_inception2_8_8): Conv2d(8, 8, kernel_size=(3, 1), stride=(1, 1), padding=same)
#           (flower_inception2_8_9): AvgPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (flower_inception2_8_10): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#         )
#       )
#     )
#     (8): normal(
#       (layer): Sequential(
#         (0): AvgPool2d(kernel_size=(6, 6), stride=(6, 6), padding=(0, 0))
#         (1): Dropout2d(p=0.7, inplace=False)
#       )
#     )
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=48, out_features=5, bias=True)
#   )
# )>
# Model inception_flower test report: accuracy = 0.239, (19 secs)
#
# Model inception_flower Visualization
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [16,24,17,18,26] => 추정 tulip : 정답 sunflower => X
# 추정확률분포 [17,23,19,19,22] => 추정 dandelion : 정답 rose => X

# %%
# F_DATA_DIR = BASE_DIR+ 'code/util/dataset/flower_prepro.ipynb'

# %run {F_DATA_DIR}

# fd = FlowersDataset([96,96], [3,96,96])

# %%
if True:
    a=1
print(a)
