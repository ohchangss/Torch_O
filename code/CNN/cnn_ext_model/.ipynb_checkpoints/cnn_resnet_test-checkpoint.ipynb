# %%
BASE_DIR = '../'*3
DATASET_DIR = BASE_DIR+'code/util/dataset/dataset_dummy.ipynb'
EXTMODEL_DIR = BASE_DIR + 'code/CNN/cnn_ext_model/ext_model.ipynb'

# %%
# %run {DATASET_DIR}
# %run {EXTMODEL_DIR}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
imagenet = DummyDataset('imagenet', 'select',[3,224,224],1000)
# Out:
# 1000

# %%
CnnExtModel.set_macro('p24',
    ['serial',
        ['loop', {'repeat':'#repeat'}, ['conv', {'ksize':3, 'chn':'#chn'}]],
        ['max', {'stride':2}]])

CnnExtModel.set_macro('vgg_19',
    ['serial',
        ['custom', {'name':'p24', 'args':{'#repeat':2, '#chn':64}}],
        ['custom', {'name':'p24', 'args':{'#repeat':2, '#chn':128}}],
        ['custom', {'name':'p24', 'args':{'#repeat':4, '#chn':256}}],
        ['custom', {'name':'p24', 'args':{'#repeat':4, '#chn':512}}],
        ['custom', {'name':'p24', 'args':{'#repeat':4, '#chn':512}}],
        ['loop', {'repeat':2}, ['full', {'width':4096}]]])

vgg19 = CnnExtModel('vgg_19', imagenet,
        ['custom', {'name':'vgg_19'}], dump_structure=True)
# Out:
# custom vgg_19
#   serial
#     custom p24
#       serial
#         loop
#           1: conv, [3, 224, 224]=>[64, 224, 224]pm : 64x3x3x3+64 = 1792
#           2: conv, [64, 224, 224]=>[64, 224, 224]pm : 64x64x3x3+64 = 36928
#         3: max, [64, 224, 224]=>[64, 112, 112]
#     custom p24
#       serial
#         loop
#           4: conv, [64, 112, 112]=>[128, 112, 112]pm : 128x64x3x3+128 = 73856
#           5: conv, [128, 112, 112]=>[128, 112, 112]pm : 128x128x3x3+128 = 147584
#         6: max, [128, 112, 112]=>[128, 56, 56]
#     custom p24
#       serial
#         loop
#           7: conv, [128, 56, 56]=>[256, 56, 56]pm : 256x128x3x3+256 = 295168
#           8: conv, [256, 56, 56]=>[256, 56, 56]pm : 256x256x3x3+256 = 590080
#           9: conv, [256, 56, 56]=>[256, 56, 56]pm : 256x256x3x3+256 = 590080
#           10: conv, [256, 56, 56]=>[256, 56, 56]pm : 256x256x3x3+256 = 590080
#         11: max, [256, 56, 56]=>[256, 28, 28]
#     custom p24
#       serial
#         loop
#           12: conv, [256, 28, 28]=>[512, 28, 28]pm : 512x256x3x3+512 = 1180160
#           13: conv, [512, 28, 28]=>[512, 28, 28]pm : 512x512x3x3+512 = 2359808
#           14: conv, [512, 28, 28]=>[512, 28, 28]pm : 512x512x3x3+512 = 2359808
#           15: conv, [512, 28, 28]=>[512, 28, 28]pm : 512x512x3x3+512 = 2359808
#         16: max, [512, 28, 28]=>[512, 14, 14]
#     custom p24
#       serial
#         loop
#           17: conv, [512, 14, 14]=>[512, 14, 14]pm : 512x512x3x3+512 = 2359808
#           18: conv, [512, 14, 14]=>[512, 14, 14]pm : 512x512x3x3+512 = 2359808
#           19: conv, [512, 14, 14]=>[512, 14, 14]pm : 512x512x3x3+512 = 2359808
#           20: conv, [512, 14, 14]=>[512, 14, 14]pm : 512x512x3x3+512 = 2359808
#         21: max, [512, 14, 14]=>[512, 7, 7]
#     loop
# [Linear(in_features=25088, out_features=4096, bias=True)]
#       22: full, [512, 7, 7]=>[4096]pm :4096x25088+4096=102764544
# [Linear(in_features=4096, out_features=4096, bias=True)]
#       23: full, [4096]=>[4096]pm :4096x4096+4096=16781312
# [Linear(in_features=4096, out_features=1000, bias=True)]
# 24: full, [4096]=>[1000]pm :1000x4096+1000=4097000
# Total parameter count : 143667240

# %%
vgg19.net
# Out:
# [P_Block(
#    (p24_1): Sequential(
#      (dict): ModuleDict(
#        (p24_1_1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_1_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_1_3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  ),
#  P_Block(
#    (p24_2): Sequential(
#      (dict): ModuleDict(
#        (p24_2_1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_2_3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  ),
#  P_Block(
#    (p24_3): Sequential(
#      (dict): ModuleDict(
#        (p24_3_1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_3_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_3_3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_3_4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_3_5): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  ),
#  P_Block(
#    (p24_4): Sequential(
#      (dict): ModuleDict(
#        (p24_4_1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_4_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_4_3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_4_4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_4_5): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  ),
#  P_Block(
#    (p24_5): Sequential(
#      (dict): ModuleDict(
#        (p24_5_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_5_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_5_3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_5_4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#        (p24_5_5): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      )
#    )
#  )]

# %%
CnnExtModel.set_macro('pn',
    ['serial',
        ['conv', {'ksize':3, 'stride':2, 'chn':'#n', 'actions':'#act'}],
        ['loop', {'repeat':'#cnt1'},
                 ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}]]])

CnnExtModel.set_macro('plain_34',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':64, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['loop', {'repeat':6}, ['conv', {'ksize':3, 'chn':64, 'actions':'#act'}]],
        ['custom', {'name':'pn', 'args':{'#cnt1':7, '#n':128, '#act':'#act'}}],
        ['custom', {'name':'pn', 'args':{'#cnt1':11, '#n':256, '#act':'#act'}}],
        ['custom', {'name':'pn', 'args':{'#cnt1':5, '#n':512, '#act':'#act'}}],
        ['avg', {'stride':7}]])

plain_34 = CnnExtModel('plain_34', imagenet,
       ['custom', {'name':'plain_34', 'args':{'#act':'LA'}}], dump_structure=True)
# Out:
# custom plain_34
#   serial
#     1: conv, [3, 224, 224]=>[64, 112, 112]pm : 64x3x7x7+64 = 9472
#     2: max, [64, 112, 112]=>[64, 56, 56]
#     loop
#       3: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#       4: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#       5: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#       6: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#       7: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#       8: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#     custom pn
#       serial
#         9: conv, [64, 56, 56]=>[128, 28, 28]pm : 128x64x3x3+128 = 73856
#         loop
#           10: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           11: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           12: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           13: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           14: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           15: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           16: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#     custom pn
#       serial
#         17: conv, [128, 28, 28]=>[256, 14, 14]pm : 256x128x3x3+256 = 295168
#         loop
#           18: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           19: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           20: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           21: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           22: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           23: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           24: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           25: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           26: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           27: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           28: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#     custom pn
#       serial
#         29: conv, [256, 14, 14]=>[512, 7, 7]pm : 512x256x3x3+512 = 1180160
#         loop
#           30: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#           31: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#           32: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#           33: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#           34: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#     35: avg, [512, 7, 7]=>[512, 1, 1]
# [Linear(in_features=512, out_features=1000, bias=True)]
# 36: full, [512, 1, 1]=>[1000]pm :1000x512+1000=513000
# Total parameter count : 21616232

# %%
CnnExtModel.set_macro('rf',
    ['add', {'x':True},
        ['serial', ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}],
                   ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}]]])

CnnExtModel.set_macro('rh',
    ['add', {'x':False},
        ['serial', ['conv', {'ksize':3, 'stride':2, 'chn':'#n', 'actions':'#act'}],
                   ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}]],
        ['avg', {'stride':2}]])

CnnExtModel.set_macro('rfull',
    ['serial',
        ['loop', {'repeat':'#cnt'},
                 ['custom', {'name':'rf', 'args':{'#n':'#n', '#act':'#act'}}]]])

CnnExtModel.set_macro('rhalf',
    ['serial',
        ['custom', {'name':'rh', 'args':{'#n':'#n', '#act':'#act'}}],
        ['loop', {'repeat':'#cnt1'},
                 ['custom', {'name':'rf', 'args':{'#n':'#n', '#act':'#act'}}]]])

CnnExtModel.set_macro('residual_34',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':64, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['custom', {'name':'rfull', 'args':{'#cnt':3, '#n':64, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':3, '#n':128, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':5, '#n':256, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':2, '#n':512, '#act':'#act'}}],
        ['avg', {'stride':7}]])

residual_34 = CnnExtModel('residual_34', imagenet,
    ['custom', {'name':'residual_34', 'args':{'#act':'LA'}}], dump_structure=True)
# Out:
# custom residual_34
#   serial
#     1: conv, [3, 224, 224]=>[64, 112, 112]pm : 64x3x7x7+64 = 9472
#     2: max, [64, 112, 112]=>[64, 56, 56]
#     custom rfull
#       serial
#         loop
#           custom rf
#             add
#               serial
#                 3: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#                 4: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#           custom rf
#             add
#               serial
#                 5: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#                 6: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#           custom rf
#             add
#               serial
#                 7: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#                 8: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#     custom rhalf
#       serial
#         custom rh
#           add
#             serial
#               9: conv, [64, 56, 56]=>[128, 28, 28]pm : 128x64x3x3+128 = 73856
#               10: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#             11: avg, [64, 56, 56]=>[64, 28, 28]
#         loop
#           custom rf
#             add
#               serial
#                 12: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#                 13: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           custom rf
#             add
#               serial
#                 14: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#                 15: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#           custom rf
#             add
#               serial
#                 16: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#                 17: conv, [128, 28, 28]=>[128, 28, 28]pm : 128x128x3x3+128 = 147584
#     custom rhalf
#       serial
#         custom rh
#           add
#             serial
#               18: conv, [128, 28, 28]=>[256, 14, 14]pm : 256x128x3x3+256 = 295168
#               19: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#             20: avg, [128, 28, 28]=>[128, 14, 14]
#         loop
#           custom rf
#             add
#               serial
#                 21: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#                 22: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           custom rf
#             add
#               serial
#                 23: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#                 24: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           custom rf
#             add
#               serial
#                 25: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#                 26: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           custom rf
#             add
#               serial
#                 27: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#                 28: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#           custom rf
#             add
#               serial
#                 29: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#                 30: conv, [256, 14, 14]=>[256, 14, 14]pm : 256x256x3x3+256 = 590080
#     custom rhalf
#       serial
#         custom rh
#           add
#             serial
#               31: conv, [256, 14, 14]=>[512, 7, 7]pm : 512x256x3x3+512 = 1180160
#               32: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#             33: avg, [256, 14, 14]=>[256, 7, 7]
#         loop
#           custom rf
#             add
#               serial
#                 34: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#                 35: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#           custom rf
#             add
#               serial
#                 36: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#                 37: conv, [512, 7, 7]=>[512, 7, 7]pm : 512x512x3x3+512 = 2359808
#     38: avg, [512, 7, 7]=>[512, 1, 1]
# [Linear(in_features=512, out_features=1000, bias=True)]
# 39: full, [512, 1, 1]=>[1000]pm :1000x512+1000=513000
# Total parameter count : 21616232

# %%
CnnExtModel.set_macro('bf',
    ['add', {'x':True},
        ['serial',
            ['conv', {'ksize':1, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':3, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':1, 'chn':'#n4', 'actions':'#act'}]]])

CnnExtModel.set_macro('bh',
    ['add', {'x':False},
        ['serial',
            ['conv', {'ksize':1, 'stride':2, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':3, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':1, 'chn':'#n4', 'actions':'#act'}]],
        ['avg', {'stride':2}]])

CnnExtModel.set_macro('bfull',
    ['serial',
        ['loop', {'repeat':'#cnt'},
            ['custom', {'name':'bf', 'args':{'#n1':'#n1', '#n4':'#n4',
                '#act':'#act'}}]]])

CnnExtModel.set_macro('bhalf',
    ['serial',
        ['custom', {'name':'bh', 'args':{'#n1':'#n1', '#n4':'#n4',
                '#act':'#act'}}],
        ['loop', {'repeat':'#cnt1'},
            ['custom', {'name':'bf', 'args':{'#n1':'#n1', '#n4':'#n4',
                '#act':'#act'}}]]])

CnnExtModel.set_macro('bottleneck_152',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':64, 'actions':'#act'}],
        ['max', {'ksize':3, 'stride':2}],
        ['custom', {'name':'bfull','args':{'#cnt':3,'#n1':64,'#n4':256,'#act':'#act'}}],
        ['custom', {'name':'bhalf','args':{'#cnt1':7,'#n1':128,'#n4':512,
            '#act':'#act'}}],
        ['custom', {'name':'bhalf','args':{'#cnt1':35,'#n1':256,'#n4':1024,
            '#act':'#act'}}],
        ['custom', {'name':'bhalf','args':{'#cnt1':2,'#n1':512,'#n4':2048,
            '#act':'#act'}}],
        ['avg', {'stride':7}]])

bottleneck_152 = CnnExtModel('bottleneck_152', imagenet,
        ['custom', {'name':'bottleneck_152', 'args':{'#act':'LAB'}}],
                    dump_structure=True)
# Out:
# custom bottleneck_152
#   serial
#     1: conv, [3, 224, 224]=>[64, 112, 112]pm : 64x3x7x7+64 = 9472
#     2: max, [64, 112, 112]=>[64, 56, 56]
#     custom bfull
#       serial
#         loop
#           custom bf
#             add
#               serial
#                 3: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x1x1+64 = 4160
#                 4: conv, [64, 56, 56]=>[64, 56, 56]pm : 64x64x3x3+64 = 36928
#                 5: conv, [64, 56, 56]=>[256, 56, 56]pm : 256x64x1x1+256 = 16640
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2784/1563034763.py in <module>
#      43 bottleneck_152 = CnnExtModel('bottleneck_152', imagenet,
#      44         ['custom', {'name':'bottleneck_152', 'args':{'#act':'LAB'}}],
# ---> 45                     dump_structure=True)
#
# ~\AppData\Local\Temp/ipykernel_2784/3734363722.py in __init__(self, name, dataset, hconfigs, show_maps, l2_decay, l1_decay, dump_structure)
#      17         self.idx = 1
#      18         #
# ---> 19         super(CnnExtModel, self).__init__(name, dataset, hconfigs, show_maps,l2_decay, l1_decay)
#      20         if self.dump_structure :
#      21             print('Total parameter count : {}'.format(self.param_count))
#
# ~\AppData\Local\Temp/ipykernel_2784/927826373.py in __init__(self, name, dataset, hconfigs, show_maps, l2_decay, l1_decay)
#       4         self.l2_decay = l2_decay
#       5         self.l1_decay = l1_decay
# ----> 6         super(CnnRegModel, self).__init__(name, dataset, hconfigs, show_maps)
#       7
#       8     def exec_all(self, epoch_count=10, batch_size = 10, learning_rate = 0.001,
#
# ~\AppData\Local\Temp/ipykernel_2784/2736955279.py in __init__(self, name, dataset, hconfigs, show_maps)
#      10         self.kernels = [] #!!필요한지 확인
#      11
# ---> 12         super(CnnBasicModel, self).__init__(name, dataset, hconfigs)
#      13         self.use_adam = True
#
# ~\AppData\Local\Temp/ipykernel_2784/3090549777.py in __init__(self, name, dataset, hconfigs)
#       5         self.numact = 0
#       6         super(Mlp_Torch, self).__init__(name, dataset)
# ----> 7         self.init_parameters(hconfigs)
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/2189688286.py in init_parameters_torch(self, hconfigs)
#       4     prev_shape = self.dataset.input_shape
#       5     for hconfig in hconfigs:
# ----> 6         pm, prev_shape=self.alloc_layer_param(prev_shape, hconfig)
#       7 #         print(pm,'pmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpm')
#       8         self.layers.append(pm)
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/3750283807.py in cnn_ext_alloc_custom_layer(self, input_shape, hconfig)
#       5
#       6 #     if self.name == name : self.macro_len = len(macro)
# ----> 7     pm_hidden, output_shape = self.alloc_layer_param(input_shape, macro)
#       8
#       9     if name == self.name:
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/721958267.py in cnn_ext_alloc_serial_layer(self, input_shape, hconfig)
#       7     for sconfig in hconfig[2:]:
#       8 #         print(self.module,idx)
# ----> 9         pm_hiddens, prev_shape = self.alloc_layer_param(prev_shape,sconfig)
#      10
#      11         for pm_hidden in pm_hiddens:
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/3750283807.py in cnn_ext_alloc_custom_layer(self, input_shape, hconfig)
#       5
#       6 #     if self.name == name : self.macro_len = len(macro)
# ----> 7     pm_hidden, output_shape = self.alloc_layer_param(input_shape, macro)
#       8
#       9     if name == self.name:
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/721958267.py in cnn_ext_alloc_serial_layer(self, input_shape, hconfig)
#       7     for sconfig in hconfig[2:]:
#       8 #         print(self.module,idx)
# ----> 9         pm_hiddens, prev_shape = self.alloc_layer_param(prev_shape,sconfig)
#      10
#      11         for pm_hidden in pm_hiddens:
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/522745971.py in cnn_ext_alloc_loop_layer(self, input_shape, hconfig)
#       6
#       7     for n in range(get_conf_param(hconfig, 'repeat',1)):
# ----> 8         pm_hidden, prev_shape = self.alloc_layer_param(prev_shape, hconfig[2])
#       9         pm_hiddens.append(pm_hidden[0])
#      10
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/3750283807.py in cnn_ext_alloc_custom_layer(self, input_shape, hconfig)
#      29             self.modules[col]= pm_hidden
#      30             mo_dict=self.get_module_dict(pm_hidden, col)
# ---> 31             B=P_Block(pm_hidden, col, mo_dict)
#      32             self.net.append(B)
#      33     #         self.net.append(nn.ReLU())
#
# ~\AppData\Local\Temp/ipykernel_2784/600759403.py in __init__(self, modules, col, module_dict)
#       9         setattr(self, self.col, nn.Sequential())
#      10         method = getattr(self, self.col)
# ---> 11         method.add_module('dict', nn.ModuleDict(module_dict))
#      12
#      13     def forward(self,x):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\container.py in __init__(self, modules)
#     301         super(ModuleDict, self).__init__()
#     302         if modules is not None:
# --> 303             self.update(modules)
#     304
#     305     @_copy_to_script_wrapper
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\container.py in update(self, modules)
#     377         if isinstance(modules, (OrderedDict, ModuleDict, container_abcs.Mapping)):
#     378             for key, module in modules.items():
# --> 379                 self[key] = module
#     380         else:
#     381             # modules here can be a list with two items
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\container.py in __setitem__(self, key, module)
#     308
#     309     def __setitem__(self, key: str, module: Module) -> None:
# --> 310         self.add_module(key, module)
#     311
#     312     def __delitem__(self, key: str) -> None:
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\module.py in add_module(self, name, module)
#     371         if not isinstance(module, Module) and module is not None:
#     372             raise TypeError("{} is not a Module subclass".format(
# --> 373                 torch.typename(module)))
#     374         elif not isinstance(name, torch._six.string_classes):
#     375             raise TypeError("module name should be a string. Got {}".format(
#
# TypeError: tuple is not a Module subclass

# %%
bottleneck_152.net
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12440/2279014222.py in <module>
# ----> 1 bottleneck_152.net
#
# NameError: name 'bottleneck_152' is not defined

# %%
# F_DATA_DIR = BASE_DIR+ 'code/util/dataset/flower_prepro.ipynb'

# %run {F_DATA_DIR}

# fd = FlowersDataset([64,64], [3,64,64])
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
CnnExtModel.set_macro('plain_flower',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':16, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['loop', {'repeat':4}, ['conv', {'ksize':3, 'chn':16, 'actions':'#act'}]],
        ['custom', {'name':'pn', 'args':{'#cnt1':3, '#n':32, '#act':'#act'}}],
        ['custom', {'name':'pn', 'args':{'#cnt1':3, '#n':64, '#act':'#act'}}],
        ['avg', {'stride':4}]])

plain_flower = CnnExtModel('plain_flower', fd,
        ['custom', {'name':'plain_flower', 'args':{'#act':'LAB'}}],
                    dump_structure=True)
plain_flower.exec_all(epoch_count=10, report=2)
# Out:
# custom plain_flower
#   serial
#     1: conv, (3, 64, 64)=>[16, 32, 32]pm : 16x3x7x7+16 = 2368
#     2: max, [16, 32, 32]=>[16, 16, 16]
#     loop
#       3: conv, [16, 16, 16]=>[16, 16, 16]pm : 16x16x3x3+16 = 2320
#       4: conv, [16, 16, 16]=>[16, 16, 16]pm : 16x16x3x3+16 = 2320
#       5: conv, [16, 16, 16]=>[16, 16, 16]pm : 16x16x3x3+16 = 2320
#       6: conv, [16, 16, 16]=>[16, 16, 16]pm : 16x16x3x3+16 = 2320
#     custom pn
#       serial
#         7: conv, [16, 16, 16]=>[32, 8, 8]pm : 32x16x3x3+32 = 4640
#         loop
#           8: conv, [32, 8, 8]=>[32, 8, 8]pm : 32x32x3x3+32 = 9248
#           9: conv, [32, 8, 8]=>[32, 8, 8]pm : 32x32x3x3+32 = 9248
#           10: conv, [32, 8, 8]=>[32, 8, 8]pm : 32x32x3x3+32 = 9248
# check
# pn_1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2784/3018119685.py in <module>
#      10 plain_flower = CnnExtModel('plain_flower', fd,
#      11         ['custom', {'name':'plain_flower', 'args':{'#act':'LAB'}}],
# ---> 12                     dump_structure=True)
#      13 plain_flower.exec_all(epoch_count=10, report=2)
#
# ~\AppData\Local\Temp/ipykernel_2784/3734363722.py in __init__(self, name, dataset, hconfigs, show_maps, l2_decay, l1_decay, dump_structure)
#      17         self.idx = 1
#      18         #
# ---> 19         super(CnnExtModel, self).__init__(name, dataset, hconfigs, show_maps,l2_decay, l1_decay)
#      20         if self.dump_structure :
#      21             print('Total parameter count : {}'.format(self.param_count))
#
# ~\AppData\Local\Temp/ipykernel_2784/927826373.py in __init__(self, name, dataset, hconfigs, show_maps, l2_decay, l1_decay)
#       4         self.l2_decay = l2_decay
#       5         self.l1_decay = l1_decay
# ----> 6         super(CnnRegModel, self).__init__(name, dataset, hconfigs, show_maps)
#       7
#       8     def exec_all(self, epoch_count=10, batch_size = 10, learning_rate = 0.001,
#
# ~\AppData\Local\Temp/ipykernel_2784/2736955279.py in __init__(self, name, dataset, hconfigs, show_maps)
#      10         self.kernels = [] #!!필요한지 확인
#      11
# ---> 12         super(CnnBasicModel, self).__init__(name, dataset, hconfigs)
#      13         self.use_adam = True
#
# ~\AppData\Local\Temp/ipykernel_2784/3090549777.py in __init__(self, name, dataset, hconfigs)
#       5         self.numact = 0
#       6         super(Mlp_Torch, self).__init__(name, dataset)
# ----> 7         self.init_parameters(hconfigs)
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/2189688286.py in init_parameters_torch(self, hconfigs)
#       4     prev_shape = self.dataset.input_shape
#       5     for hconfig in hconfigs:
# ----> 6         pm, prev_shape=self.alloc_layer_param(prev_shape, hconfig)
#       7 #         print(pm,'pmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpmpm')
#       8         self.layers.append(pm)
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/3501457055.py in cnn_ext_alloc_custom_layer(self, input_shape, hconfig)
#       5
#       6 #     if self.name == name : self.macro_len = len(macro)
# ----> 7     pm_hidden, output_shape = self.alloc_layer_param(input_shape, macro)
#       8
#       9     if name == self.name:
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/721958267.py in cnn_ext_alloc_serial_layer(self, input_shape, hconfig)
#       7     for sconfig in hconfig[2:]:
#       8 #         print(self.module,idx)
# ----> 9         pm_hiddens, prev_shape = self.alloc_layer_param(prev_shape,sconfig)
#      10
#      11         for pm_hidden in pm_hiddens:
#
# ~\AppData\Local\Temp/ipykernel_2784/192598140.py in cnn_ext_alloc_layer_param(self, input_shape, hconfig)
#      10             print('{:>{width}}{}'.format('', dump_str, width = self.layer_depth*2))
#      11         self.layer_depth += 1;
# ---> 12     pm, output_shape = super(CnnExtModel, self).alloc_layer_param(input_shape, hconfig)
#      13 #     print(pm,'pmpmpmpmpm')
#      14     if layer_type in ['serial', 'parallel', 'loop', 'add', 'custom']:
#
# ~\AppData\Local\Temp/ipykernel_2784/2926312647.py in cnn_basic_alloc_layer_param(self, input_shape, hconfig)
#       4     m_name = 'alloc_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     pm, output_shape = method(input_shape, hconfig)
#       7     return pm, output_shape
#       8
#
# ~\AppData\Local\Temp/ipykernel_2784/3501457055.py in cnn_ext_alloc_custom_layer(self, input_shape, hconfig)
#      29             self.modules[col]= pm_hidden
#      30             mo_dict=self.get_module_dict(pm_hidden, col)
# ---> 31             B=P_Block(pm_hidden, col, mo_dict)
#      32             self.net.append(B)
#      33     #         self.net.append(nn.ReLU())
#
# ~\AppData\Local\Temp/ipykernel_2784/600759403.py in __init__(self, modules, col, module_dict)
#       9         setattr(self, self.col, nn.Sequential())
#      10         method = getattr(self, self.col)
# ---> 11         method.add_module('dict', nn.ModuleDict(module_dict))
#      12
#      13     def forward(self,x):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\container.py in __init__(self, modules)
#     301         super(ModuleDict, self).__init__()
#     302         if modules is not None:
# --> 303             self.update(modules)
#     304
#     305     @_copy_to_script_wrapper
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\container.py in update(self, modules)
#     377         if isinstance(modules, (OrderedDict, ModuleDict, container_abcs.Mapping)):
#     378             for key, module in modules.items():
# --> 379                 self[key] = module
#     380         else:
#     381             # modules here can be a list with two items
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\container.py in __setitem__(self, key, module)
#     308
#     309     def __setitem__(self, key: str, module: Module) -> None:
# --> 310         self.add_module(key, module)
#     311
#     312     def __delitem__(self, key: str) -> None:
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\module.py in add_module(self, name, module)
#     371         if not isinstance(module, Module) and module is not None:
#     372             raise TypeError("{} is not a Module subclass".format(
# --> 373                 torch.typename(module)))
#     374         elif not isinstance(name, torch._six.string_classes):
#     375             raise TypeError("module name should be a string. Got {}".format(
#
# TypeError: tuple is not a Module subclass

# %%
CnnExtModel.set_macro('residual_flower',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':16, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['custom', {'name':'rfull', 'args':{'#cnt':2, '#n':16, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':1, '#n':32, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':1, '#n':64, '#act':'#act'}}],
        ['avg', {'stride':4}]])

residual_flower = CnnExtModel('residual_flower', fd,
      ['custom', {'name':'residual_flower', 'args':{'#act':'LAB'}}],
                  dump_structure=True)
residual_flower.exec_all(epoch_count=10, report=2)

# %%
CnnExtModel.set_macro('bottleneck_flower',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':16, 'actions':'#act'}],
        ['max', {'ksize':3, 'stride':2}],
        ['custom', {'name':'bfull', 'args':{'#cnt':1,'#n1':16,'#n4': 64,
            '#act':'#act'}}],
        ['custom', {'name':'bhalf', 'args':{'#cnt1':2,'#n1':32,'#n4':128
            '#act':'#act'}}],
        ['custom', {'name':'bhalf', 'args':{'#cnt1':1,'#n1':64,'#n4':256,
            '#act':'#act'}}],
        ['avg', {'stride':4}]])

bottleneck_flower = CnnExtModel('bottleneck_flower', fd,
    ['custom', {'name':'bottleneck_flower', 'args':{'#act':'LAB'}}],
        dump_structure=True)
bottleneck_flower.exec_all(epoch_count=10, report=2)

# %%
# %run {DATASET_DIR}
# %run {EXTMODEL_DIR}

imagenet = DummyDataset('imagenet', 'select',[299,299,3],1000)

CnnExtModel.set_macro('p24',
    ['serial',
        ['loop', {'repeat':'#repeat'}, ['conv', {'ksize':3, 'chn':'#chn'}]],
        ['max', {'stride':2}]])

CnnExtModel.set_macro('vgg_19',
    ['serial',
        ['custom', {'name':'p24', 'args':{'#repeat':2, '#chn':64}}],
        ['custom', {'name':'p24', 'args':{'#repeat':2, '#chn':128}}],
        ['custom', {'name':'p24', 'args':{'#repeat':4, '#chn':256}}],
        ['custom', {'name':'p24', 'args':{'#repeat':4, '#chn':512}}],
        ['custom', {'name':'p24', 'args':{'#repeat':4, '#chn':512}}],
        ['loop', {'repeat':2}, ['full', {'width':4096}]]])

vgg19 = CnnExtModel('vgg_19', imagenet,
        ['custom', {'name':'vgg_19'}], dump_structure=True)

CnnExtModel.set_macro('pn',
    ['serial',
        ['conv', {'ksize':3, 'stride':2, 'chn':'#n', 'actions':'#act'}],
        ['loop', {'repeat':'#cnt1'},
                 ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}]]])

CnnExtModel.set_macro('plain_34',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':64, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['loop', {'repeat':6}, ['conv', {'ksize':3, 'chn':64, 'actions':'#act'}]],
        ['custom', {'name':'pn', 'args':{'#cnt1':7, '#n':128, '#act':'#act'}}],
        ['custom', {'name':'pn', 'args':{'#cnt1':11, '#n':256, '#act':'#act'}}],
        ['custom', {'name':'pn', 'args':{'#cnt1':5, '#n':512, '#act':'#act'}}],
        ['avg', {'stride':7}]])

plain_34 = CnnExtModel('plain_34', imagenet,
       ['custom', {'name':'plain_34', 'args':{'#act':'LA'}}], dump_structure=True)

CnnExtModel.set_macro('rf',
    ['add', {'x':True},
        ['serial', ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}],
                   ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}]]])

CnnExtModel.set_macro('rh',
    ['add', {'x':False},
        ['serial', ['conv', {'ksize':3, 'stride':2, 'chn':'#n', 'actions':'#act'}],
                   ['conv', {'ksize':3, 'chn':'#n', 'actions':'#act'}]],
        ['avg', {'stride':2}]])

CnnExtModel.set_macro('rfull',
    ['serial',
        ['loop', {'repeat':'#cnt'},
                 ['custom', {'name':'rf', 'args':{'#n':'#n', '#act':'#act'}}]]])

CnnExtModel.set_macro('rhalf',
    ['serial',
        ['custom', {'name':'rh', 'args':{'#n':'#n', '#act':'#act'}}],
        ['loop', {'repeat':'#cnt1'},
                 ['custom', {'name':'rf', 'args':{'#n':'#n', '#act':'#act'}}]]])

CnnExtModel.set_macro('residual_34',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':64, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['custom', {'name':'rfull', 'args':{'#cnt':3, '#n':64, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':3, '#n':128, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':5, '#n':256, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':2, '#n':512, '#act':'#act'}}],
        ['avg', {'stride':7}]])

residual_34 = CnnExtModel('residual_34', imagenet,
    ['custom', {'name':'residual_34', 'args':{'#act':'LA'}}], dump_structure=True)

CnnExtModel.set_macro('bf',
    ['add', {'x':True},
        ['serial',
            ['conv', {'ksize':1, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':3, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':1, 'chn':'#n4', 'actions':'#act'}]]])

CnnExtModel.set_macro('bh',
    ['add', {'x':False},
        ['serial',
            ['conv', {'ksize':1, 'stride':2, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':3, 'chn':'#n1', 'actions':'#act'}],
            ['conv', {'ksize':1, 'chn':'#n4', 'actions':'#act'}]],
        ['avg', {'stride':2}]])

CnnExtModel.set_macro('bfull',
    ['serial',
        ['loop', {'repeat':'#cnt'},
            ['custom', {'name':'bf', 'args':{'#n1':'#n1', '#n4':'#n4',
                '#act':'#act'}}]]])

CnnExtModel.set_macro('bhalf',
    ['serial',
        ['custom', {'name':'bh', 'args':{'#n1':'#n1', '#n4':'#n4',
                '#act':'#act'}}],
        ['loop', {'repeat':'#cnt1'},
            ['custom', {'name':'bf', 'args':{'#n1':'#n1', '#n4':'#n4',
                '#act':'#act'}}]]])

CnnExtModel.set_macro('bottleneck_152',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':64, 'actions':'#act'}],
        ['max', {'ksize':3, 'stride':2}],
        ['custom', {'name':'bfull','args':{'#cnt':3,'#n1':64,'#n4':256,'#act':'#act'}}],
        ['custom', {'name':'bhalf','args':{'#cnt1':7,'#n1':128,'#n4':512,
            '#act':'#act'}}],
        ['custom', {'name':'bhalf','args':{'#cnt1':35,'#n1':256,'#n4':1024,
            '#act':'#act'}}],
        ['custom', {'name':'bhalf','args':{'#cnt1':2,'#n1':512,'#n4':2048,
            '#act':'#act'}}],
        ['avg', {'stride':7}]])

bottleneck_152 = CnnExtModel('bottleneck_152', imagenet,
        ['custom', {'name':'bottleneck_152', 'args':{'#act':'LAB'}}],
                    dump_structure=True)

# %run ../chap05/dataset_flowers.ipynb

fd = FlowersDataset([64,64], [64,64,3])

CnnExtModel.set_macro('plain_flower',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':16, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['loop', {'repeat':4}, ['conv', {'ksize':3, 'chn':16, 'actions':'#act'}]],
        ['custom', {'name':'pn', 'args':{'#cnt1':3, '#n':32, '#act':'#act'}}],
        ['custom', {'name':'pn', 'args':{'#cnt1':3, '#n':64, '#act':'#act'}}],
        ['avg', {'stride':4}]])

plain_flower = CnnExtModel('plain_flower', fd,
        ['custom', {'name':'plain_flower', 'args':{'#act':'LAB'}}],
                    dump_structure=True)
plain_flower.exec_all(epoch_count=10, report=2)

CnnExtModel.set_macro('residual_flower',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':16, 'actions':'#act'}],
        ['max', {'stride':2}],
        ['custom', {'name':'rfull', 'args':{'#cnt':2, '#n':16, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':1, '#n':32, '#act':'#act'}}],
        ['custom', {'name':'rhalf', 'args':{'#cnt1':1, '#n':64, '#act':'#act'}}],
        ['avg', {'stride':4}]])

residual_flower = CnnExtModel('residual_flower', fd,
      ['custom', {'name':'residual_flower', 'args':{'#act':'LAB'}}],
                  dump_structure=True)
residual_flower.exec_all(epoch_count=10, report=2)

CnnExtModel.set_macro('bottleneck_flower',
    ['serial',
        ['conv', {'ksize':7, 'stride':2, 'chn':16, 'actions':'#act'}],
        ['max', {'ksize':3, 'stride':2}],
        ['custom', {'name':'bfull', 'args':{'#cnt':1,'#n1':16,'#n4': 64,
            '#act':'#act'}}],
        ['custom', {'name':'bhalf', 'args':{'#cnt1':2,'#n1':32,'#n4':128
            '#act':'#act'}}],
        ['custom', {'name':'bhalf', 'args':{'#cnt1':1,'#n1':64,'#n4':256,
            '#act':'#act'}}],
        ['avg', {'stride':4}]])

bottleneck_flower = CnnExtModel('bottleneck_flower', fd,
    ['custom', {'name':'bottleneck_flower', 'args':{'#act':'LAB'}}],
        dump_structure=True)
bottleneck_flower.exec_all(epoch_count=10, report=2)
