# %%
BASE_DIR='../'*3
REG_DIR = BASE_DIR + 'code/CNN/cnn_regmodel/cnn_reg_model.ipynb'
FLW_DIR = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'

OFC_DIR = BASE_DIR+'code/util/dataset/dataset_office31.ipynb'

# %%
# %run {REG_DIR}
# %run {FLW_DIR}
# %run {OFC_DIR}
# Out:
# Using device: cuda
# GeForce GTX 1660 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.1 GB
# Using PyTorch version: 1.10.0

# %%
fd = FlowersDataset([96, 96], [3, 96, 96])
# od = Office31Dataset([96, 96], [3,96, 96])

# %%
EPOCH = 10
BATCH_SIZE=10
NUM_WORKERS=0
LEARNING_RATE = 0.001

# %%
fm1 = CnnRegModel('flowers_model_1', fd, [['full',{'width':30,'actfunc':'relu'}],
                                           ['full',{'width':10,'actfunc':'relu'}]])
fm1.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
         ,show_params=True )
# fm1.exec_all(epoch_count=10, report=2, show_params=True)
# Out:
# (3, 96, 96)
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=10, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#     Epoch 1: cost=2.810, accuracy=0.203/0.160 (0/0 secs)
#     Epoch 1: cost=2.215, accuracy=0.198/0.110 (0/0 secs)
#     Epoch 1: cost=2.019, accuracy=0.194/0.150 (0/0 secs)
#     Epoch 1: cost=1.918, accuracy=0.196/0.140 (0/0 secs)
#     Epoch 1: cost=1.860, accuracy=0.192/0.160 (1/1 secs)
#     Epoch 1: cost=1.821, accuracy=0.187/0.140 (0/1 secs)
#     Epoch 1: cost=1.791, accuracy=0.189/0.280 (0/1 secs)
#     Epoch 1: cost=1.769, accuracy=0.193/0.180 (0/1 secs)
#     Epoch 2: cost=1.607, accuracy=0.265/0.170 (0/1 secs)
#     Epoch 2: cost=1.609, accuracy=0.249/0.180 (0/1 secs)
#     Epoch 2: cost=1.605, accuracy=0.262/0.220 (0/1 secs)
#     Epoch 2: cost=1.608, accuracy=0.242/0.210 (1/2 secs)
#     Epoch 2: cost=1.608, accuracy=0.237/0.190 (0/2 secs)
#     Epoch 2: cost=1.608, accuracy=0.233/0.200 (0/2 secs)
#     Epoch 2: cost=1.607, accuracy=0.238/0.180 (0/2 secs)
#     Epoch 2: cost=1.607, accuracy=0.234/0.250 (0/2 secs)
#     Epoch 3: cost=1.602, accuracy=0.225/0.220 (0/2 secs)
#     Epoch 3: cost=1.605, accuracy=0.210/0.200 (0/2 secs)
#     Epoch 3: cost=1.604, accuracy=0.223/0.120 (1/3 secs)
#     Epoch 3: cost=1.604, accuracy=0.224/0.210 (0/3 secs)
#     Epoch 3: cost=1.603, accuracy=0.225/0.200 (0/3 secs)
#     Epoch 3: cost=1.602, accuracy=0.229/0.200 (0/3 secs)
#     Epoch 3: cost=1.601, accuracy=0.235/0.180 (0/3 secs)
#     Epoch 3: cost=1.601, accuracy=0.231/0.200 (0/3 secs)
#     Epoch 4: cost=1.601, accuracy=0.235/0.220 (0/3 secs)
#     Epoch 4: cost=1.599, accuracy=0.234/0.200 (1/4 secs)
#     Epoch 4: cost=1.599, accuracy=0.230/0.220 (0/4 secs)
#     Epoch 4: cost=1.600, accuracy=0.231/0.110 (0/4 secs)
#     Epoch 4: cost=1.599, accuracy=0.237/0.170 (0/4 secs)
#     Epoch 4: cost=1.599, accuracy=0.230/0.210 (0/4 secs)
#     Epoch 4: cost=1.598, accuracy=0.235/0.220 (0/4 secs)
#     Epoch 4: cost=1.599, accuracy=0.231/0.200 (0/4 secs)
#     Epoch 5: cost=1.590, accuracy=0.252/0.270 (1/5 secs)
#     Epoch 5: cost=1.597, accuracy=0.251/0.260 (0/5 secs)
#     Epoch 5: cost=1.594, accuracy=0.256/0.260 (0/5 secs)
#     Epoch 5: cost=1.598, accuracy=0.248/0.270 (0/5 secs)
#     Epoch 5: cost=1.599, accuracy=0.240/0.190 (0/5 secs)
#     Epoch 5: cost=1.599, accuracy=0.238/0.260 (0/5 secs)
#     Epoch 5: cost=1.599, accuracy=0.240/0.340 (0/5 secs)
#     Epoch 5: cost=1.599, accuracy=0.239/0.250 (0/5 secs)
#     Epoch 6: cost=1.598, accuracy=0.228/0.250 (1/6 secs)
#     Epoch 6: cost=1.603, accuracy=0.244/0.220 (0/6 secs)
#     Epoch 6: cost=1.599, accuracy=0.247/0.260 (0/6 secs)
#     Epoch 6: cost=1.595, accuracy=0.246/0.280 (0/6 secs)
#     Epoch 6: cost=1.594, accuracy=0.249/0.240 (0/6 secs)
#     Epoch 6: cost=1.594, accuracy=0.250/0.200 (0/6 secs)
#     Epoch 6: cost=1.596, accuracy=0.248/0.260 (0/6 secs)
#     Epoch 6: cost=1.599, accuracy=0.243/0.250 (1/7 secs)
#     Epoch 7: cost=1.595, accuracy=0.260/0.320 (0/7 secs)
#     Epoch 7: cost=1.596, accuracy=0.251/0.270 (0/7 secs)
#     Epoch 7: cost=1.600, accuracy=0.248/0.270 (0/7 secs)
#     Epoch 7: cost=1.600, accuracy=0.246/0.270 (0/7 secs)
#     Epoch 7: cost=1.600, accuracy=0.245/0.230 (0/7 secs)
#     Epoch 7: cost=1.598, accuracy=0.242/0.310 (0/7 secs)
#     Epoch 7: cost=1.597, accuracy=0.244/0.250 (1/8 secs)
#     Epoch 7: cost=1.598, accuracy=0.242/0.270 (0/8 secs)
#     Epoch 8: cost=1.592, accuracy=0.252/0.290 (0/8 secs)
#     Epoch 8: cost=1.595, accuracy=0.250/0.270 (0/8 secs)
#     Epoch 8: cost=1.602, accuracy=0.237/0.290 (0/8 secs)
#     Epoch 8: cost=1.601, accuracy=0.233/0.230 (0/8 secs)
#     Epoch 8: cost=1.601, accuracy=0.234/0.240 (0/8 secs)
#     Epoch 8: cost=1.600, accuracy=0.236/0.190 (1/9 secs)
#     Epoch 8: cost=1.598, accuracy=0.238/0.270 (0/9 secs)
#     Epoch 8: cost=1.597, accuracy=0.245/0.250 (0/9 secs)
#     Epoch 9: cost=1.588, accuracy=0.257/0.220 (0/9 secs)
#     Epoch 9: cost=1.594, accuracy=0.240/0.260 (0/9 secs)
#     Epoch 9: cost=1.596, accuracy=0.236/0.280 (0/9 secs)
#     Epoch 9: cost=1.599, accuracy=0.235/0.240 (0/9 secs)
#     Epoch 9: cost=1.599, accuracy=0.237/0.320 (1/10 secs)
#     Epoch 9: cost=1.599, accuracy=0.241/0.290 (0/10 secs)
#     Epoch 9: cost=1.600, accuracy=0.241/0.200 (0/10 secs)
#     Epoch 9: cost=1.598, accuracy=0.243/0.290 (0/10 secs)
#     Epoch 10: cost=1.598, accuracy=0.240/0.240 (0/10 secs)
#     Epoch 10: cost=1.594, accuracy=0.244/0.280 (0/10 secs)
#     Epoch 10: cost=1.596, accuracy=0.242/0.250 (0/10 secs)
#     Epoch 10: cost=1.595, accuracy=0.246/0.230 (1/11 secs)
#     Epoch 10: cost=1.595, accuracy=0.244/0.230 (0/11 secs)
#     Epoch 10: cost=1.597, accuracy=0.242/0.240 (0/11 secs)
#     Epoch 10: cost=1.598, accuracy=0.239/0.260 (0/11 secs)
#     Epoch 10: cost=1.598, accuracy=0.240/0.240 (0/11 secs)
# Model flowers_model_1 train ended in 11 secs:
# <bound method Module.parameters of Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=10, out_features=5, bias=True)
#   )
# )>
# Model flowers_model_1 test report: accuracy = 0.248, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 rose => X
# Near 0 parameters =  0.0%(217/829790)

# %%
fm1 = CnnRegModel('flowers_model_1', fd, [['full',{'width':30,'actfunc':'relu'}],
                                           ['full',{'width':10,'actfunc':'relu'}]]
                 , l2_decay=0.000008)
fm1.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
         ,show_params=True )
# fm1.exec_all(epoch_count=10, report=2, show_params=True)
# Out:
# (3, 96, 96)
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=10, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 8e-06
# )
#     Epoch 1: cost=2.293, accuracy=0.208/0.250 (0/0 secs)
#     Epoch 1: cost=1.951, accuracy=0.215/0.200 (0/0 secs)
#     Epoch 1: cost=1.837, accuracy=0.222/0.230 (0/0 secs)
#     Epoch 1: cost=1.780, accuracy=0.223/0.220 (0/0 secs)
#     Epoch 1: cost=1.745, accuracy=0.229/0.230 (0/0 secs)
#     Epoch 1: cost=1.722, accuracy=0.232/0.270 (0/0 secs)
#     Epoch 1: cost=1.705, accuracy=0.229/0.260 (0/0 secs)
#     Epoch 1: cost=1.692, accuracy=0.233/0.240 (1/1 secs)
#     Epoch 2: cost=1.599, accuracy=0.260/0.260 (0/1 secs)
#     Epoch 2: cost=1.601, accuracy=0.250/0.320 (0/1 secs)
#     Epoch 2: cost=1.602, accuracy=0.250/0.200 (0/1 secs)
#     Epoch 2: cost=1.603, accuracy=0.240/0.240 (0/1 secs)
#     Epoch 2: cost=1.603, accuracy=0.243/0.250 (0/1 secs)
#     Epoch 2: cost=1.601, accuracy=0.246/0.290 (0/1 secs)
#     Epoch 2: cost=1.601, accuracy=0.246/0.260 (1/2 secs)
#     Epoch 2: cost=1.602, accuracy=0.242/0.280 (0/2 secs)
#     Epoch 3: cost=1.598, accuracy=0.250/0.290 (0/2 secs)
#     Epoch 3: cost=1.596, accuracy=0.251/0.290 (0/2 secs)
#     Epoch 3: cost=1.600, accuracy=0.251/0.300 (0/2 secs)
#     Epoch 3: cost=1.599, accuracy=0.250/0.300 (0/2 secs)
#     Epoch 3: cost=1.599, accuracy=0.252/0.260 (0/2 secs)
#     Epoch 3: cost=1.601, accuracy=0.245/0.210 (0/2 secs)
#     Epoch 3: cost=1.601, accuracy=0.240/0.210 (1/3 secs)
#     Epoch 3: cost=1.600, accuracy=0.239/0.240 (0/3 secs)
#     Epoch 4: cost=1.589, accuracy=0.275/0.230 (0/3 secs)
#     Epoch 4: cost=1.586, accuracy=0.283/0.250 (0/3 secs)
#     Epoch 4: cost=1.587, accuracy=0.274/0.210 (0/3 secs)
#     Epoch 4: cost=1.589, accuracy=0.267/0.270 (0/3 secs)
#     Epoch 4: cost=1.593, accuracy=0.256/0.280 (0/3 secs)
#     Epoch 4: cost=1.595, accuracy=0.253/0.250 (1/4 secs)
#     Epoch 4: cost=1.597, accuracy=0.246/0.280 (0/4 secs)
#     Epoch 4: cost=1.598, accuracy=0.242/0.290 (0/4 secs)
#     Epoch 5: cost=1.596, accuracy=0.248/0.270 (0/4 secs)
#     Epoch 5: cost=1.596, accuracy=0.245/0.290 (0/4 secs)
#     Epoch 5: cost=1.599, accuracy=0.242/0.220 (0/4 secs)
#     Epoch 5: cost=1.598, accuracy=0.239/0.240 (0/4 secs)
#     Epoch 5: cost=1.596, accuracy=0.241/0.300 (1/5 secs)
#     Epoch 5: cost=1.596, accuracy=0.246/0.260 (0/5 secs)
#     Epoch 5: cost=1.596, accuracy=0.246/0.270 (0/5 secs)
#     Epoch 5: cost=1.597, accuracy=0.244/0.240 (0/5 secs)
#     Epoch 6: cost=1.595, accuracy=0.270/0.270 (0/5 secs)
#     Epoch 6: cost=1.597, accuracy=0.250/0.330 (0/5 secs)
#     Epoch 6: cost=1.600, accuracy=0.246/0.240 (0/5 secs)
#     Epoch 6: cost=1.602, accuracy=0.230/0.260 (1/6 secs)
#     Epoch 6: cost=1.603, accuracy=0.227/0.300 (0/6 secs)
#     Epoch 6: cost=1.601, accuracy=0.232/0.220 (0/6 secs)
#     Epoch 6: cost=1.600, accuracy=0.237/0.240 (0/6 secs)
#     Epoch 6: cost=1.599, accuracy=0.240/0.270 (0/6 secs)
#     Epoch 7: cost=1.599, accuracy=0.262/0.260 (0/6 secs)
#     Epoch 7: cost=1.595, accuracy=0.264/0.230 (0/6 secs)
#     Epoch 7: cost=1.595, accuracy=0.256/0.230 (0/6 secs)
#     Epoch 7: cost=1.594, accuracy=0.260/0.250 (1/7 secs)
#     Epoch 7: cost=1.596, accuracy=0.252/0.260 (0/7 secs)
#     Epoch 7: cost=1.598, accuracy=0.248/0.220 (0/7 secs)
#     Epoch 7: cost=1.599, accuracy=0.244/0.280 (0/7 secs)
#     Epoch 7: cost=1.598, accuracy=0.242/0.330 (0/7 secs)
#     Epoch 8: cost=1.602, accuracy=0.238/0.280 (0/7 secs)
#     Epoch 8: cost=1.603, accuracy=0.236/0.270 (0/7 secs)
#     Epoch 8: cost=1.599, accuracy=0.245/0.260 (1/8 secs)
#     Epoch 8: cost=1.599, accuracy=0.237/0.200 (0/8 secs)
#     Epoch 8: cost=1.598, accuracy=0.238/0.220 (0/8 secs)
#     Epoch 8: cost=1.598, accuracy=0.236/0.260 (0/8 secs)
#     Epoch 8: cost=1.598, accuracy=0.240/0.220 (0/8 secs)
#     Epoch 8: cost=1.600, accuracy=0.238/0.260 (0/8 secs)
#     Epoch 9: cost=1.594, accuracy=0.257/0.240 (0/8 secs)
#     Epoch 9: cost=1.589, accuracy=0.260/0.280 (1/9 secs)
#     Epoch 9: cost=1.592, accuracy=0.249/0.240 (0/9 secs)
#     Epoch 9: cost=1.594, accuracy=0.251/0.250 (0/9 secs)
#     Epoch 9: cost=1.596, accuracy=0.247/0.310 (0/9 secs)
#     Epoch 9: cost=1.597, accuracy=0.243/0.280 (0/9 secs)
#     Epoch 9: cost=1.597, accuracy=0.242/0.310 (0/9 secs)
#     Epoch 9: cost=1.597, accuracy=0.243/0.220 (0/9 secs)
#     Epoch 10: cost=1.590, accuracy=0.260/0.250 (0/9 secs)
#     Epoch 10: cost=1.592, accuracy=0.241/0.230 (1/10 secs)
#     Epoch 10: cost=1.595, accuracy=0.238/0.280 (0/10 secs)
#     Epoch 10: cost=1.596, accuracy=0.238/0.270 (0/10 secs)
#     Epoch 10: cost=1.596, accuracy=0.242/0.260 (0/10 secs)
#     Epoch 10: cost=1.598, accuracy=0.242/0.270 (0/10 secs)
#     Epoch 10: cost=1.597, accuracy=0.240/0.230 (0/10 secs)
#     Epoch 10: cost=1.598, accuracy=0.241/0.230 (0/10 secs)
# Model flowers_model_1 train ended in 10 secs:
# <bound method Module.parameters of Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=10, out_features=5, bias=True)
#   )
# )>
# Model flowers_model_1 test report: accuracy = 0.248, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 sunflower => X
# Near 0 parameters = 12.3%(101691/829790)
