# %%
BASE_DIR='../'*3
REG_DIR = BASE_DIR + 'code/CNN/cnn_regmodel/cnn_reg_model.ipynb'
FLW_DIR = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'

OFC_DIR = BASE_DIR+'code/util/dataset/dataset_office31.ipynb'

# %%
# %run {REG_DIR}
# %run {FLW_DIR}
# %run {OFC_DIR}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
fd = FlowersDataset([96, 96], [3, 96, 96])
# od = Office31Dataset([96, 96], [3,96, 96])

# %%
EPOCH = 10
BATCH_SIZE=10
NUM_WORKERS=0
LEARNING_RATE = 0.001

# %%
fm1 = CnnRegModel('flowers_model_1', fd, [['full',{'width':30,'actfunc':'relu'}],
                                           ['full',{'width':10,'actfunc':'relu'}]])
fm1.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
         ,show_params=True )
# fm1.exec_all(epoch_count=10, report=2, show_params=True)
# Out:
# (3, 96, 96)
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=10, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#     Epoch 1: cost=1.814, accuracy=0.242/0.220 (2/2 secs)
#     Epoch 1: cost=1.707, accuracy=0.255/0.270 (1/3 secs)
#     Epoch 1: cost=1.672, accuracy=0.251/0.220 (1/4 secs)
#     Epoch 1: cost=1.655, accuracy=0.248/0.290 (1/5 secs)
#     Epoch 1: cost=1.645, accuracy=0.249/0.220 (1/6 secs)
#     Epoch 1: cost=1.638, accuracy=0.249/0.200 (1/7 secs)
#     Epoch 1: cost=1.635, accuracy=0.244/0.240 (1/8 secs)
#     Epoch 1: cost=1.630, accuracy=0.246/0.240 (1/9 secs)
#     Epoch 2: cost=1.599, accuracy=0.245/0.210 (2/11 secs)
#     Epoch 2: cost=1.602, accuracy=0.230/0.280 (1/12 secs)
#     Epoch 2: cost=1.601, accuracy=0.239/0.240 (1/13 secs)
#     Epoch 2: cost=1.603, accuracy=0.233/0.230 (1/14 secs)
#     Epoch 2: cost=1.603, accuracy=0.235/0.190 (1/15 secs)
#     Epoch 2: cost=1.602, accuracy=0.242/0.220 (1/16 secs)
#     Epoch 2: cost=1.601, accuracy=0.244/0.240 (1/17 secs)
#     Epoch 2: cost=1.601, accuracy=0.243/0.270 (1/18 secs)
#     Epoch 3: cost=1.602, accuracy=0.210/0.230 (3/21 secs)
#     Epoch 3: cost=1.601, accuracy=0.230/0.310 (3/24 secs)
#     Epoch 3: cost=1.602, accuracy=0.231/0.250 (3/27 secs)
#     Epoch 3: cost=1.601, accuracy=0.236/0.220 (3/30 secs)
#     Epoch 3: cost=1.601, accuracy=0.238/0.220 (3/33 secs)
#     Epoch 3: cost=1.599, accuracy=0.244/0.240 (4/37 secs)
#     Epoch 3: cost=1.598, accuracy=0.248/0.230 (3/40 secs)
#     Epoch 3: cost=1.598, accuracy=0.248/0.260 (3/43 secs)
#     Epoch 4: cost=1.596, accuracy=0.250/0.280 (5/48 secs)
#     Epoch 4: cost=1.598, accuracy=0.241/0.250 (3/51 secs)
#     Epoch 4: cost=1.597, accuracy=0.239/0.280 (3/54 secs)
#     Epoch 4: cost=1.598, accuracy=0.237/0.180 (3/57 secs)
#     Epoch 4: cost=1.598, accuracy=0.243/0.240 (4/61 secs)
#     Epoch 4: cost=1.598, accuracy=0.241/0.260 (3/64 secs)
#     Epoch 4: cost=1.599, accuracy=0.239/0.280 (3/67 secs)
#     Epoch 4: cost=1.599, accuracy=0.242/0.250 (3/70 secs)
#     Epoch 5: cost=1.598, accuracy=0.257/0.250 (5/75 secs)
#     Epoch 5: cost=1.600, accuracy=0.245/0.290 (3/78 secs)
#     Epoch 5: cost=1.597, accuracy=0.247/0.230 (3/81 secs)
#     Epoch 5: cost=1.598, accuracy=0.248/0.260 (3/84 secs)
#     Epoch 5: cost=1.597, accuracy=0.248/0.330 (3/87 secs)
#     Epoch 5: cost=1.596, accuracy=0.250/0.230 (3/90 secs)
#     Epoch 5: cost=1.596, accuracy=0.251/0.240 (2/92 secs)
#     Epoch 5: cost=1.598, accuracy=0.249/0.230 (3/95 secs)
#     Epoch 6: cost=1.603, accuracy=0.272/0.260 (5/100 secs)
#     Epoch 6: cost=1.601, accuracy=0.259/0.240 (3/103 secs)
#     Epoch 6: cost=1.602, accuracy=0.252/0.220 (3/106 secs)
#     Epoch 6: cost=1.601, accuracy=0.244/0.200 (3/109 secs)
#     Epoch 6: cost=1.600, accuracy=0.244/0.200 (3/112 secs)
#     Epoch 6: cost=1.601, accuracy=0.240/0.290 (3/115 secs)
#     Epoch 6: cost=1.601, accuracy=0.238/0.220 (3/118 secs)
#     Epoch 6: cost=1.599, accuracy=0.243/0.200 (3/121 secs)
#     Epoch 7: cost=1.592, accuracy=0.267/0.220 (6/127 secs)
#     Epoch 7: cost=1.602, accuracy=0.233/0.240 (3/130 secs)
#     Epoch 7: cost=1.598, accuracy=0.246/0.270 (3/133 secs)
#     Epoch 7: cost=1.599, accuracy=0.243/0.270 (3/136 secs)
#     Epoch 7: cost=1.598, accuracy=0.247/0.230 (4/140 secs)
#     Epoch 7: cost=1.597, accuracy=0.248/0.230 (4/144 secs)
#     Epoch 7: cost=1.598, accuracy=0.248/0.240 (3/147 secs)
#     Epoch 7: cost=1.597, accuracy=0.249/0.200 (3/150 secs)
#     Epoch 8: cost=1.604, accuracy=0.235/0.260 (5/155 secs)
#     Epoch 8: cost=1.603, accuracy=0.230/0.240 (3/158 secs)
#     Epoch 8: cost=1.602, accuracy=0.236/0.310 (3/161 secs)
#     Epoch 8: cost=1.598, accuracy=0.247/0.260 (3/164 secs)
#     Epoch 8: cost=1.597, accuracy=0.253/0.280 (3/167 secs)
#     Epoch 8: cost=1.596, accuracy=0.255/0.230 (4/171 secs)
#     Epoch 8: cost=1.597, accuracy=0.254/0.240 (3/174 secs)
#     Epoch 8: cost=1.598, accuracy=0.249/0.340 (2/176 secs)
#     Epoch 9: cost=1.608, accuracy=0.210/0.240 (5/181 secs)
#     Epoch 9: cost=1.602, accuracy=0.224/0.240 (3/184 secs)
#     Epoch 9: cost=1.602, accuracy=0.228/0.250 (3/187 secs)
#     Epoch 9: cost=1.601, accuracy=0.232/0.250 (3/190 secs)
#     Epoch 9: cost=1.602, accuracy=0.231/0.260 (3/193 secs)
#     Epoch 9: cost=1.601, accuracy=0.234/0.200 (3/196 secs)
#     Epoch 9: cost=1.600, accuracy=0.239/0.290 (3/199 secs)
#     Epoch 9: cost=1.599, accuracy=0.243/0.230 (3/202 secs)
#     Epoch 10: cost=1.596, accuracy=0.272/0.220 (5/207 secs)
#     Epoch 10: cost=1.598, accuracy=0.254/0.220 (3/210 secs)
#     Epoch 10: cost=1.596, accuracy=0.256/0.210 (3/213 secs)
#     Epoch 10: cost=1.599, accuracy=0.251/0.320 (3/216 secs)
#     Epoch 10: cost=1.601, accuracy=0.242/0.220 (3/219 secs)
#     Epoch 10: cost=1.600, accuracy=0.241/0.250 (3/222 secs)
#     Epoch 10: cost=1.600, accuracy=0.243/0.240 (3/225 secs)
#     Epoch 10: cost=1.599, accuracy=0.244/0.220 (3/228 secs)
# Model flowers_model_1 train ended in 230 secs:
# <bound method Module.parameters of Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Linear(in_features=10, out_features=5, bias=True)
#   )
# )>
# Model flowers_model_1 test report: accuracy = 0.225, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [17,25,19,17,23] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [17,25,19,17,23] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [17,25,19,17,23] => 추정 dandelion : 정답 sunflower => X
# Near 0 parameters =  0.0%(233/829790)
