# %%
BASE_DIR = "../"*3
MODEL_DIR = BASE_DIR +'code/CNN/cnn_basic/cnn_basic_model.ipynb'
FLW_DIR = BASE_DIR +'code/UTIL/dataset/flower_prepro.ipynb'
OFFICE_DIR = BASE_DIR +'code/UTIL/dataset/office31_prepro.ipynb'

# %%
# %run {MODEL_DIR}
# %run {FLW_DIR}
# Out:
# Using device: cuda
# NVIDIA GeForce RTX 3060 Laptop GPU
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# Using PyTorch version: 1.10.1

# %%
# %run {OFFICE_DIR}
# Out:
# Using device: cuda
# NVIDIA GeForce RTX 3060 Laptop GPU
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# Using PyTorch version: 1.10.1

# %%
EPOCH = 50
BATCH_SIZE=10
NUM_WORKERS=0
LEARNING_RATE = 0.0001

# %%
fd = FlowersDataset([96, 96], [3, 96, 96])
print(fd)
# Out:
# flowers(select, 3450+436+431)

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [
                ['conv', {'ksize':2, 'chn':6, 'actfunc':'relu'}], 
                ['max', {'stride':2}]
            ])
fm.use_adam=False
fm.exec_all(epoch_count=EPOCH, report=5, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
 # SGD -> lr 수정(더 작게)및 epoch 늘릴필요 있음
# Out:
# Model flowers_model_1 train started
#
#
# CrossEntropyLoss()
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layers): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=13824, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0001
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# /home/ubuntu/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/conv.py:443: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  /opt/conda/conda-bld/pytorch_1639180594101/work/aten/src/ATen/native/Convolution.cpp:647.)
#   self.padding, self.dilation, self.groups)
#     Epoch 5: cost=16.038, accuracy=0.244/0.250 (8/8 secs)
#     Epoch 10: cost=16.005, accuracy=0.244/0.250 (2/10 secs)
#     Epoch 15: cost=15.989, accuracy=0.244/0.170 (3/13 secs)
#     Epoch 20: cost=15.981, accuracy=0.244/0.260 (2/15 secs)
#     Epoch 25: cost=15.977, accuracy=0.244/0.210 (2/17 secs)
#     Epoch 30: cost=15.975, accuracy=0.244/0.300 (3/20 secs)
#     Epoch 35: cost=15.974, accuracy=0.244/0.250 (2/22 secs)
#     Epoch 40: cost=15.973, accuracy=0.244/0.220 (3/25 secs)
#     Epoch 45: cost=15.973, accuracy=0.244/0.240 (2/27 secs)
#     Epoch 50: cost=15.973, accuracy=0.244/0.280 (3/30 secs)
# Model flowers_model_1 train ended in 30 secs:
# Model flowers_model_1 test report: accuracy = 0.234, (0 secs)
#
# Model flowers_model_1 Visualization
# /home/ubuntu/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [18,24,18,17,23] => 추정 dandelion : 정답 tulip => X

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [
                ['conv', {'ksize':2, 'chn':6, 'actfunc':'relu'}], 
                ['max', {'stride':2}]
            ])
fm.use_adam=True
fm.exec_all(epoch_count=EPOCH, report=5, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
 # adam -> 과대적합, 정확도x -> 규제추가 및 신경망 추가
# Out:
# Model flowers_model_1 train started
#
#
# CrossEntropyLoss()
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layers): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=13824, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#     Epoch 5: cost=11.017, accuracy=0.543/0.420 (6/6 secs)
#     Epoch 10: cost=9.365, accuracy=0.644/0.380 (6/12 secs)
# Model flowers_model_1 train ended in 12 secs:
# Model flowers_model_1 test report: accuracy = 0.385, (0 secs)
#
# Model flowers_model_1 Visualization
# /home/ubuntu/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# 추정확률분포 [13,81, 5, 0, 1] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [ 0, 0,81, 0,19] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 0, 0,84, 0,16] => 추정 rose : 정답 tulip => X

# %%
fm = CnnBasicModel('flowers_model_1', fd, [['conv', {'ksize':2, 'chn':6,'actfunc':'relu'}], 
                ['max', {'stride':2}],
                                           ['conv', {'ksize':2, 'chn':12,'actfunc':'relu'}], 
                ['avg', {'stride':2}]
                ])
fm.use_adam = True
fm.exec_all(epoch_count=EPOCH, report=5, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
#Adam

# epoch 더 올려볼수 있다.
# Out:
# Model flowers_model_1 train started
#
#
# CrossEntropyLoss()
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layers): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6912, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#     Epoch 5: cost=8.686, accuracy=0.672/0.480 (6/6 secs)
#     Epoch 10: cost=2.780, accuracy=0.907/0.590 (6/12 secs)
# Model flowers_model_1 train ended in 12 secs:
# Model flowers_model_1 test report: accuracy = 0.495, (0 secs)
#
# Model flowers_model_1 Visualization
# /home/ubuntu/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# 추정확률분포 [ 0,86, 8, 2, 4] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [87, 6, 1, 6, 0] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [ 0, 0, 5, 0,95] => 추정 tulip : 정답 tulip => O

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6,'actfunc':'relu'}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12,'actfunc':'relu'}], 
                ['avg', {'stride':2}],
               ['conv', {'ksize':3, 'chn':24,'actfunc':'relu'}], 
                ['avg', {'stride':2}],
               ['conv', {'ksize':3, 'chn':48,'actfunc':'relu'}], 
                ['avg', {'stride':2}],
                ])
fm3.exec_all(epoch_count=EPOCH, report=5, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# Model flowers_model_3 train started
#
#
# CrossEntropyLoss()
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layers): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (6): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (9): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=432, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0001
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
#     Epoch 5: cost=14.155, accuracy=0.372/0.380 (8/8 secs)
#     Epoch 10: cost=12.884, accuracy=0.461/0.360 (7/15 secs)
#     Epoch 15: cost=11.644, accuracy=0.520/0.510 (7/22 secs)
#     Epoch 20: cost=11.007, accuracy=0.554/0.550 (7/29 secs)
#     Epoch 25: cost=10.500, accuracy=0.581/0.580 (8/37 secs)
#     Epoch 30: cost=10.207, accuracy=0.599/0.600 (7/44 secs)
#     Epoch 35: cost=9.833, accuracy=0.612/0.420 (7/51 secs)
#     Epoch 40: cost=9.579, accuracy=0.623/0.610 (8/59 secs)
#     Epoch 45: cost=9.340, accuracy=0.630/0.590 (8/67 secs)
#     Epoch 50: cost=8.996, accuracy=0.646/0.650 (7/74 secs)
# Model flowers_model_3 train ended in 74 secs:
# Model flowers_model_3 test report: accuracy = 0.539, (0 secs)
#
# Model flowers_model_3 Visualization
# /home/ubuntu/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# 추정확률분포 [ 5,34,32, 9,20] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [18, 0,77, 0, 5] => 추정 rose : 정답 rose => O
# 추정확률분포 [12,41, 0,42, 3] => 추정 sunflower : 정답 tulip => X

# %%
od = Office31Dataset([96, 96], [3, 96, 96])

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'relu'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'relu'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'relu'}], 
                ['avg', {'stride':3}],
               ['conv', {'ksize':3, 'chn':48, 'actfunc':'relu'}], 
                ['avg', {'stride':2}]])
om3.use_adam=True
om3.exec_all(epoch_count=EPOCH, report=5, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# Model office31_model_3 train started
#
#
# None
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layers): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=(3, 3), stride=(3, 3), padding=(0, 0))
#     (9): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=768, out_features=34, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
#     Epoch 5: cost=3.292, accuracy=0.798+0.217/0.870+0.210 (6/6 secs)
#     Epoch 10: cost=2.915, accuracy=0.833+0.299/0.730+0.240 (6/12 secs)
#     Epoch 15: cost=2.645, accuracy=0.855+0.361/0.880+0.290 (6/18 secs)
#     Epoch 20: cost=2.405, accuracy=0.873+0.417/0.770+0.320 (6/24 secs)
#     Epoch 25: cost=2.185, accuracy=0.888+0.453/0.820+0.260 (6/30 secs)
#     Epoch 30: cost=1.991, accuracy=0.894+0.513/0.870+0.310 (5/35 secs)
#     Epoch 35: cost=1.818, accuracy=0.909+0.540/0.880+0.420 (6/41 secs)
#     Epoch 40: cost=1.659, accuracy=0.921+0.584/0.840+0.350 (7/48 secs)
#     Epoch 45: cost=1.537, accuracy=0.918+0.618/0.860+0.350 (5/53 secs)
#     Epoch 50: cost=1.387, accuracy=0.926+0.653/0.880+0.340 (6/59 secs)
# Model office31_model_3 train ended in 59 secs:
# Model office31_model_3 test report: accuracy = 0.871+0.365, (0 secs)
#
# Model office31_model_3 Visualization
# /home/ubuntu/anaconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# [ 도메인 추정결과 ]
# 추정확률분포 [ 0,99, 1] => 추정 dslr : 정답 dslr => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [99, 0, 1] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 1, 0, 0, 0, 1, 0, 0, 3,...] => 추정 ring_binder : 정답 mouse => X
# 추정확률분포 [ 0, 0, 0, 0, 0, 1, 1, 1,...] => 추정 desktop_computer : 정답 desktop_computer => O
# 추정확률분포 [ 0, 0, 0, 0, 0, 1, 0, 0,...] => 추정 punchers : 정답 punchers => O
