# %%
BASE_DIR = "../"*3
MODEL_DIR = BASE_DIR +'code/CNN/cnn_basic/cnn_basic_model.ipynb'
FLW_DIR = '../../../code/UTIL/dataset/flower_prepro.ipynb'
OFFICE_DIR = BASE_DIR +'code/UTIL/dataset/office31_prepro.ipynb'

# %%
# %run {MODEL_DIR}

# %%
print(FLW_DIR)
# %run {FLW_DIR}
# Out:
# ../../../code/UTIL/dataset/flower_prepro.ipynb
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'../../..//code/util/dataset/dataset.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/ubuntu_work/work/Torch_O/code/UTIL/dataset/flower_prepro.ipynb in <module>
#       1 BASE_DIR = '../'*3
#       2 RUN_DIR = BASE_DIR + '/code/util/dataset/dataset.ipynb'
# ----> 3 get_ipython().run_line_magic('run', '{RUN_DIR}')
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'../../..//code/util/dataset/dataset.ipynb.py'` not found.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'../../..//code/util/dataset/dataset.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_12008/3355906196.py in <module>
#       1 print(FLW_DIR)
# ----> 2 get_ipython().run_line_magic('run', '{FLW_DIR}')
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2836                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2837                     if raise_exceptions:
# -> 2838                         result.raise_error()
#    2839                     elif not result.success:
#    2840                         break
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_12008/878403849.py in <module>
#       1 BASE_DIR = '../'*3
#       2 RUN_DIR = BASE_DIR + '/code/util/dataset/dataset.ipynb'
# ----> 3 get_ipython().run_line_magic('run', '{RUN_DIR}')
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'../../..//code/util/dataset/dataset.ipynb.py'` not found.

# %%
# %run {OFFICE_DIR}

# %%
EPOCH = 1
BATCH_SIZE=35
NUM_WORKERS=0
LEARNING_RATE = 0.005

# %%
fd = FlowersDataset([96, 96], [3, 96, 96])
print(fd)
# Out:
# flowers(select, 3450+436+431)

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [['conv', {'ksize':2, 'chn':6}], 
                ['max', {'stride':2}], 
                ])
fm.exec_all(epoch_count=EPOCH, report=10, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (2): Flatten(start_dim=1, end_dim=-1)
#     (3): Linear(in_features=13824, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=153.828, accuracy=0.226/0.250 (7/7 secs)
#     Epoch 1: cost=133.019, accuracy=0.221/0.280 (6/13 secs)
#     Epoch 1: cost=118.942, accuracy=0.245/0.320 (5/18 secs)
#     Epoch 1: cost=108.420, accuracy=0.261/0.400 (5/23 secs)
#     Epoch 1: cost=101.720, accuracy=0.279/0.390 (5/28 secs)
#     Epoch 1: cost=95.201, accuracy=0.291/0.460 (6/34 secs)
#     Epoch 1: cost=90.340, accuracy=0.302/0.340 (5/39 secs)
#     Epoch 1: cost=86.488, accuracy=0.306/0.300 (6/45 secs)
#     Epoch 1: cost=84.599, accuracy=0.311/0.380 (5/50 secs)
# Model flowers_model_1 train ended in 55 secs:
# <bound method Module.parameters of Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (2): Flatten(start_dim=1, end_dim=-1)
#     (3): Linear(in_features=13824, out_features=5, bias=True)
#   )
# )>
# Model flowers_model_1 test report: accuracy = 0.365, (2 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [ 0, 0,100, 0, 0] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 0,100, 0, 0, 0] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 0, 0,100, 0, 0] => 추정 rose : 정답 tulip => X

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [['conv', {'ksize':2, 'chn':6,'actfunc':'relu'}], 
                ['max', {'stride':2}],
                                           ['conv', {'ksize':2, 'chn':12,'actfunc':'relu'}], 
                ['avg', {'stride':2}]
                ])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6912, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=5.009, accuracy=0.226/0.260 (0/0 secs)
#     Epoch 1: cost=4.171, accuracy=0.258/0.320 (0/0 secs)
#     Epoch 2: cost=2.711, accuracy=0.325/0.290 (1/1 secs)
#     Epoch 2: cost=2.602, accuracy=0.324/0.350 (0/1 secs)
#     Epoch 3: cost=2.284, accuracy=0.349/0.320 (0/1 secs)
#     Epoch 3: cost=2.315, accuracy=0.347/0.330 (0/1 secs)
#     Epoch 4: cost=1.908, accuracy=0.394/0.290 (1/2 secs)
#     Epoch 4: cost=1.918, accuracy=0.387/0.310 (0/2 secs)
#     Epoch 5: cost=1.899, accuracy=0.408/0.410 (0/2 secs)
#     Epoch 5: cost=1.885, accuracy=0.403/0.440 (1/3 secs)
#     Epoch 6: cost=1.639, accuracy=0.435/0.350 (0/3 secs)
#     Epoch 6: cost=1.707, accuracy=0.435/0.330 (0/3 secs)
#     Epoch 7: cost=1.555, accuracy=0.475/0.370 (1/4 secs)
#     Epoch 7: cost=1.550, accuracy=0.463/0.410 (0/4 secs)
#     Epoch 8: cost=1.480, accuracy=0.453/0.370 (0/4 secs)
#     Epoch 8: cost=1.472, accuracy=0.464/0.360 (0/4 secs)
#     Epoch 9: cost=1.448, accuracy=0.474/0.370 (1/5 secs)
#     Epoch 9: cost=1.395, accuracy=0.494/0.390 (0/5 secs)
#     Epoch 10: cost=1.330, accuracy=0.504/0.400 (1/6 secs)
#     Epoch 10: cost=1.296, accuracy=0.518/0.380 (0/6 secs)
#     Epoch 11: cost=1.237, accuracy=0.543/0.320 (0/6 secs)
#     Epoch 11: cost=1.270, accuracy=0.532/0.340 (0/6 secs)
#     Epoch 12: cost=1.126, accuracy=0.577/0.350 (1/7 secs)
#     Epoch 12: cost=1.174, accuracy=0.554/0.440 (0/7 secs)
#     Epoch 13: cost=1.102, accuracy=0.584/0.390 (0/7 secs)
#     Epoch 13: cost=1.093, accuracy=0.584/0.390 (1/8 secs)
#     Epoch 14: cost=1.067, accuracy=0.578/0.360 (0/8 secs)
#     Epoch 14: cost=1.073, accuracy=0.583/0.420 (0/8 secs)
#     Epoch 15: cost=1.068, accuracy=0.600/0.350 (1/9 secs)
#     Epoch 15: cost=1.016, accuracy=0.610/0.400 (0/9 secs)
#     Epoch 16: cost=0.966, accuracy=0.620/0.410 (0/9 secs)
#     Epoch 16: cost=0.989, accuracy=0.608/0.390 (0/9 secs)
#     Epoch 17: cost=0.906, accuracy=0.647/0.350 (1/10 secs)
#     Epoch 17: cost=0.924, accuracy=0.652/0.440 (0/10 secs)
#     Epoch 18: cost=0.896, accuracy=0.659/0.400 (0/10 secs)
#     Epoch 18: cost=0.880, accuracy=0.667/0.390 (1/11 secs)
#     Epoch 19: cost=0.932, accuracy=0.632/0.470 (0/11 secs)
#     Epoch 19: cost=0.906, accuracy=0.647/0.390 (0/11 secs)
#     Epoch 20: cost=0.851, accuracy=0.674/0.450 (1/12 secs)
#     Epoch 20: cost=0.842, accuracy=0.684/0.430 (0/12 secs)
# Model flowers_model_1 train ended in 12 secs:
# Model flowers_model_1 test report: accuracy = 0.480, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [43,50, 2, 1, 5] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 6, 4, 3,27,60] => 추정 tulip : 정답 sunflower => X
# 추정확률분포 [ 2, 1,38,17,42] => 추정 tulip : 정답 tulip => O

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6,'actfunc':'relu'}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12,'actfunc':'relu'}], 
                ['avg', {'stride':2}],
               ['conv', {'ksize':3, 'chn':24,'actfunc':'relu'}], 
                ['avg', {'stride':2}],
               ['conv', {'ksize':3, 'chn':48,'actfunc':'relu'}], 
                ['avg', {'stride':2}],
                ])
fm3.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# Model flowers_model_3 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (6): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (9): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=432, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=1.726, accuracy=0.193/0.250 (0/0 secs)
#     Epoch 1: cost=1.681, accuracy=0.213/0.330 (0/0 secs)
#     Epoch 2: cost=1.580, accuracy=0.276/0.260 (1/1 secs)
#     Epoch 2: cost=1.573, accuracy=0.282/0.270 (0/1 secs)
#     Epoch 3: cost=1.545, accuracy=0.291/0.290 (0/1 secs)
#     Epoch 3: cost=1.536, accuracy=0.300/0.320 (1/2 secs)
#     Epoch 4: cost=1.508, accuracy=0.332/0.330 (0/2 secs)
#     Epoch 4: cost=1.497, accuracy=0.321/0.300 (0/2 secs)
#     Epoch 5: cost=1.473, accuracy=0.345/0.340 (1/3 secs)
#     Epoch 5: cost=1.460, accuracy=0.355/0.360 (0/3 secs)
#     Epoch 6: cost=1.421, accuracy=0.382/0.470 (0/3 secs)
#     Epoch 6: cost=1.436, accuracy=0.368/0.380 (1/4 secs)
#     Epoch 7: cost=1.425, accuracy=0.386/0.390 (0/4 secs)
#     Epoch 7: cost=1.420, accuracy=0.379/0.330 (0/4 secs)
#     Epoch 8: cost=1.379, accuracy=0.395/0.410 (1/5 secs)
#     Epoch 8: cost=1.396, accuracy=0.391/0.400 (0/5 secs)
#     Epoch 9: cost=1.401, accuracy=0.381/0.490 (0/5 secs)
#     Epoch 9: cost=1.384, accuracy=0.396/0.460 (1/6 secs)
#     Epoch 10: cost=1.374, accuracy=0.406/0.430 (0/6 secs)
#     Epoch 10: cost=1.359, accuracy=0.415/0.450 (0/6 secs)
#     Epoch 11: cost=1.339, accuracy=0.431/0.450 (1/7 secs)
#     Epoch 11: cost=1.339, accuracy=0.420/0.430 (0/7 secs)
#     Epoch 12: cost=1.334, accuracy=0.418/0.450 (0/7 secs)
#     Epoch 12: cost=1.321, accuracy=0.429/0.390 (1/8 secs)
#     Epoch 13: cost=1.299, accuracy=0.441/0.430 (0/8 secs)
#     Epoch 13: cost=1.307, accuracy=0.439/0.330 (0/8 secs)
#     Epoch 14: cost=1.292, accuracy=0.464/0.460 (1/9 secs)
#     Epoch 14: cost=1.289, accuracy=0.459/0.420 (0/9 secs)
#     Epoch 15: cost=1.269, accuracy=0.455/0.410 (0/9 secs)
#     Epoch 15: cost=1.287, accuracy=0.451/0.410 (1/10 secs)
#     Epoch 16: cost=1.257, accuracy=0.479/0.450 (0/10 secs)
#     Epoch 16: cost=1.272, accuracy=0.465/0.450 (0/10 secs)
#     Epoch 17: cost=1.258, accuracy=0.462/0.400 (1/11 secs)
#     Epoch 17: cost=1.253, accuracy=0.469/0.370 (0/11 secs)
#     Epoch 18: cost=1.248, accuracy=0.473/0.420 (0/11 secs)
#     Epoch 18: cost=1.243, accuracy=0.475/0.460 (1/12 secs)
#     Epoch 19: cost=1.252, accuracy=0.480/0.460 (0/12 secs)
#     Epoch 19: cost=1.239, accuracy=0.479/0.410 (0/12 secs)
#     Epoch 20: cost=1.251, accuracy=0.456/0.440 (1/13 secs)
#     Epoch 20: cost=1.229, accuracy=0.473/0.460 (0/13 secs)
#     Epoch 21: cost=1.218, accuracy=0.486/0.450 (0/13 secs)
#     Epoch 21: cost=1.213, accuracy=0.485/0.420 (1/14 secs)
#     Epoch 22: cost=1.201, accuracy=0.504/0.510 (0/14 secs)
#     Epoch 22: cost=1.197, accuracy=0.511/0.470 (0/14 secs)
#     Epoch 23: cost=1.184, accuracy=0.502/0.520 (1/15 secs)
#     Epoch 23: cost=1.197, accuracy=0.496/0.450 (0/15 secs)
#     Epoch 24: cost=1.198, accuracy=0.501/0.490 (0/15 secs)
#     Epoch 24: cost=1.188, accuracy=0.501/0.440 (1/16 secs)
#     Epoch 25: cost=1.175, accuracy=0.513/0.510 (0/16 secs)
#     Epoch 25: cost=1.182, accuracy=0.502/0.500 (0/16 secs)
#     Epoch 26: cost=1.184, accuracy=0.517/0.480 (1/17 secs)
#     Epoch 26: cost=1.182, accuracy=0.511/0.440 (0/17 secs)
#     Epoch 27: cost=1.193, accuracy=0.504/0.450 (0/17 secs)
#     Epoch 27: cost=1.182, accuracy=0.509/0.480 (1/18 secs)
#     Epoch 28: cost=1.174, accuracy=0.504/0.460 (0/18 secs)
#     Epoch 28: cost=1.174, accuracy=0.516/0.500 (0/18 secs)
#     Epoch 29: cost=1.162, accuracy=0.526/0.480 (1/19 secs)
#     Epoch 29: cost=1.154, accuracy=0.524/0.500 (0/19 secs)
#     Epoch 30: cost=1.162, accuracy=0.522/0.500 (0/19 secs)
#     Epoch 30: cost=1.150, accuracy=0.524/0.450 (1/20 secs)
#     Epoch 31: cost=1.155, accuracy=0.524/0.490 (0/20 secs)
#     Epoch 31: cost=1.155, accuracy=0.521/0.480 (0/20 secs)
#     Epoch 32: cost=1.167, accuracy=0.524/0.550 (1/21 secs)
#     Epoch 32: cost=1.148, accuracy=0.529/0.520 (0/21 secs)
#     Epoch 33: cost=1.139, accuracy=0.539/0.540 (0/21 secs)
#     Epoch 33: cost=1.134, accuracy=0.534/0.460 (1/22 secs)
#     Epoch 34: cost=1.148, accuracy=0.532/0.430 (0/22 secs)
#     Epoch 34: cost=1.143, accuracy=0.531/0.530 (0/22 secs)
#     Epoch 35: cost=1.103, accuracy=0.553/0.400 (1/23 secs)
#     Epoch 35: cost=1.130, accuracy=0.543/0.510 (0/23 secs)
#     Epoch 36: cost=1.115, accuracy=0.545/0.500 (0/23 secs)
#     Epoch 36: cost=1.123, accuracy=0.541/0.540 (1/24 secs)
#     Epoch 37: cost=1.107, accuracy=0.559/0.460 (0/24 secs)
#     Epoch 37: cost=1.114, accuracy=0.545/0.500 (0/24 secs)
#     Epoch 38: cost=1.120, accuracy=0.524/0.480 (1/25 secs)
#     Epoch 38: cost=1.115, accuracy=0.540/0.560 (0/25 secs)
#     Epoch 39: cost=1.120, accuracy=0.546/0.470 (0/25 secs)
#     Epoch 39: cost=1.113, accuracy=0.546/0.400 (0/25 secs)
#     Epoch 40: cost=1.072, accuracy=0.571/0.480 (1/26 secs)
#     Epoch 40: cost=1.100, accuracy=0.553/0.510 (0/26 secs)
#     Epoch 41: cost=1.109, accuracy=0.559/0.490 (1/27 secs)
#     Epoch 41: cost=1.100, accuracy=0.553/0.550 (0/27 secs)
#     Epoch 42: cost=1.051, accuracy=0.570/0.500 (0/27 secs)
#     Epoch 42: cost=1.097, accuracy=0.548/0.510 (0/27 secs)
#     Epoch 43: cost=1.120, accuracy=0.527/0.480 (1/28 secs)
#     Epoch 43: cost=1.107, accuracy=0.545/0.520 (0/28 secs)
#     Epoch 44: cost=1.118, accuracy=0.561/0.500 (1/29 secs)
#     Epoch 44: cost=1.093, accuracy=0.559/0.460 (0/29 secs)
#     Epoch 45: cost=1.081, accuracy=0.574/0.570 (0/29 secs)
#     Epoch 45: cost=1.079, accuracy=0.571/0.530 (0/29 secs)
#     Epoch 46: cost=1.080, accuracy=0.566/0.540 (1/30 secs)
#     Epoch 46: cost=1.088, accuracy=0.558/0.530 (0/30 secs)
#     Epoch 47: cost=1.064, accuracy=0.585/0.420 (0/30 secs)
#     Epoch 47: cost=1.076, accuracy=0.573/0.500 (1/31 secs)
#     Epoch 48: cost=1.082, accuracy=0.559/0.420 (0/31 secs)
#     Epoch 48: cost=1.077, accuracy=0.567/0.500 (0/31 secs)
#     Epoch 49: cost=1.046, accuracy=0.592/0.500 (1/32 secs)
#     Epoch 49: cost=1.063, accuracy=0.579/0.470 (0/32 secs)
#     Epoch 50: cost=1.088, accuracy=0.567/0.550 (0/32 secs)
#     Epoch 50: cost=1.072, accuracy=0.575/0.440 (1/33 secs)
#     Epoch 51: cost=1.076, accuracy=0.563/0.490 (0/33 secs)
#     Epoch 51: cost=1.067, accuracy=0.567/0.520 (0/33 secs)
#     Epoch 52: cost=1.060, accuracy=0.571/0.480 (1/34 secs)
#     Epoch 52: cost=1.065, accuracy=0.573/0.560 (0/34 secs)
#     Epoch 53: cost=1.041, accuracy=0.585/0.450 (0/34 secs)
#     Epoch 53: cost=1.055, accuracy=0.576/0.430 (1/35 secs)
#     Epoch 54: cost=1.047, accuracy=0.581/0.430 (0/35 secs)
#     Epoch 54: cost=1.060, accuracy=0.570/0.520 (0/35 secs)
#     Epoch 55: cost=1.057, accuracy=0.582/0.550 (1/36 secs)
#     Epoch 55: cost=1.047, accuracy=0.582/0.440 (0/36 secs)
#     Epoch 56: cost=1.033, accuracy=0.587/0.460 (0/36 secs)
#     Epoch 56: cost=1.038, accuracy=0.576/0.500 (1/37 secs)
#     Epoch 57: cost=1.039, accuracy=0.564/0.540 (0/37 secs)
#     Epoch 57: cost=1.036, accuracy=0.574/0.420 (0/37 secs)
#     Epoch 58: cost=1.077, accuracy=0.559/0.540 (1/38 secs)
#     Epoch 58: cost=1.045, accuracy=0.570/0.510 (0/38 secs)
#     Epoch 59: cost=1.047, accuracy=0.586/0.490 (0/38 secs)
#     Epoch 59: cost=1.043, accuracy=0.579/0.440 (1/39 secs)
#     Epoch 60: cost=1.051, accuracy=0.568/0.540 (0/39 secs)
#     Epoch 60: cost=1.040, accuracy=0.584/0.500 (0/39 secs)
#     Epoch 61: cost=1.010, accuracy=0.599/0.500 (1/40 secs)
#     Epoch 61: cost=1.033, accuracy=0.585/0.550 (0/40 secs)
#     Epoch 62: cost=1.015, accuracy=0.596/0.500 (0/40 secs)
#     Epoch 62: cost=1.029, accuracy=0.593/0.510 (1/41 secs)
#     Epoch 63: cost=1.025, accuracy=0.593/0.500 (0/41 secs)
#     Epoch 63: cost=1.015, accuracy=0.598/0.500 (0/41 secs)
#     Epoch 64: cost=1.051, accuracy=0.572/0.510 (1/42 secs)
#     Epoch 64: cost=1.033, accuracy=0.585/0.470 (0/42 secs)
#     Epoch 65: cost=1.037, accuracy=0.580/0.460 (0/42 secs)
#     Epoch 65: cost=1.019, accuracy=0.590/0.550 (1/43 secs)
#     Epoch 66: cost=1.020, accuracy=0.579/0.470 (0/43 secs)
#     Epoch 66: cost=1.022, accuracy=0.580/0.430 (0/43 secs)
#     Epoch 67: cost=1.021, accuracy=0.596/0.500 (1/44 secs)
#     Epoch 67: cost=1.011, accuracy=0.594/0.490 (0/44 secs)
#     Epoch 68: cost=1.011, accuracy=0.610/0.450 (0/44 secs)
#     Epoch 68: cost=1.013, accuracy=0.597/0.480 (1/45 secs)
#     Epoch 69: cost=1.012, accuracy=0.586/0.480 (0/45 secs)
#     Epoch 69: cost=0.998, accuracy=0.596/0.510 (0/45 secs)
#     Epoch 70: cost=0.988, accuracy=0.611/0.460 (1/46 secs)
#     Epoch 70: cost=1.001, accuracy=0.603/0.480 (0/46 secs)
#     Epoch 71: cost=1.010, accuracy=0.591/0.530 (0/46 secs)
#     Epoch 71: cost=1.014, accuracy=0.600/0.530 (1/47 secs)
#     Epoch 72: cost=0.999, accuracy=0.610/0.540 (0/47 secs)
#     Epoch 72: cost=1.021, accuracy=0.593/0.500 (0/47 secs)
#     Epoch 73: cost=0.996, accuracy=0.604/0.490 (1/48 secs)
#     Epoch 73: cost=1.007, accuracy=0.601/0.510 (0/48 secs)
#     Epoch 74: cost=1.010, accuracy=0.606/0.540 (0/48 secs)
#     Epoch 74: cost=1.007, accuracy=0.606/0.510 (1/49 secs)
#     Epoch 75: cost=0.986, accuracy=0.599/0.540 (0/49 secs)
#     Epoch 75: cost=0.990, accuracy=0.602/0.540 (0/49 secs)
#     Epoch 76: cost=0.983, accuracy=0.609/0.510 (1/50 secs)
#     Epoch 76: cost=0.990, accuracy=0.600/0.440 (0/50 secs)
#     Epoch 77: cost=1.018, accuracy=0.611/0.490 (0/50 secs)
#     Epoch 77: cost=0.992, accuracy=0.609/0.420 (1/51 secs)
#     Epoch 78: cost=1.007, accuracy=0.593/0.560 (0/51 secs)
#     Epoch 78: cost=0.984, accuracy=0.609/0.590 (0/51 secs)
#     Epoch 79: cost=0.973, accuracy=0.604/0.570 (1/52 secs)
#     Epoch 79: cost=0.978, accuracy=0.605/0.500 (0/52 secs)
#     Epoch 80: cost=0.963, accuracy=0.615/0.460 (0/52 secs)
#     Epoch 80: cost=0.974, accuracy=0.622/0.510 (1/53 secs)
#     Epoch 81: cost=0.970, accuracy=0.616/0.540 (0/53 secs)
#     Epoch 81: cost=0.966, accuracy=0.615/0.520 (0/53 secs)
#     Epoch 82: cost=0.992, accuracy=0.599/0.520 (1/54 secs)
#     Epoch 82: cost=0.978, accuracy=0.606/0.530 (0/54 secs)
#     Epoch 83: cost=0.959, accuracy=0.629/0.520 (0/54 secs)
#     Epoch 83: cost=0.985, accuracy=0.606/0.510 (1/55 secs)
#     Epoch 84: cost=0.965, accuracy=0.603/0.590 (0/55 secs)
#     Epoch 84: cost=0.984, accuracy=0.604/0.560 (0/55 secs)
#     Epoch 85: cost=0.979, accuracy=0.612/0.470 (1/56 secs)
#     Epoch 85: cost=0.970, accuracy=0.609/0.490 (0/56 secs)
#     Epoch 86: cost=0.961, accuracy=0.622/0.600 (0/56 secs)
#     Epoch 86: cost=0.968, accuracy=0.609/0.480 (1/57 secs)
#     Epoch 87: cost=0.923, accuracy=0.634/0.560 (0/57 secs)
#     Epoch 87: cost=0.949, accuracy=0.625/0.440 (0/57 secs)
#     Epoch 88: cost=0.970, accuracy=0.608/0.500 (1/58 secs)
#     Epoch 88: cost=0.961, accuracy=0.618/0.550 (0/58 secs)
#     Epoch 89: cost=0.971, accuracy=0.616/0.470 (0/58 secs)
#     Epoch 89: cost=0.957, accuracy=0.619/0.540 (1/59 secs)
#     Epoch 90: cost=0.966, accuracy=0.622/0.580 (0/59 secs)
#     Epoch 90: cost=0.963, accuracy=0.617/0.500 (0/59 secs)
#     Epoch 91: cost=0.961, accuracy=0.624/0.490 (1/60 secs)
#     Epoch 91: cost=0.954, accuracy=0.620/0.410 (0/60 secs)
#     Epoch 92: cost=0.959, accuracy=0.624/0.510 (0/60 secs)
#     Epoch 92: cost=0.968, accuracy=0.623/0.490 (1/61 secs)
#     Epoch 93: cost=0.921, accuracy=0.629/0.450 (0/61 secs)
#     Epoch 93: cost=0.952, accuracy=0.613/0.410 (0/61 secs)
#     Epoch 94: cost=0.958, accuracy=0.626/0.460 (1/62 secs)
#     Epoch 94: cost=0.948, accuracy=0.631/0.530 (0/62 secs)
#     Epoch 95: cost=0.951, accuracy=0.623/0.490 (0/62 secs)
#     Epoch 95: cost=0.933, accuracy=0.632/0.590 (1/63 secs)
#     Epoch 96: cost=0.920, accuracy=0.650/0.530 (0/63 secs)
#     Epoch 96: cost=0.930, accuracy=0.637/0.480 (0/63 secs)
#     Epoch 97: cost=0.936, accuracy=0.632/0.510 (1/64 secs)
#     Epoch 97: cost=0.946, accuracy=0.630/0.520 (0/64 secs)
#     Epoch 98: cost=0.932, accuracy=0.641/0.490 (0/64 secs)
#     Epoch 98: cost=0.945, accuracy=0.628/0.530 (1/65 secs)
#     Epoch 99: cost=0.934, accuracy=0.629/0.500 (0/65 secs)
#     Epoch 99: cost=0.937, accuracy=0.630/0.620 (0/65 secs)
#     Epoch 100: cost=0.910, accuracy=0.652/0.510 (1/66 secs)
#     Epoch 100: cost=0.919, accuracy=0.636/0.560 (0/66 secs)
# Model flowers_model_3 train ended in 66 secs:
# Model flowers_model_3 test report: accuracy = 0.532, (0 secs)
#
# Model flowers_model_3 Visualization
# 추정확률분포 [ 2, 3, 1,85, 9] => 추정 sunflower : 정답 sunflower => O
# 추정확률분포 [13,77, 5, 0, 4] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [53,13,27, 1, 6] => 추정 daisy : 정답 daisy => O

# %%
od = Office31Dataset([96, 96], [3, 96, 96])

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'tanh'}], 
                ['avg', {'stride':3}],
               ['conv', {'ksize':3, 'chn':48, 'actfunc':'tanh'}], 
                ['avg', {'stride':2}]])
om3.exec_all(epoch_count=EPOCH, report=80, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# Model office31_model_3 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Tanh()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): Tanh()
#     (5): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): Tanh()
#     (8): AvgPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0)
#     (9): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (10): Tanh()
#     (11): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Linear(in_features=768, out_features=34, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=4.343, accuracy=0.683+0.039/0.740+0.060 (0/0 secs)
#     Epoch 2: cost=4.192, accuracy=0.684+0.062/0.700+0.060 (1/1 secs)
#     Epoch 3: cost=4.087, accuracy=0.713+0.088/0.750+0.090 (1/2 secs)
#     Epoch 4: cost=3.990, accuracy=0.738+0.103/0.770+0.090 (1/3 secs)
#     Epoch 5: cost=3.936, accuracy=0.743+0.106/0.740+0.090 (0/3 secs)
#     Epoch 6: cost=3.872, accuracy=0.741+0.124/0.740+0.120 (1/4 secs)
#     Epoch 7: cost=3.841, accuracy=0.736+0.125/0.690+0.150 (1/5 secs)
#     Epoch 8: cost=3.793, accuracy=0.743+0.138/0.760+0.110 (0/5 secs)
#     Epoch 9: cost=3.770, accuracy=0.749+0.162/0.660+0.150 (1/6 secs)
#     Epoch 10: cost=3.740, accuracy=0.748+0.165/0.670+0.160 (1/7 secs)
#     Epoch 11: cost=3.728, accuracy=0.749+0.166/0.720+0.160 (0/7 secs)
#     Epoch 12: cost=3.709, accuracy=0.737+0.172/0.720+0.140 (1/8 secs)
#     Epoch 13: cost=3.695, accuracy=0.745+0.174/0.730+0.170 (1/9 secs)
#     Epoch 14: cost=3.658, accuracy=0.750+0.185/0.710+0.160 (0/9 secs)
#     Epoch 15: cost=3.649, accuracy=0.750+0.188/0.660+0.150 (1/10 secs)
#     Epoch 16: cost=3.628, accuracy=0.758+0.196/0.720+0.170 (1/11 secs)
#     Epoch 17: cost=3.597, accuracy=0.755+0.194/0.740+0.140 (0/11 secs)
#     Epoch 18: cost=3.588, accuracy=0.750+0.200/0.680+0.150 (1/12 secs)
#     Epoch 19: cost=3.579, accuracy=0.760+0.201/0.740+0.200 (1/13 secs)
#     Epoch 20: cost=3.554, accuracy=0.758+0.202/0.720+0.160 (0/13 secs)
#     Epoch 21: cost=3.536, accuracy=0.761+0.206/0.780+0.190 (1/14 secs)
#     Epoch 22: cost=3.543, accuracy=0.759+0.207/0.780+0.200 (1/15 secs)
#     Epoch 23: cost=3.525, accuracy=0.757+0.205/0.760+0.200 (0/15 secs)
#     Epoch 24: cost=3.501, accuracy=0.764+0.210/0.730+0.170 (1/16 secs)
#     Epoch 25: cost=3.511, accuracy=0.764+0.208/0.710+0.230 (1/17 secs)
#     Epoch 26: cost=3.492, accuracy=0.762+0.214/0.730+0.220 (0/17 secs)
#     Epoch 27: cost=3.478, accuracy=0.767+0.210/0.730+0.220 (1/18 secs)
#     Epoch 28: cost=3.472, accuracy=0.764+0.218/0.760+0.210 (1/19 secs)
#     Epoch 29: cost=3.457, accuracy=0.766+0.227/0.760+0.260 (0/19 secs)
#     Epoch 30: cost=3.431, accuracy=0.767+0.233/0.680+0.230 (1/20 secs)
#     Epoch 31: cost=3.409, accuracy=0.771+0.235/0.740+0.220 (1/21 secs)
#     Epoch 32: cost=3.427, accuracy=0.770+0.229/0.720+0.190 (0/21 secs)
#     Epoch 33: cost=3.405, accuracy=0.772+0.233/0.710+0.190 (1/22 secs)
#     Epoch 34: cost=3.395, accuracy=0.777+0.239/0.800+0.250 (1/23 secs)
#     Epoch 35: cost=3.385, accuracy=0.773+0.233/0.760+0.240 (0/23 secs)
#     Epoch 36: cost=3.375, accuracy=0.769+0.242/0.700+0.300 (1/24 secs)
#     Epoch 37: cost=3.349, accuracy=0.778+0.245/0.740+0.220 (1/25 secs)
#     Epoch 38: cost=3.331, accuracy=0.780+0.250/0.750+0.260 (0/25 secs)
#     Epoch 39: cost=3.332, accuracy=0.775+0.246/0.750+0.210 (1/26 secs)
#     Epoch 40: cost=3.341, accuracy=0.770+0.252/0.690+0.250 (1/27 secs)
#     Epoch 41: cost=3.317, accuracy=0.775+0.243/0.800+0.200 (0/27 secs)
#     Epoch 42: cost=3.313, accuracy=0.778+0.261/0.750+0.260 (1/28 secs)
#     Epoch 43: cost=3.305, accuracy=0.783+0.254/0.720+0.250 (1/29 secs)
#     Epoch 44: cost=3.295, accuracy=0.778+0.255/0.740+0.180 (0/29 secs)
#     Epoch 45: cost=3.283, accuracy=0.785+0.254/0.800+0.290 (1/30 secs)
#     Epoch 46: cost=3.288, accuracy=0.779+0.246/0.750+0.250 (1/31 secs)
#     Epoch 47: cost=3.262, accuracy=0.782+0.253/0.790+0.190 (0/31 secs)
#     Epoch 48: cost=3.247, accuracy=0.786+0.261/0.770+0.240 (1/32 secs)
#     Epoch 49: cost=3.245, accuracy=0.786+0.266/0.750+0.220 (1/33 secs)
#     Epoch 50: cost=3.239, accuracy=0.785+0.261/0.720+0.290 (0/33 secs)
#     Epoch 51: cost=3.227, accuracy=0.785+0.267/0.750+0.250 (1/34 secs)
#     Epoch 52: cost=3.207, accuracy=0.791+0.276/0.770+0.240 (1/35 secs)
#     Epoch 53: cost=3.212, accuracy=0.786+0.266/0.710+0.240 (0/35 secs)
#     Epoch 54: cost=3.206, accuracy=0.786+0.268/0.790+0.250 (1/36 secs)
#     Epoch 55: cost=3.214, accuracy=0.789+0.268/0.780+0.260 (1/37 secs)
#     Epoch 56: cost=3.184, accuracy=0.787+0.283/0.740+0.230 (0/37 secs)
#     Epoch 57: cost=3.168, accuracy=0.792+0.273/0.770+0.180 (1/38 secs)
#     Epoch 58: cost=3.168, accuracy=0.796+0.284/0.740+0.290 (1/39 secs)
#     Epoch 59: cost=3.164, accuracy=0.791+0.283/0.760+0.230 (0/39 secs)
#     Epoch 60: cost=3.138, accuracy=0.794+0.286/0.760+0.190 (1/40 secs)
#     Epoch 61: cost=3.138, accuracy=0.795+0.285/0.740+0.240 (1/41 secs)
#     Epoch 62: cost=3.164, accuracy=0.796+0.280/0.730+0.230 (0/41 secs)
#     Epoch 63: cost=3.118, accuracy=0.799+0.285/0.720+0.190 (1/42 secs)
#     Epoch 64: cost=3.144, accuracy=0.795+0.283/0.790+0.260 (1/43 secs)
#     Epoch 65: cost=3.124, accuracy=0.795+0.290/0.750+0.270 (0/43 secs)
#     Epoch 66: cost=3.116, accuracy=0.794+0.288/0.810+0.230 (1/44 secs)
#     Epoch 67: cost=3.082, accuracy=0.803+0.301/0.820+0.240 (1/45 secs)
#     Epoch 68: cost=3.093, accuracy=0.801+0.295/0.710+0.250 (0/45 secs)
#     Epoch 69: cost=3.089, accuracy=0.801+0.295/0.780+0.220 (1/46 secs)
#     Epoch 70: cost=3.067, accuracy=0.804+0.297/0.700+0.250 (1/47 secs)
#     Epoch 71: cost=3.044, accuracy=0.803+0.311/0.750+0.250 (0/47 secs)
#     Epoch 72: cost=3.049, accuracy=0.808+0.302/0.770+0.280 (1/48 secs)
#     Epoch 73: cost=3.046, accuracy=0.807+0.305/0.770+0.220 (1/49 secs)
#     Epoch 74: cost=3.028, accuracy=0.807+0.313/0.740+0.270 (0/49 secs)
#     Epoch 75: cost=3.051, accuracy=0.805+0.302/0.770+0.190 (1/50 secs)
#     Epoch 76: cost=3.046, accuracy=0.801+0.311/0.800+0.250 (1/51 secs)
#     Epoch 77: cost=3.033, accuracy=0.808+0.309/0.780+0.210 (0/51 secs)
#     Epoch 78: cost=3.016, accuracy=0.808+0.313/0.730+0.220 (1/52 secs)
#     Epoch 79: cost=3.011, accuracy=0.811+0.313/0.720+0.270 (1/53 secs)
#     Epoch 80: cost=2.994, accuracy=0.810+0.323/0.810+0.280 (0/53 secs)
#     Epoch 81: cost=3.006, accuracy=0.807+0.318/0.790+0.220 (1/54 secs)
#     Epoch 82: cost=3.001, accuracy=0.809+0.314/0.790+0.220 (1/55 secs)
#     Epoch 83: cost=2.992, accuracy=0.811+0.320/0.760+0.200 (1/56 secs)
#     Epoch 84: cost=2.999, accuracy=0.809+0.318/0.740+0.240 (0/56 secs)
#     Epoch 85: cost=2.988, accuracy=0.810+0.320/0.750+0.210 (1/57 secs)
#     Epoch 86: cost=2.964, accuracy=0.812+0.327/0.800+0.200 (1/58 secs)
#     Epoch 87: cost=2.946, accuracy=0.814+0.337/0.740+0.270 (0/58 secs)
#     Epoch 88: cost=2.967, accuracy=0.809+0.325/0.730+0.260 (1/59 secs)
#     Epoch 89: cost=2.946, accuracy=0.812+0.334/0.740+0.300 (1/60 secs)
#     Epoch 90: cost=2.951, accuracy=0.810+0.325/0.810+0.210 (0/60 secs)
#     Epoch 91: cost=2.942, accuracy=0.817+0.333/0.810+0.230 (1/61 secs)
#     Epoch 92: cost=2.921, accuracy=0.815+0.333/0.760+0.220 (1/62 secs)
#     Epoch 93: cost=2.923, accuracy=0.814+0.339/0.750+0.270 (0/62 secs)
#     Epoch 94: cost=2.922, accuracy=0.819+0.338/0.770+0.280 (1/63 secs)
#     Epoch 95: cost=2.917, accuracy=0.813+0.334/0.830+0.270 (1/64 secs)
#     Epoch 96: cost=2.927, accuracy=0.811+0.339/0.710+0.260 (0/64 secs)
#     Epoch 97: cost=2.919, accuracy=0.814+0.332/0.770+0.240 (1/65 secs)
#     Epoch 98: cost=2.920, accuracy=0.808+0.344/0.790+0.230 (1/66 secs)
#     Epoch 99: cost=2.886, accuracy=0.819+0.340/0.820+0.240 (0/66 secs)
#     Epoch 100: cost=2.904, accuracy=0.815+0.341/0.740+0.240 (1/67 secs)
# Model office31_model_3 train ended in 67 secs:
# Model office31_model_3 test report: accuracy = 0.792+0.254, (0 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [63,21,16] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [76, 2,22] => 추정 amazon : 정답 webcam => X
# 추정확률분포 [80,10,10] => 추정 amazon : 정답 webcam => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 6, 2, 1, 2, 1, 1, 6, 1,...] => 추정 headphones : 정답 headphones => O
# 추정확률분포 [ 0, 2, 2, 0, 0, 2, 0, 0,...] => 추정 projector : 정답 projector => O
# 추정확률분포 [ 0,13, 1, 1, 0, 0, 2, 0,...] => 추정 desktop_computer : 정답 punchers => X
