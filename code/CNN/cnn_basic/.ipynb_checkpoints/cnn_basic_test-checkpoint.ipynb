# %%
BASE_DIR = '../'*3
MODEL_DIR = BASE_DIR +'code/CNN/cnn_basic/cnn_basic_model.ipynb'
FLW_DIR = BASE_DIR + 'code/UTIL/dataset/flower_prepro.ipynb'
OFFICE_DIR = BASE_DIR +'code/UTIL/dataset/office31_prepro.ipynb'
# %run {MODEL_DIR}
# %run {FLW_DIR}
# %run {OFFICE_DIR}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
EPOCH = 10
BATCH_SIZE=30
NUM_WORKERS=0
LEARNING_RATE = 0.00005

# %%
fd = FlowersDataset([96, 96], [3, 96, 96])
print(fd)
# Out:
# flowers(select, 3450+652+215)

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [['full',{'width':30}],
                                           ['full',{'width':10}]])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# [[Linear(in_features=27648, out_features=30, bias=True)], [Linear(in_features=30, out_features=10, bias=True)], [Flatten(start_dim=1, end_dim=-1)], [Linear(in_features=10, out_features=5, bias=True)]]
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Linear(in_features=27648, out_features=30, bias=True)
#     (1): Linear(in_features=30, out_features=10, bias=True)
#     (2): Flatten(start_dim=1, end_dim=-1)
#     (3): Linear(in_features=10, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=53.740, accuracy=0.284/0.270 (2/2 secs)
#     Epoch 1: cost=37.312, accuracy=0.325/0.340 (1/3 secs)
#     Epoch 2: cost=21.717, accuracy=0.389/0.260 (2/5 secs)
#     Epoch 2: cost=20.988, accuracy=0.387/0.400 (2/7 secs)
#     Epoch 3: cost=13.271, accuracy=0.417/0.310 (2/9 secs)
#     Epoch 3: cost=14.581, accuracy=0.421/0.370 (1/10 secs)
#     Epoch 4: cost=13.106, accuracy=0.453/0.290 (2/12 secs)
#     Epoch 4: cost=11.194, accuracy=0.465/0.360 (1/13 secs)
#     Epoch 5: cost=12.311, accuracy=0.488/0.410 (2/15 secs)
#     Epoch 5: cost=14.221, accuracy=0.453/0.300 (1/16 secs)
#     Epoch 6: cost=13.126, accuracy=0.478/0.310 (3/19 secs)
#     Epoch 6: cost=10.063, accuracy=0.510/0.410 (1/20 secs)
#     Epoch 7: cost=9.582, accuracy=0.526/0.400 (2/22 secs)
#     Epoch 7: cost=9.748, accuracy=0.519/0.400 (1/23 secs)
#     Epoch 8: cost=9.929, accuracy=0.509/0.380 (2/25 secs)
#     Epoch 8: cost=11.384, accuracy=0.484/0.350 (2/27 secs)
#     Epoch 9: cost=7.375, accuracy=0.530/0.420 (2/29 secs)
#     Epoch 9: cost=9.025, accuracy=0.513/0.380 (1/30 secs)
#     Epoch 10: cost=5.908, accuracy=0.607/0.330 (2/32 secs)
#     Epoch 10: cost=6.621, accuracy=0.589/0.420 (1/33 secs)
# Model flowers_model_1 train ended in 34 secs:
# Model flowers_model_1 test report: accuracy = 0.437, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [ 0, 0,100, 0, 0] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 0,95, 0, 5, 0] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [ 0,16,71,13, 0] => 추정 rose : 정답 sunflower => X

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [['conv', {'ksize':2, 'chn':6}], 
                ['max', {'stride':2}], 
                ])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# [[Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1)), ReLU()], [MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)], [Flatten(start_dim=1, end_dim=-1)], [Linear(in_features=13824, out_features=5, bias=True)]]
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=13824, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=5.851, accuracy=0.243/0.210 (4/4 secs)
#     Epoch 1: cost=5.137, accuracy=0.250/0.360 (3/7 secs)
#     Epoch 2: cost=3.319, accuracy=0.312/0.290 (6/13 secs)
#     Epoch 2: cost=3.180, accuracy=0.327/0.330 (3/16 secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11652/757792297.py in <module>
#       4                 ])
#       5 fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
# ----> 6            , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
#       7           )
#
# ~\AppData\Local\Temp/ipykernel_11652/4054610662.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, num_workers)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3, num_workers=0):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report, num_workers)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# ~\AppData\Local\Temp/ipykernel_11652/1004127769.py in train_torch(self, epoch_count, batch_size, learning_rate, report, num_workers)
#      45             loss=self.forward_postproc(loss_func, output, y_train)
#      46             acc = self.eval_accuracy(X_train, y_train, output)
# ---> 47             loss.backward()
#      48             optimizer.step()
#      49
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:

# %%
#SGD
fm = CnnBasicModel('flowers_model_1', fd, [['conv', {'ksize':2, 'chn':6,'actfunc':'relu'}], 
                ['max', {'stride':2}],
                                           ['conv', {'ksize':2, 'chn':12,'actfunc':'relu'}], 
                ['avg', {'stride':2}]
                ])
fm.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# Model flowers_model_1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(2, 2), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6912, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
# C:\Users\oh\anaconda3\envs\nalcoding\lib\site-packages\torch\nn\modules\conv.py:440: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ..\aten\src\ATen\native\Convolution.cpp:660.)
#   self.padding, self.dilation, self.groups)
#     Epoch 1: cost=4.007, accuracy=0.244/0.250 (6/6 secs)
#     Epoch 1: cost=3.551, accuracy=0.273/0.320 (5/11 secs)
#     Epoch 2: cost=2.492, accuracy=0.358/0.300 (11/22 secs)
#     Epoch 2: cost=2.393, accuracy=0.356/0.370 (6/28 secs)
#     Epoch 3: cost=2.027, accuracy=0.383/0.290 (10/38 secs)
#     Epoch 3: cost=2.053, accuracy=0.385/0.310 (5/43 secs)
#     Epoch 4: cost=1.752, accuracy=0.435/0.360 (11/54 secs)
#     Epoch 4: cost=1.786, accuracy=0.430/0.330 (6/60 secs)
#     Epoch 5: cost=1.560, accuracy=0.465/0.360 (10/70 secs)
#     Epoch 5: cost=1.635, accuracy=0.451/0.430 (6/76 secs)
#     Epoch 6: cost=1.433, accuracy=0.497/0.280 (10/86 secs)
#     Epoch 6: cost=1.464, accuracy=0.491/0.430 (6/92 secs)
#     Epoch 7: cost=1.302, accuracy=0.527/0.370 (10/102 secs)
#     Epoch 7: cost=1.339, accuracy=0.519/0.370 (5/107 secs)
#     Epoch 8: cost=1.294, accuracy=0.534/0.390 (11/118 secs)
#     Epoch 8: cost=1.272, accuracy=0.533/0.340 (6/124 secs)
#     Epoch 9: cost=1.138, accuracy=0.572/0.310 (10/134 secs)
#     Epoch 9: cost=1.174, accuracy=0.566/0.390 (6/140 secs)
#     Epoch 10: cost=1.186, accuracy=0.544/0.330 (10/150 secs)
#     Epoch 10: cost=1.161, accuracy=0.565/0.350 (6/156 secs)
# Model flowers_model_1 train ended in 161 secs:
# Model flowers_model_1 test report: accuracy = 0.371, (1 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [ 3,13,68, 6, 9] => 추정 rose : 정답 daisy => X
# 추정확률분포 [ 2,17,41, 0,41] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [37,14,19,18,12] => 추정 daisy : 정답 tulip => X

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6,'actfunc':'relu'}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12,'actfunc':'relu'}], 
                ['avg', {'stride':2}]])
fm3.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# Model flowers_model_3 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=1728, out_features=5, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=14.011, accuracy=0.193/0.190 (4/4 secs)
#     Epoch 1: cost=9.163, accuracy=0.196/0.170 (4/8 secs)
#     Epoch 2: cost=3.518, accuracy=0.240/0.270 (8/16 secs)
#     Epoch 2: cost=3.461, accuracy=0.236/0.190 (5/21 secs)
#     Epoch 3: cost=3.010, accuracy=0.250/0.270 (7/28 secs)
#     Epoch 3: cost=3.010, accuracy=0.244/0.290 (4/32 secs)
#     Epoch 4: cost=2.784, accuracy=0.276/0.250 (8/40 secs)
#     Epoch 4: cost=2.708, accuracy=0.265/0.240 (4/44 secs)
#     Epoch 5: cost=2.621, accuracy=0.272/0.270 (8/52 secs)
#     Epoch 5: cost=2.499, accuracy=0.279/0.320 (4/56 secs)
#     Epoch 6: cost=2.361, accuracy=0.278/0.230 (8/64 secs)
#     Epoch 6: cost=2.386, accuracy=0.275/0.270 (4/68 secs)
#     Epoch 7: cost=2.248, accuracy=0.293/0.310 (7/75 secs)
#     Epoch 7: cost=2.197, accuracy=0.293/0.280 (5/80 secs)
#     Epoch 8: cost=2.079, accuracy=0.297/0.340 (8/88 secs)
#     Epoch 8: cost=2.082, accuracy=0.305/0.300 (4/92 secs)
#     Epoch 9: cost=1.966, accuracy=0.333/0.290 (8/100 secs)
#     Epoch 9: cost=1.976, accuracy=0.315/0.280 (4/104 secs)
#     Epoch 10: cost=1.953, accuracy=0.308/0.300 (8/112 secs)
#     Epoch 10: cost=1.888, accuracy=0.319/0.270 (4/116 secs)
# Model flowers_model_3 train ended in 119 secs:
# Model flowers_model_3 test report: accuracy = 0.242, (1 secs)
#
# Model flowers_model_3 Visualization
# 추정확률분포 [ 4, 0,95, 0, 0] => 추정 rose : 정답 tulip => X
# 추정확률분포 [ 0,26, 9, 2,63] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 5,84, 7, 1, 2] => 추정 dandelion : 정답 dandelion => O

# %%
od = Office31Dataset([96, 96], [3, 96, 96])

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'tanh'}], 
                ['avg', {'stride':3}]])
om3.exec_all(epoch_count=EPOCH, report=40, batch_size =BATCH_SIZE \
           , learning_rate = LEARNING_RATE , num_workers = NUM_WORKERS \
          )
# Out:
# (3, 96, 96)
# Model office31_model_3 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (layer1): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Tanh()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): Tanh()
#     (5): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): Tanh()
#     (8): AvgPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0)
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=1536, out_features=34, bias=True)
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5e-05
#     weight_decay: 0
# )
#     Epoch 1: cost=4.385, accuracy=0.593+0.051/0.710+0.050 (7/7 secs)
#     Epoch 1: cost=4.314, accuracy=0.634+0.057/0.660+0.050 (7/14 secs)
#     Epoch 2: cost=4.131, accuracy=0.696+0.095/0.680+0.070 (12/26 secs)
#     Epoch 2: cost=4.122, accuracy=0.691+0.095/0.690+0.110 (7/33 secs)
#     Epoch 3: cost=4.003, accuracy=0.708+0.113/0.650+0.080 (11/44 secs)
#     Epoch 3: cost=3.974, accuracy=0.714+0.120/0.690+0.070 (8/52 secs)
#     Epoch 4: cost=3.841, accuracy=0.736+0.130/0.690+0.110 (12/64 secs)
#     Epoch 4: cost=3.837, accuracy=0.732+0.129/0.700+0.070 (7/71 secs)
#     Epoch 5: cost=3.773, accuracy=0.730+0.152/0.660+0.090 (11/82 secs)
#     Epoch 5: cost=3.762, accuracy=0.730+0.145/0.700+0.150 (7/89 secs)
#     Epoch 6: cost=3.680, accuracy=0.750+0.154/0.640+0.180 (12/101 secs)
#     Epoch 6: cost=3.669, accuracy=0.750+0.156/0.700+0.130 (6/107 secs)
#     Epoch 7: cost=3.658, accuracy=0.750+0.161/0.730+0.180 (11/118 secs)
#     Epoch 7: cost=3.635, accuracy=0.754+0.163/0.690+0.200 (7/125 secs)
#     Epoch 8: cost=3.605, accuracy=0.738+0.178/0.700+0.230 (11/136 secs)
#     Epoch 8: cost=3.578, accuracy=0.752+0.182/0.760+0.160 (7/143 secs)
#     Epoch 9: cost=3.522, accuracy=0.760+0.207/0.720+0.160 (12/155 secs)
#     Epoch 9: cost=3.529, accuracy=0.767+0.191/0.720+0.200 (8/163 secs)
#     Epoch 10: cost=3.507, accuracy=0.760+0.196/0.780+0.210 (11/174 secs)
#     Epoch 10: cost=3.504, accuracy=0.758+0.202/0.760+0.180 (7/181 secs)
# Model office31_model_3 train ended in 186 secs:
# Model office31_model_3 test report: accuracy = 0.776+0.157, (1 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [96, 2, 2] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [ 1,29,70] => 추정 webcam : 정답 dslr => X
# 추정확률분포 [97, 2, 1] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 1, 0, 3, 4, 3, 2, 4,...] => 추정 pen : 정답 pen => O
# 추정확률분포 [10,22, 9, 2, 1, 2,13, 1,...] => 추정 bike : 정답 file_cabinet => X
# 추정확률분포 [ 0, 0, 0, 2, 4, 2, 1, 2,...] => 추정 pen : 정답 pen => O
