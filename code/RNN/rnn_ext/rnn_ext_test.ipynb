# %%
BASE_DIR = '../'*3
RUN_DIR = BASE_DIR + 'code/RNN/rnn_ext/rnn_ext_model.ipynb'
DATA_DIR = BASE_DIR + 'code/UTIL/dataset/dataset_videoshot.ipynb'

# %%
EPOCH = 10
BATCH_SIZE=30
NUM_WORKERS=0
LEARNING_RATE = 0.001

# %%
# %run {RUN_DIR}
# %run {DATA_DIR}
# Out:
# Using device: cpu
# Using PyTorch version: 1.9.0

# %%
vsd  = VideoShotDataset(['AStarIsBorn1937.mp4'])
# # vsd  = VideoShotDataset(['AStarIsBorn1937.mp4'],count = 50,batch = BATCH_SIZE)
# # print(vsd)
# Out:
# AStarIsBorn1937.mp4: cache file is found => use cache
# Creating thumbnail cache is done

# %%
conf1 = \
    [['seqwrap', ['avg',{'stride':30}],
                 ['conv',{'ksize':3, 'chn':12}],
#                  ['full', {'width':16}]],
                 ['full', {'width':16}]],
    ['lstm', {'recur_size':8}]]
    
vsm1 = RnnExtModel('vsm1', vsd, conf1)
vsm1.exec_all(epoch_count=EPOCH, report=2,batch_size=BATCH_SIZE, show_cnt=3)

# vsm1.exec_all(epoch_count=10, report=2, show_cnt=3,batch_size=BATCH_SIZE)
# Out:
# [3, 90, 120]
# 90 30 120 30
# xxxxxxxxxxxxxxxx 10
# Model vsm1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (cnn): Sequential(
#     (0): AvgPool2d(kernel_size=(30, 30), stride=(30, 30), padding=(0, 0))
#     (1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (2): ReLU()
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=144, out_features=16, bias=True)
#   )
#   (Lstm): Sequential(
#     (0): LSTM(
#       (lstm): LSTM(16, 8, batch_first=True)
#     )
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Model vsm1 train ended in 2 secs:
# Model vsm1 test report: accuracy = 0.592, (0 secs)
#
# Model vsm1 Visualization
# Est: 0.43,0.65,0.65,0.55
# Ans: 1.00,1.00,1.00,1.00
# Est: 0.60,0.66,0.66,0.65
# Ans: 1.00,1.00,0.00,1.00
# Est: 0.50,0.47,0.53,0.52
# Ans: 0.00,1.00,1.00,0.00

# %%
vsd.set_timesteps(6)

vsm1_6 = RnnExtModel('vsm1_6', vsd, conf1)
vsm1_6.exec_all(epoch_count=10, report=2, show_cnt=3)

vsd.set_timesteps(5)
# Out:
# [3, 90, 120]
# 90 30 120 30
# xxxxxxxxxxxxxxxx 10
# Model vsm1_6 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (cnn): Sequential(
#     (0): AvgPool2d(kernel_size=(30, 30), stride=(30, 30), padding=(0, 0))
#     (1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (2): ReLU()
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=144, out_features=16, bias=True)
#   )
#   (Lstm): Sequential(
#     (0): LSTM(
#       (lstm): LSTM(16, 8, batch_first=True)
#     )
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Model vsm1_6 train ended in 2 secs:
# Model vsm1_6 test report: accuracy = 0.611, (1 secs)
#
# Model vsm1_6 Visualization
# Est: 0.60,0.62,0.61,0.65,0.64
# Ans: 1.00,0.00,1.00,1.00,0.00
# Est: 0.61,0.59,0.58,0.58,0.64
# Ans: 0.00,1.00,0.00,1.00,1.00
# Est: 0.59,0.62,0.60,0.62,0.61
# Ans: 0.00,1.00,1.00,0.00,1.00

# %%
conf3 = \
    [['seqwrap', ['conv',{'ksize':1, 'chn':4}],
                 ['max',{'stride':2}],
                 ['conv',{'ksize':1, 'chn':8}],
                 ['max',{'stride':3}],
                 ['conv',{'ksize':1, 'chn':16}],
                 ['avg',{'stride':5}],
                 ['full', {'width':12}]],
    ['lstm', {'recur_size':8}]]
    
vsm3 = RnnExtModel('vsm3', vsd, conf3)
vsm3.exec_all(epoch_count=10, report=2, show_cnt=3)
# Out:
# [16, 15, 20]
# 15 5 20 5
# xxxxxxxxxxxxxxxx 10
# Model vsm3 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (cnn): Sequential(
#     (0): Conv2d(3, 4, kernel_size=(1, 1), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0), dilation=1, ceil_mode=False)
#     (3): Conv2d(4, 8, kernel_size=(1, 1), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=(3, 3), stride=(3, 3), padding=(1, 1), dilation=1, ceil_mode=False)
#     (6): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=(5, 5), stride=(5, 5), padding=(0, 0))
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=192, out_features=12, bias=True)
#   )
#   (Lstm): Sequential(
#     (0): LSTM(
#       (lstm): LSTM(12, 8, batch_first=True)
#     )
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Model vsm3 train ended in 10 secs:
# Model vsm3 test report: accuracy = 0.607, (5 secs)
#
# Model vsm3 Visualization
# Est: 0.50,0.51,0.51,0.51
# Ans: 1.00,1.00,0.00,1.00
# Est: 0.50,0.51,0.51,0.51
# Ans: 1.00,1.00,0.00,0.00
# Est: 0.51,0.51,0.50,0.51
# Ans: 1.00,0.00,1.00,1.00

# %%
vsm1.exec_all(epoch_count=400, report=2, show_cnt=1)
# vsm2.exec_all(epoch_count=40, report=20, show_cnt=0)
# vsm3.exec_all(epoch_count=40, report=20, show_cnt=0)
# Out:
# xxxxxxxxxxxxxxxx 400
# Model vsm1 train started
#
#
# !!!!!!!!!!!
# !! Layer !! .
# !!!!!!!!!!!
#
#  Net(
#   (cnn): Sequential(
#     (0): AvgPool2d(kernel_size=(30, 30), stride=(30, 30), padding=(0, 0))
#     (1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (2): ReLU()
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Linear(in_features=144, out_features=16, bias=True)
#   )
#   (Lstm): Sequential(
#     (0): LSTM(
#       (lstm): LSTM(16, 8, batch_first=True)
#     )
#   )
# )
#
# !!!!!!!!!!!!!!!
# !! optimizer !!
# !!!!!!!!!!!!!!!
#
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Model vsm1 train ended in 65 secs:
# Model vsm1 test report: accuracy = 0.654, (1 secs)
#
# Model vsm1 Visualization
# Est: 0.69,0.67,0.68,0.68
# Ans: 1.00,1.00,1.00,0.00
